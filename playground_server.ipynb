# %%
import fitz
import re

# %%
PDF_PATH = 'hp1.pdf'
doc = fitz.open(PDF_PATH)
print(doc)
# Out:
# Document('hp1.pdf')

# %%
# bbox format: [x1, y1, x2, y2]
# origin format: [x, y]

# %%
UNCERTAINTY_END = 10
UNCERTAINTY_SIZE = 2
UNCERTAINTY_LINE_HEIGTH = 2

REMOVE_PAGE_NUMBER = True

PAGE_NUM_PATTERN = r'[0-9]+'
#PAGE_NUM_PATTERN = r'\- [0-9]+ \-'

# %%
def flags_decomposer(flags):
    """Make font flags human readable."""
    l = []
    if flags & 2 ** 0:
        l.append("superscript")
    if flags & 2 ** 1:
        l.append("italic")
    if flags & 2 ** 2:
        l.append("serifed")
    else:
        l.append("sans")
    if flags & 2 ** 3:
        l.append("monospaced")
    else:
        l.append("proportional")
    if flags & 2 ** 4:
        l.append("bold")
    return l

# %%
def get_spans(book, starting_page=0):
    spans = []
    for page_nr in range(starting_page, book.page_count):
        blocks = book[page_nr].get_text('dict', flags=11)['blocks']
        for block in blocks:
            if block['type'] == 0: # Text Block
                # Remove the page number if needed
                if REMOVE_PAGE_NUMBER and len(block['lines']) == 1 and len(block['lines'][0]['spans']) == 1 and bool(re.match(PAGE_NUM_PATTERN, block['lines'][0]['spans'][0]['text'].strip())):
                   continue
                for line in block['lines']:
                    for span in line['spans']:
                        if span['text'].strip() != '':
                            spans.append({
                                'text': span['text'],
                                'size': round(span['size']),
                                'y_org': round(span['origin'][1]),
                                'x_end': round(span['bbox'][2]),
                                'flags': span['flags']
                            })
            if block['type'] == 1: # Image Block
                pass # TODO
    return spans

# %%
spans = get_spans(doc, starting_page=6)
spans
# Out:
# [{'text': 'Ein Junge Überlebt',
#   'size': 22,
#   'y_org': 63,
#   'x_end': 283,
#   'flags': 4},
#  {'text': 'Mr. und Mrs. Dursley im Ligusterweg Nummer 4 waren stolz',
#   'size': 11,
#   'y_org': 105,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'darauf, ganz und gar normal zu sein, sehr stolz sogar. Niemand wäre',
#   'size': 11,
#   'y_org': 118,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'auf die Idee gekommen, sie könnten sich in eine merkwürdige und',
#   'size': 11,
#   'y_org': 131,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'geheimnisvolle Geschichte verstricken, denn mit solchem Unsinn',
#   'size': 11,
#   'y_org': 144,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wollten sie nichts zu tun haben.',
#   'size': 11,
#   'y_org': 157,
#   'x_end': 179,
#   'flags': 4},
#  {'text': 'Mr. Dursley war Direktor einer Firma namens Grunnings, die',
#   'size': 12,
#   'y_org': 171,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Bohrmaschinen herstellte. Er war groß und bullig und hatte fast',
#   'size': 12,
#   'y_org': 186,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'keinen Hals, dafür aber einen sehr großen Schnurrbart. Mrs.',
#   'size': 12,
#   'y_org': 200,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley war dünn und blond und besaß doppelt so viel Hals, wie',
#   'size': 12,
#   'y_org': 214,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'notwendig gewesen wäre, was allerdings sehr nützlich war, denn',
#   'size': 12,
#   'y_org': 228,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'so konnte sie den Hals über den Gartenzaun recken und zu den',
#   'size': 12,
#   'y_org': 242,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Nachbarn hinüberspähen. Die Dursleys hatten einen kleinen Sohn',
#   'size': 12,
#   'y_org': 256,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'namens Dudley und in ihren Augen gab es nirgendwo einen',
#   'size': 12,
#   'y_org': 270,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'prächtigeren Jungen.',
#   'size': 12,
#   'y_org': 285,
#   'x_end': 141,
#   'flags': 4},
#  {'text': 'Die Dursleys besaßen alles, was sie wollten, doch sie hatten',
#   'size': 12,
#   'y_org': 299,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'auch ein Geheimnis, und dass es Jemand aufdecken könnte, war',
#   'size': 12,
#   'y_org': 313,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ihre größte Sorge. Einfach unerträglich wäre es, wenn die Sache',
#   'size': 12,
#   'y_org': 327,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'mit den Potters herauskommen würde. Mrs. Potter war die',
#   'size': 12,
#   'y_org': 341,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Schwester von Mrs. Dursley; doch die beiden hatten sich schon',
#   'size': 12,
#   'y_org': 355,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'seit etlichen Jahren nicht mehr gesehen. Mrs. Dursley behauptete',
#   'size': 12,
#   'y_org': 370,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sogar, dass sie gar keine Schwester hätte, denn diese und deren',
#   'size': 12,
#   'y_org': 384,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Nichtsnutz von einem Mann waren so undursleyhaft, wie man es',
#   'size': 12,
#   'y_org': 398,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sich nur denken konnte. Was würden bloß die Nachbarn sagen,',
#   'size': 12,
#   'y_org': 412,
#   'x_end': 342,
#   'flags': 4},
#  {'text': 'sollten die Potters eines Tages in ihrer Straße aufkreuzen?',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Die Dursleys wussten, dass auch die Potters einen kleinen Sohn',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hatten, doch den hatten sie nie gesehen. Auch dieser Junge war',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ein guter Grund, sich von den Potters fernzuhalten; mit einem',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'solchen Kind sollte ihr Dudley nicht in Berührung kommen.',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 326,
#   'flags': 4},
#  {'text': 'Als Mr. und Mrs. Dursley an dem trüben und grauen',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dienstag, an dem unsere Geschichte beginnt, die Augen',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aufschlugen, war an dem wolkenverhangenen Himmel draußen',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'kein Vorzeichen der merkwürdigen und geheimnisvollen Dinge',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'zu erkennen, die bald Überall im Land geschehen sollten. Mr.',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley summte vor sich hin und suchte sich für die Arbeit seine',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'langweiligste Krawatte aus, und Mrs. Dursley schwatzte munter',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'vor sich hin, während sie mit dem schreienden Dudley rangelte',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'und ihn in seinen Hochstuhl zwängte.',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 220,
#   'flags': 4},
#  {'text': 'Keiner von ihnen sah den riesigen Waldkauz am Fenster',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'vorbeifliegen.',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 107,
#   'flags': 4},
#  {'text': 'Um halb neun griff Mr. Dursley nach der Aktentasche, gab',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'seiner Frau einen Schmatz auf die Wange und versuchte es auch',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'bei Dudley mit einem Abschiedskuss. Der ging Jedoch daneben,',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'weil Dudley gerade einen Wutanfall hatte und die Wände mit',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'seinem Haferbrei bewarf »Kleiner Schlingel«, gluckste Mt',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Dursley, während er nach draußen ging. Er setzte sich in den',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Wagen und fuhr rückwärts die Einfahrt zu Nummer 4 hinaus.',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 333,
#   'flags': 4},
#  {'text': 'An der Straßenecke fiel ihm zum ersten Mal etwas Merk-',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'würdiges auf - eine Katze, die eine Straßenkarte studierte. Einen',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Moment war Mr. Dursley nicht klar, was er gesehen hatte -',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dann wandte er rasch den Kopf zurück, um noch einmal',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hinzuschauen. An der Einbiegung zum Ligusterweg stand eine',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'getigerte Katze, aber eine Straßenkarte war nicht zu sehen.',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Woran er nur wieder gedacht hatte! Das',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 238,
#   'flags': 4},
#  {'text': 'musste eine Sinnestäuschung gewesen sein. Mr. Dursley',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'blinzelte und starrte die Katze an. Die Katze starrte zurück.',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Während Mr. Dursley um die Ecke bog und die Straße ent-',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'langfuhr, beobachtete er die Katze im Rückspiegel. Jetzt las sie',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'das Schild mit dem Namen ',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 172,
#   'flags': 4},
#  {'text': 'Ligusterweg ', 'size': 12, 'y_org': 110, 'x_end': 234, 'flags': 6},
#  {'text': '- nein, sie ', 'size': 12, 'y_org': 110, 'x_end': 284, 'flags': 4},
#  {'text': 'blickte ', 'size': 12, 'y_org': 110, 'x_end': 319, 'flags': 6},
#  {'text': 'auf das', 'size': 12, 'y_org': 110, 'x_end': 354, 'flags': 4},
#  {'text': 'Schild. Katzen konnten weder Karten ',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 231,
#   'flags': 4},
#  {'text': 'noch ', 'size': 12, 'y_org': 124, 'x_end': 259, 'flags': 6},
#  {'text': 'Schilder lesen. Mr.',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley gab sich einen kleinen Ruck und verjagte die Katze aus',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'seinen Gedanken. Während er in Richtung Stadt fuhr, hatte er',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nur noch den großen Auftrag für Bohrmaschinen im Sinn, der',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'heute hoffentlich eintreffen würde.',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 206,
#   'flags': 4},
#  {'text': 'Doch am Stadtrand wurden die Bohrmaschinen von etwas',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'anderem aus seinen Gedanken verdrängt. Er saß im üblichen',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'morgendlichen Stau fest und konnte nicht wohin zu bemerken,',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dass offenbar eine Menge seltsam gekleideter Menschen',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'unterwegs waren. Menschen in langen und weiten Umhängen.',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Mr. Dursley konnte Leute nicht ausstehen, die sich komisch',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'anzogen - wie sich die Jungen Leute herausputzten! Das musste',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wohl irgendeine dumme neue Mode sein. Er trommelte mit den',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Fingern auf das Lenkrad und sein Blick fiel auf eine Ansammlung',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dieser merkwürdigen Gestalten nicht weit von ihm. Ganz',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aufgeregt flüsterten sie miteinander. Erzürnt stellte Mr. Dursley',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'fest, dass einige von ihnen überhaupt nicht Jung waren; nanu,',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dieser Mann dort musste älter sein als er und trug einen',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'smaragdgrünen Umhang! Der hatte vielleicht Nerven! Doch dann',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'fiel Mr. Dursley plötzlich ein, dass dies wohl eine verrückte',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Verkleidung sein musste - die Leute sammelten offenbar für',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'irgendetwas ... Ja, so musste es sein. Die Autoschlange bewegte',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sich, und ein paar Minuten später fuhr Mr. Dursley auf den',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Parkplatz seiner Firma, die Gedanken wieder bei den Bohrern.',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 338,
#   'flags': 4},
#  {'text': 'In seinem Büro im neunten Stock saß Mr. Dursley im-',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'mer mit dem Rücken zum Fenster. Andernfalls wäre es ihm an',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'diesem Morgen schwer gefallen, sich auf die Bohrer zu',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'konzentrieren. Er bemerkte die Eulen nicht, die am helllichten',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Tage vorbeischossen, wohl aber die Leute unten auf der Straße;',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sie deuteten in die Lüfte und verfolgten mit offenen Mündern,',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wie eine Eule nach der andern über ihre Köpfe hinwegflog. Die',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'meisten von ihnen hatten überhaupt noch nie eine gesehen, nicht',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'einmal nachts. Mr. Dursley Jedoch verbrachte einen ganz',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'gewöhnlichen, eulenfreien Morgen. Er machte fünf verschiedene',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Leute zur Schnecke. Er führte mehrere wichtige Telefongesprä-',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'che und schrie dabei noch ein wenig lauter. Bis zur Mittagspause',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'war er glänzender Laune und wollte sich nun ein wenig die Beine',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'vertreten und beim Bäcker über der Straße einen Krapfen holen.',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 347,
#   'flags': 4},
#  {'text': 'Die Leute in der merkwürdigen Aufmachung hatte er schon',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'längst vergessen, doch nun, auf dem Weg zum Bäcker,',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'begegnete er einigen dieser Gestalten. Im Vorbeigehen warf er',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ihnen zornige Blicke zu. Er wusste nicht, warum, aber sie',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'bereiteten ihm Unbehagen. Auch dieses Pack hier tuschelte ganz',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aufgeregt, und eine Sammelbüchse war nirgends zu sehen. Auf',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dem Weg zurück vom Bäcker, eine Tüte mit einem großen',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Schokoladenkringel in der Hand, schnappte er ein paar Worte',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'von ihnen auf', 'size': 12, 'y_org': 351, 'x_end': 107, 'flags': 4},
#  {'text': '»Die Potters, das stimmt, das hab ich gehört',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 273,
#   'flags': 4},
#  {'text': '»-ja, ihr Sohn, Harry -«',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 174,
#   'flags': 4},
#  {'text': 'Mr. Dursley blieb wie angewurzelt stehen. Angst überkam',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ihn. Er wandte sich nach den Flüsterern um, als ob er ihnen',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'etwas sagen wollte, besann sich dann aber eines Besseren.',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 318,
#   'flags': 4},
#  {'text': 'Hastig überquerte er die Straße, stürmte hoch ins Büro,',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'fauchte seine Sekretärin an, er wolle nicht gestört werden, griff',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nach dem Telefon und hatte schon fast die Nummer',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 288,
#   'flags': 4},
#  {'text': 'von daheim gewählt, als er es sich anders überlegte. Er legte den',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Hörer auf die Gabel und strich sich über den Schnurrbart. Nein,',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dachte er, ich bin dumm. Potter war kein besonders',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ungewöhnlicher Name. Sicher gab es eine Menge Leute, die',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Potter hießen und einen Sohn namens Harry hatten. Nun, da er',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'darüber nachdachte, war er sich nicht einmal mehr sicher, ob sein',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Neffe wirklich Harry hieß. Er hatte den Jungen noch nicht einmal',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'gesehen. Er konnte auch Harvey heißen. Es hatte keinen Sinn,',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Mrs. Dursley zu beunruhigen, sie geriet immer so außer sich,',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wenn man ihre Schwester auch nur erwähnte. Er machte ihr',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'deswegen keinen Vorwurf - wenn er eine solche Schwester hätte',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 351,
#   'flags': 4},
#  {'text': 'Und dennoch, diese Leute in den Umhängen ...',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 286,
#   'flags': 4},
#  {'text': 'An diesem Nachmittag fiel es ihm um einiges schwerer, seine',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Gedanken auf die Bohrer zu richten, und als er das Büro um fünf',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Uhr verließ, war er immer noch so voller Sorge, dass er beim',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ersten ', 'size': 12, 'y_org': 266, 'x_end': 74, 'flags': 4},
#  {'text': 'Schritt ', 'size': 12, 'y_org': 266, 'x_end': 121, 'flags': 4},
#  {'text': 'nach ', 'size': 12, 'y_org': 266, 'x_end': 160, 'flags': 4},
#  {'text': 'draußen ', 'size': 12, 'y_org': 266, 'x_end': 214, 'flags': 4},
#  {'text': 'gleich ', 'size': 12, 'y_org': 266, 'x_end': 259, 'flags': 4},
#  {'text': 'mit ', 'size': 12, 'y_org': 266, 'x_end': 291, 'flags': 4},
#  {'text': 'Jemandem', 'size': 12, 'y_org': 266, 'x_end': 354, 'flags': 4},
#  {'text': 'zusammenprallte.',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 125,
#   'flags': 4},
#  {'text': '»Verzeihung«, grummelte er, als der kleine alte Mann ins',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Stolpern kam und beinahe hinfiel. Erst nach ein paar Sekunden',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'bemerkte Mr. Dursley, dass der Mann einen violetten Umhang',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'trug. Dass er ihn fast umgestoßen hatte, schien ihn gar nicht',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'weiter zu ärgern. Im Gegenteil, auf seinem Gesicht öffnete sich',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ein breites Lächeln, und die Leute, die vorbeigingen, blickten auf,',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'als er mit piepsiger Stimme sagte: »Heute verzeih ich alles, mein',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'lieber Herr, heute kann mich nichts aus der Bahn werfen! Freuen',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wir uns, denn Du-weißt-schon-wer ist endlich von uns gegangen!',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Selbst Muggel wie Sie sollten diesen freudigen, freudigen Tag',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'feiern!«', 'size': 12, 'y_org': 436, 'x_end': 79, 'flags': 4},
#  {'text': 'Und der alte Mann umarmte Mr. Dursley ungefähr in',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Bauchhöhe und ging von dannen.',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 201,
#   'flags': 4},
#  {'text': 'Mr. Dursley stand da wie angewurzelt. Ein völlig Fremder',
#   'size': 12,
#   'y_org': 478,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hatte ihn umarmt. Auch hatte er ihn wohl einen Muggel genannt,',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'was immer das sein mochte. Völlig durcheinander eilte er zu',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'seinem Wagen und fuhr nach Hause. Er hoffte, sich diese Dinge',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nur einzubilden, und das war neu für ihn, denn von',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Einbildungskraft Welt er normalerweise gar nichts.',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 284,
#   'flags': 4},
#  {'text': 'Als er in die Auffahrt von Nummer 4 einbog, fiel sein Blick',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'als Erstes - und das besserte seine Laune nicht gerade - auf die',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'getigerte Katze, die er am Morgen schon gesehen hatte. Sie saß',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Jetzt auf seiner Gartenmauer. Gewiss war es dieselbe Katze; sie',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'hatte dasselbe Muster um die Augen.',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 219,
#   'flags': 4},
#  {'text': '»Schhhh!«, zischte Mr. Dursley laut.',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 237,
#   'flags': 4},
#  {'text': 'Die Katze regte sich nicht. Sie blickte ihn nur aus ernsten',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Augen an. War so etwas denn normal für Katzen, fragte sich Mn',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley. Er versuchte sich zusammenzureißen und öffnete die',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Haustür. Immer noch war er entschlossen, nichts von alledem',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'seiner Frau zu sagen.',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 143,
#   'flags': 4},
#  {'text': 'Mrs. Dursley hatte einen netten, gewöhnlichen Tag hinter',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sich. Beim Abendessen erzählte sie ihm alles über Frau',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Nachbarins Probleme mit deren Tochter und dass Dudley ein',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'neues Wort gelernt hatte (»pfui«). Mr. Dursley versuchte sich',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ganz wie immer zu geben. Er brachte Dudley zu Bett und ging',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dann ins Wohnzimmer, wo er sich das Neueste in den',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Abendnachrichten ansah.',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 161,
#   'flags': 4},
#  {'text': '»Und hier noch eine Meldung. Wie die Vogelkundler im',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ganzen Land berichten, haben sich unsere Eulen heute sehr',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ungewöhnlich verhalten. Obwohl Eulen normalerweise nachts',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Jagen und tagsüber kaum gesichtet werden, wurden diese Vögel',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'seit Sonnenaufgang hunderte Male beobachtet, wie sie kreuz und',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'quer über das Land hinwegflogen. Die Fachleute können sich',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nicht erklären, warum die Eulen plötzlich ihre Gewohnheiten',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'geändert haben.« Der Nachrichtensprecher erlaubte sich ein',
#   'size': 12,
#   'y_org': 478,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Grinsen. »Sehr mys-',
#   'size': 12,
#   'y_org': 492,
#   'x_end': 140,
#   'flags': 4},
#  {'text': 'teriös. Und nun zu Jim McGuffin mit dem Wetter. Sind heute',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Abend noch weitere Eulenschauer zu erwarten, Jim?«',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 298,
#   'flags': 4},
#  {'text': '»Nun, Ted«, meinte der Wetteransager, »das kann ich nicht',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'sagen, aber es sind nicht nur die Eulen, die sich heute seltsam',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'verhalten haben. Zuschauer aus so entfernten Gegenden wie',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Kent, Yorkshire und Dundee haben mich heute angerufen und',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'berichtet, dass anstelle des Regens, den ich gestern versprochen',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hatte, ganze Schauer von Sternschnuppen niedergegangen sind!',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Vielleicht haben die Leute zu früh Silvester gefeiert - das ist noch',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'eine Weile hin, meine Damen und Herren! Aber ich kann Ihnen',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'für heute eine regnerische Nacht versprechen.«',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 266,
#   'flags': 4},
#  {'text': 'Mr. Dursley saß starr wie ein Eiszapfen in seinem Sessel.',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Sternschnuppen über ganz Großbritannien? Eulen, die bei Tage',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'flogen? ', 'size': 12, 'y_org': 238, 'x_end': 81, 'flags': 4},
#  {'text': 'Allerorten ', 'size': 12, 'y_org': 238, 'x_end': 142, 'flags': 4},
#  {'text': 'geheimnisvolle ',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 226,
#   'flags': 4},
#  {'text': 'Leute ', 'size': 12, 'y_org': 238, 'x_end': 266, 'flags': 4},
#  {'text': 'in ', 'size': 12, 'y_org': 238, 'x_end': 288, 'flags': 4},
#  {'text': 'sonderbarer', 'size': 12, 'y_org': 238, 'x_end': 354, 'flags': 4},
#  {'text': 'Kleidung? Und ein Tuscheln, ein Tuscheln über die Potters ...',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 335,
#   'flags': 4},
#  {'text': 'Mrs. Dursley kam mit zwei Tassen Tee ins Wohnzimmer. Es',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hatte keinen Zweck. Er musste ihr etwas sagen. Nervös räusperte',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'er sich. »Ahm - Petunia, Liebes - du hast in letzter Zeit nichts',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'von deiner Schwester gehört, oder?«',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 217,
#   'flags': 4},
#  {'text': 'Wie er befürchtet hatte, blickte ihn Mrs. Dursley entsetzt und',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wütend an. Schließlich taten sie für gewöhnlich so, als hätte sie',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'keine Schwester.',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 123,
#   'flags': 4},
#  {'text': '»Nein«, sagte sie scharf. »Warum?«',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 254,
#   'flags': 4},
#  {'text': '»Komisches Zeug in den Nachrichten«, murmelte Mr.',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley. »Eulen ... Sternschnuppen ... und heute waren eine',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Menge komisch aussehender Leute in der Stadt ...«',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 287,
#   'flags': 4},
#  {'text': '»Und?«, ', 'size': 12, 'y_org': 422, 'x_end': 107, 'flags': 6},
#  {'text': 'fuhr ihn Mrs. Dursley an.',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 227,
#   'flags': 4},
#  {'text': '»Nun, ich dachte nur . .. vielleicht ... hat es etwas zu tun mit',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 353,
#   'flags': 4},
#  {'text': '... du weißt ... ',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 112,
#   'flags': 4},
#  {'text': 'ihrem Klüngel.«',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 190,
#   'flags': 6},
#  {'text': 'Mrs. Dursley nippte mit geschützten Lippen an ihrem Tee.',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Konnte er es wagen, ihr zu sagen, dass er den Namen',
#   'size': 12,
#   'y_org': 478,
#   'x_end': 297,
#   'flags': 4},
#  {'text': '»Potter« gehört hatte? Nein, das konnte er nicht. Stattdessen',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'bemerkte er so beiläufig, wie er nur konnte: »Ihr Sohn - er wäre',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ungefähr in Dudleys Alter, oder?«',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 204,
#   'flags': 4},
#  {'text': '»Ich nehme an«, sagte Mrs. Dursley steif',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 257,
#   'flags': 4},
#  {'text': '»Wie war noch mal sein Name? Howard, nicht wahr?«',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 322,
#   'flags': 4},
#  {'text': '»Harry. Ein hässlicher, gewöhnlicher Name, wenn du mich',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'fragst.«', 'size': 12, 'y_org': 138, 'x_end': 79, 'flags': 4},
#  {'text': '»O Ja, sagte Mr. Dursley, und das Herz rutschte ihm in die',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Hose. »Ja, da bin ich ganz deiner Meinung.«',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 254,
#   'flags': 4},
#  {'text': 'Bis es Zeit zum Schlafen war und sie nach oben gingen,',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'verlor er kein Wort mehr darüber. Während Mrs. Dursley im Bad',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'war, schlich sich Mr. Dursley zum Schlafzimmerfenster und',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'spähte hinunter in den Vorgarten. Die Katze war immer noch da.',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Sie starrte auf den Ligusterweg, als ob sie auf etwas wartete.',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 332,
#   'flags': 4},
#  {'text': 'Bildete er sich das alles nur ein? Konnte all dies etwas mit',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'den Potters zu tun haben? Wenn es so war ... und wenn',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'herauskäme, dass sie verwandt waren mit einem Paar von - nein,',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'das würde er einfach nicht ertragen können.',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 250,
#   'flags': 4},
#  {'text': 'Die Dursleys gingen zu Bett. Mrs. Dursley schlief rasch ein,',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'doch Mr. Dursley lag wach und wälzte alles noch einmal im Kopf',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hin und her. Bevor er einschlief, kam ihm ein letzter, tröstender',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Gedanke. Selbst wenn die Potters wirklich mit dieser Geschichte',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'zu tun hatten, gab es keinen Grund, warum sie bei ihm und Mrs.',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley auftauchen sollten. Die Potters wussten sehr wohl, was',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Petunia von ihnen und ihresgleichen hielt ... Er konnte sich nicht',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'denken, wie er und Petunia in irgendetwas hineingeraten sollten,',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'was dort draußen vor sich ging - er gähnte und drehte sich auf',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'die Seite -. damit würden er und seine Frau Jedenfalls nichts zu',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'tun haben ...', 'size': 12, 'y_org': 450, 'x_end': 101, 'flags': 4},
#  {'text': 'Wie sehr er sich täuschte.',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 184,
#   'flags': 4},
#  {'text': 'Mr. Dursley mochte in einen unruhigen Schlaf hinü-',
#   'size': 12,
#   'y_org': 478,
#   'x_end': 309,
#   'flags': 4},
#  {'text': 'bergeglitten sein, doch die Katze draußen auf der Mauer zeigte',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'keine Spur von Müdigkeit. Sie saß noch immer da wie eine',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Statue, die Augen ohne zu blinzeln auf die weiter entfernte Ecke',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'des Ligusterwegs gerichtet. Kein Härchen regte sich, als eine',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Straße weiter eine Autotür zugeknallt wurde oder als zwei Eulen',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'über ihren Kopf hinwegschwirrten. In der Tat war es fast',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Mitternacht, als die Katze sich zum ersten Mal rührte.',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 299,
#   'flags': 4},
#  {'text': 'An der Ecke, die sie beobachtet hatte, erschien ein Mann, so',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Jäh und lautlos, als wäre er geradewegs aus dem Boden',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'gewachsen. Der Schwanz der Katze zuckte und ihre Augen',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'verengten sich zu Schlitzen.',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 175,
#   'flags': 4},
#  {'text': 'Einen Mann wie diesen hatte man im Ligusterweg noch nie',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'gesehen. Er war groß, dünn und sehr alt, Jedenfalls der silbernen',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Farbe seines Haares und Bartes nach zu schließen, die beide so',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'lang waren, dass sie in seinem Gürtel steckten. Er trug eine lange',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Robe, einen purpurroten Umhang, der den Boden streifte, und',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Schnallenstiefel mit hohen Hacken. Seine blauen Augen',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'leuchteten funkelnd hinter den halbmondförmigen Brillengläsern',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hervor, und seine Nase war sehr lang und krumm, als ob sie',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'mindestens zweimal gebrochen wäre. Der Name dieses Mannes',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'war Albus Dumbledore.',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 156,
#   'flags': 4},
#  {'text': 'Albus Dumbledore schien nicht zu bemerken, dass er soeben',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'in einer Straße aufgetaucht war, in der alles an ihm, von seinem',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Namen bis zu seinen Stiefeln, keineswegs willkommen war.',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Gedankenverloren durchstöberte er die Taschen seines Umhangs.',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Doch offenbar bemerkte er, dass er beobachtet wurde, denn',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'plötzlich sah er zu der Katze hinüber, die ihn vom andern Ende',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'der Straße her immer noch anstarrte. Aus irgendeinem Grunde',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'schien ihn der Anblick der Katze zu belustigen. Er gluckste',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'vergnügt und murmelte: »Ich hätte es wissen müssen.«',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 303,
#   'flags': 4},
#  {'text': 'In seiner Innentasche hatte er gefunden, wonach er suchte.',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Es sah aus wie ein silbernes Feuerzeug. Er ließ den Deckel',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aufschnappen, hielt es hoch in die Luft und ließ es knipsen. Mit',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'einem leisen »Plop« ging eine Straßenlaterne in der Nähe aus. Er',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'knipste noch mal - und die nächste Laterne flackerte und erlosch.',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Zwölfmal knipste er mit dem Ausmacher, bis die einzigen',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Lichter, die in der ganzen Straße noch zu sehen waren, zwei',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'kleine Stecknadelköpfe in der Ferne waren, und das waren die',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Augen der Katze, die ihn beobachtete. Niemand, der Jetzt aus',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dem Fenster geschaut hätte, auch nicht die scharfäugige Mrs.',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursley, hätte nun irgendetwas von dem mitbekommen, was',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'unten auf dem Bürgersteig geschah. Dumbledore ließ den Aus-',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'macher in die Umhangtasche gleiten und machte sich auf den',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Weg die Straße entlang zu Nummer 4, wo er sich auf die Mauer',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'neben die Katze setzte. Er sah sie nicht an, doch nach einer Weile',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'sprach er mit ihr.',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 123,
#   'flags': 4},
#  {'text': '»Was für eine Überraschung, Sie hier zu sehen, Professor',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'McGonagall.«', 'size': 12, 'y_org': 294, 'x_end': 111, 'flags': 4},
#  {'text': 'Mit einem Lächeln wandte er sich zur Seite, doch die',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Tigerkatze war verschwunden. Statt ihrer lächelte er einer',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ziemlich ernst dreinblickenden Frau mit Brille zu, deren Gläser',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'quadratisch waren wie das Muster um die Augen der Katze.',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Auch sie trug einen Umhang, einen smaragdgrünen. Ihr',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'schwarzes ', 'size': 12, 'y_org': 379, 'x_end': 94, 'flags': 4},
#  {'text': 'Haar ', 'size': 12, 'y_org': 379, 'x_end': 132, 'flags': 4},
#  {'text': 'war ', 'size': 12, 'y_org': 379, 'x_end': 164, 'flags': 4},
#  {'text': 'zu ', 'size': 12, 'y_org': 379, 'x_end': 190, 'flags': 4},
#  {'text': 'einem ', 'size': 12, 'y_org': 379, 'x_end': 234, 'flags': 4},
#  {'text': 'festen ', 'size': 12, 'y_org': 379, 'x_end': 277, 'flags': 4},
#  {'text': 'Knoten ', 'size': 12, 'y_org': 379, 'x_end': 327, 'flags': 4},
#  {'text': 'zu-', 'size': 12, 'y_org': 379, 'x_end': 354, 'flags': 4},
#  {'text': 'sammengebunden. Sie sah recht verwirrt aus.',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 257,
#   'flags': 4},
#  {'text': '»Woher wussten Sie, dass ich es war?«, fragte sie.',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 302,
#   'flags': 4},
#  {'text': '»Mein lieber Professor, ich habe noch nie eine Katze so steif',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dasitzen sehen.«',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 120,
#   'flags': 4},
#  {'text': '»Sie wären auch steif, wenn Sie den ganzen Tag auf einer',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Backsteinmauer gesessen hätten«, sagte Professor McGonagall.',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 346,
#   'flags': 4},
#  {'text': '»Den ganzen Tag? Wo Sie doch hätten feiern können?',
#   'size': 12,
#   'y_org': 478,
#   'x_end': 321,
#   'flags': 4},
#  {'text': '»Ich muss auf dem Weg an mindestens einem Dutzend Feste',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'und Partys vorbeigekommen sein.«',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 210,
#   'flags': 4},
#  {'text': 'Verärgert schnaubte Professor McGonagall durch die Nase.',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 347,
#   'flags': 4},
#  {'text': '»O Ja, alle Welt feiert, sehr schön«, sagte sie ungeduldig.',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': '»Man sollte meinen, sie könnten ein bisschen vorsichtiger sein,',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aber nein - selbst die Muggel haben bemerkt, dass etwas los ist.',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Sie haben es in ihren Nachrichten gebracht.« Mit einem',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Kopfrucken deutete sie auf das dunkle Wohnzimmerfenster der',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dursleys. »Ich habe es gehört. Ganze Schwärme von Eulen ...',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Sternschnuppen ... Nun, ganz dumm sind sie auch wieder nicht.',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Sie mussten einfach irgendetwas bemerken. Sternschnuppen',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'unten in Kent - ich wette, das war Dädalus Diggel. Der war noch',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nie besonders vernünftig.«',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 168,
#   'flags': 4},
#  {'text': '»Sie können ihnen keinen Vorwurf machen«, sagte',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dumbledore sanft. »Elf Jahre lang haben wir herzlich wenig zu',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'feiern gehabt.«',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 114,
#   'flags': 4},
#  {'text': '»Das weiß ich«, sagte Professor McGonagall gereizt. »Aber',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'das ist kein Grund, den Kopf zu verlieren. Die Leute sind einfach',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'unvorsichtig, wenn sie sich am helllichten Tage draußen auf den',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Straßen herumtreiben und Gerüchte zum Besten geben.',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Wenigstens könnten sie Muggelsachen anziehen.«',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 280,
#   'flags': 4},
#  {'text': 'Dabei wandte sie sich mit scharfem Blick Dumbledore zu, als',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hoffte sie, er würde ihr etwas mitteilen. Doch er schwieg, und sie',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'fuhr fort: »Das wäre eine schöne Bescherung, wenn',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ausgerechnet an dem Tag, da Du-weißt-schon-wer endlich',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'verschwindet, die Muggel alles über uns herausfinden würden.',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Ich nehme an, er ist wirklich verschwunden, Dumbledore?«',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 325,
#   'flags': 4},
#  {'text': '»Es sieht ganz danach aus«, sagte Dumbledore. »Wir müs-',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sen für vieles dankbar sein. Möchten Sie ein Brausebonbon?«',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 334,
#   'flags': 4},
#  {'text': '»Ein was?«', 'size': 12, 'y_org': 54, 'x_end': 117, 'flags': 4},
#  {'text': '»Ein Zitronenbrausebonbon. Eine Nascherei der Muggel, auf',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'die ich ganz scharf bin.«',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 158,
#   'flags': 4},
#  {'text': '»Nein, danke«, sagte Professor McGonagall kühl, als sei',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Jetzt nicht der richtige Moment für Zitronenbrausebonbons.',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': '»Wie ich schon sagte, selbst wenn Du-weißt-schon-wer wirklich',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'fort ist -«', 'size': 12, 'y_org': 138, 'x_end': 87, 'flags': 4},
#  {'text': '»Mein lieber Professor, eine vernünftige Person wie Sie kann',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ihn doch sicher beim Namen nennen? Der ganze Unsinn mit',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 353,
#   'flags': 4},
#  {'text': '>Du-weißt-schon-wer< - seit elf Jahren versuche ich die Leute',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dazu zu bringen, ihn bei seinem richtigen Namen zu nennen:',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Voldemort.« ', 'size': 12, 'y_org': 209, 'x_end': 105, 'flags': 6},
#  {'text': 'Professor McGonagall zuckte zurück, doch',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dumbledore, der zwei weitere Bonbons aus der Tüte fischte,',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'schien davon keine Notiz zu nehmen. »Es verwirrt doch nur,',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wenn wir dauernd >Du-weißt-schon-wen< sagen. ich habe nie',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'eingesehen, warum ich Angst davor haben sollte, Voldemorts',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Namen auszusprechen.«',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 158,
#   'flags': 4},
#  {'text': '»Das weiß ich wohl«, sagte Professor McGonagall halb',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aufgebracht, halb bewundernd. »Doch Sie sind anders. Alle',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'wissen, dass Sie der Einzige sind, den Du-weißt- ... ahm, na gut,',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Voldemort ', 'size': 12, 'y_org': 337, 'x_end': 96, 'flags': 6},
#  {'text': 'fürchtete.«', 'size': 12, 'y_org': 337, 'x_end': 148, 'flags': 4},
#  {'text': '»Sie schmeicheln mir«, sagte Dumbledore leise. »Voldemort',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hatte Kräfte, die ich nie besitzen werde.«',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 237,
#   'flags': 4},
#  {'text': '»Nur weil Sie zu -ja - nobel sind, um sie einzusetzen.«',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 321,
#   'flags': 4},
#  {'text': '»Ein Glück, dass es dunkel ist. So rot bin ich nicht mehr',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'geworden, seit Madam Pomfrey mir gesagt hat, ihr gefielen',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'meine neuen Ohrenschützer.«',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 184,
#   'flags': 4},
#  {'text': 'Professor McGonagall sah Dumbledore scharf an und sagte:',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': '»Die Eulen sind nichts gegen die ',
#   'size': 12,
# ...
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sich plötzlich wieder daran erinnerte. »Es konnte fliegen.«',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 319,
#   'flags': 4},
#  {'text': 'Onkel Vernon knallte beinahe in den Vordermann. Er drehte',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sich auf seinem Sitz ganz nach hinten um, das Gesicht wie eine',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'riesige Scheibe Rote Bete mit Schnurrbart, und schrie Harry an:',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': '»MOTORRÄDER FLIEGEN NICHT!«',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 235,
#   'flags': 4},
#  {'text': 'Dudley und Piers wieherten.',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 197,
#   'flags': 4},
#  {'text': '»Das weiß ich«, sagte Harry. »Es war Ja nur ein Traum.«',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 336,
#   'flags': 4},
#  {'text': 'Hätte er bloß nichts gesagt, dachte er. Wenn es etwas gab,',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'was die Dursleys noch mehr hassten als seine Fragen, dann',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'waren es seine Geschichten über die Dinge, die sich nicht so',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'verhielten, wie sie sollten, egal ob es nun in einem Traum oder in',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'einem Comic passierte - sie glaubten offenbar, er könnte auf',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'gefährliche Gedanken kommen.',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 193,
#   'flags': 4},
#  {'text': 'Es war ein sehr sonniger Sonnabend und im Zoo drängelten',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sich die Familien. Die Dursleys kauften Dudley und Piers am',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Eingang ein paar große Schoko-Eiskugeln, und weil die Frau im',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Eiswagen Harry mit einem Lächeln fragte, was denn der Junge',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Mann bekomme, kauften sie ihm ein billiges Zitroneneis am Stiel.',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Das war auch nicht schlecht, dachte Harry und lutschte vor sich',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hin, während sie einem Gorilla zuschauten, der sich am Kopf',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'kratzte und der, auch wenn er nicht blond war, Dudley',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'erstaunlich ähnlich sah.',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 152,
#   'flags': 4},
#  {'text': 'Es war Harrys bester Morgen seit langem. Umsichtig ging er',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'ein Stück hinter den Dursleys her, damit Dudley',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 272,
#   'flags': 4},
#  {'text': 'und Piers, die um die Mittagszeit anfingen sich zu langweilen,',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nicht wieder auf ihre Lieblingsbeschäftigung verfielen, nämlich',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Harry zu verhauen. Sie aßen im Zoorestaurant, und als Dudley',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'einen Wutanfall bekam, weil sein Eisbecher Hawaii nicht groß',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'genug war, bestellte ihm Onkel Vernon einen neuen, und Harry',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'durfte den ersten aufessen.',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 169,
#   'flags': 4},
#  {'text': 'Das war des Guten zu viel, und im Nachhinein hatte Harry',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'das Gefühl, er hätte es wissen müssen.',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 225,
#   'flags': 4},
#  {'text': 'Nach dem Mittagessen gingen sie ins Reptilienhaus. Hier',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'drin war es kühl und dunkel und entlang der Wände waren runde',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Sichtfenster eingelassen. Hinter dem Glas krabbelten und glitten',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'alle Arten von Echsen und Schlangen über Äste und Steine.',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dudley und Piers wollten die riesigen, giftigen Kobras und die',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Pythonschlangen sehen, die Menschen zerquetschen konnten.',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Schnell fand Dudley die größte Schlange, die es hier gab. Sie',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'hätte sich zweimal um Onkel Vernons Wagen schlingen und ihn',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'in einen Mülleimer quetschen können - doch offenbar war sie',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'dazu gerade nicht in Stimmung. Tatsächlich döste sie vor sich',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hin.', 'size': 12, 'y_org': 308, 'x_end': 60, 'flags': 4},
#  {'text': 'Dudley hatte die Nase gegen das Fenster gepresst und starrte',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'wie gebannt auf die glänzenden braunen Windungen.',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 293,
#   'flags': 4},
#  {'text': '»Mach, dass sie sich bewegt«, sagte er in quengelndem Ton',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'zu seinem Vater. Onkel Vernon klopfte mit der Faust gegen das',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Glas, doch die Schlange rührte sich nicht.',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 240,
#   'flags': 4},
#  {'text': "»Mach's noch einmal«, befahl Dudley. Onkel Vernon",
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'trommelte behände mit den Knöcheln auf das Glas, doch die',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Schlange schnarchte einfach weiter.',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 212,
#   'flags': 4},
#  {'text': '»Wie langweilig«, klagte Dudley und schlurfte davon.',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 318,
#   'flags': 4},
#  {'text': 'Harry trat vor die Scheibe und ließ den Blick auf der',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Schlange ruhen. Es hätte ihn nicht überrascht, wenn auch',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 314,
#   'flags': 4},
#  {'text': 'sie vor Langeweile gestorben wäre - keine Gesellschaft außer',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'doofen Leuten, die mit den Fingern gegen das Glas trommelten',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'und sie den ganzen Tag lang störten. Das war schlimmer, als',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'einen Schrank als Zimmer zu haben, wo der einzige Besucher',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Tante Petunia war, die an die Tür hämmerte, um einen',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'aufzuwecken. Doch zumindest bekam er den Rest des Hauses zu',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sehen.', 'size': 12, 'y_org': 138, 'x_end': 72, 'flags': 4},
#  {'text': 'Die Schlange öffnete plötzlich ihre kleinen Perlaugen.',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Langsam, ganz allmählich, hob sie den Kopf bis ihre Augen auf',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'einer Höhe mit denen Harrys waren.',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 215,
#   'flags': 4},
#  {'text': 'Sie zwinkerte.',
#   'size': 12,
#   'y_org': 195,
#   'x_end': 128,
#   'flags': 6},
#  {'text': 'Harry starrte sie an. Rasch blickte er über die Schulter, ob',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Jemand zusah. Niemand. Er drehte sich wieder zu der Schlange',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'um und zwinkerte zurück.',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 167,
#   'flags': 4},
#  {'text': 'Die Schlange stieß mit dem Kopf in Richtung Onkel Vernon',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'und Dudley und rollte die Augen nach oben. Sie sah Harry mit',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'einem Blick an, der eindeutig sagte:',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 213,
#   'flags': 4},
#  {'text': '»So was muss ich den ganzen Tag ertragen.«',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 279,
#   'flags': 6},
#  {'text': '»Ich weiß«, murmelte Harry durch das Glas, wenn er auch',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'nicht sicher war, ob die Schlange ihn hören konnte. »Das muss',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'dich wirklich auf die Palme bringen.«',
#   'size': 12,
#   'y_org': 337,
#   'x_end': 220,
#   'flags': 4},
#  {'text': 'Die Schlange nickte lebhaft.',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 196,
#   'flags': 4},
#  {'text': '»Weber kommst du eigentlich?«, fragte Harry.',
#   'size': 12,
#   'y_org': 365,
#   'x_end': 284,
#   'flags': 4},
#  {'text': 'Die Schlange stieß mit ihrem Schwanz gegen ein kleines',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Schild nahe dem Fenster. Harry spähte auf die Inschrift.',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 308,
#   'flags': 4},
#  {'text': 'Boa constrictor, Brasilien.',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 191,
#   'flags': 6},
#  {'text': '»War es schön dort?«',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 166,
#   'flags': 4},
#  {'text': 'Wieder stieß die Schlange mit dem Schwanz gegen das',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Schild, und Harry las weiter: ',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 191,
#   'flags': 4},
#  {'text': 'Dieses Exemplar wurde im Zoo',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 6},
#  {'text': 'ausgebrütet »Oh, ',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 129,
#   'flags': 6},
#  {'text': 'ich verstehe, du warst nie in Brasilien?«',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 317,
#   'flags': 4},
#  {'text': 'Die Schlange schüttelte den Kopf, und plötzlich erschallte',
#   'size': 12,
#   'y_org': 478,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'hinter Harry ein ohrenbetäubendes Rufen, das sie beide',
#   'size': 12,
#   'y_org': 492,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'zusammenzucken ließ: »DUDLEY! MR. DURS-',
#   'size': 12,
#   'y_org': 507,
#   'x_end': 275,
#   'flags': 4},
#  {'text': 'LEY! KOMMT UND SEHT EUCH DIESE SCHLANGE AM',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'DAS ', 'size': 12, 'y_org': 68, 'x_end': 69, 'flags': 4},
#  {'text': 'GLAUBT ', 'size': 12, 'y_org': 68, 'x_end': 118, 'flags': 6},
#  {'text': 'IHR NICHT, WAS DIE TUT!«',
#   'size': 12,
#   'y_org': 68,
#   'x_end': 270,
#   'flags': 4},
#  {'text': 'Dudley kam, so schnell er konnte, auf sie zugewatschelt.',
#   'size': 12,
#   'y_org': 82,
#   'x_end': 332,
#   'flags': 4},
#  {'text': '»Aus dem Weg, Mann«, sagte er und stieß Harry in die',
#   'size': 12,
#   'y_org': 96,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Rippen. Harry, von dem Schlag ganz überrascht, fiel hart auf den',
#   'size': 12,
#   'y_org': 110,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Betonboden. Was nun kam, passierte so schnell, dass niemand',
#   'size': 12,
#   'y_org': 124,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'sah, wie es geschah: Einen Moment lang drückten sich Piers und',
#   'size': 12,
#   'y_org': 138,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Dudley ganz dicht gegen das Glas und im nächsten Moment',
#   'size': 12,
#   'y_org': 153,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'sprangen sie unter Schreckgeheule zurück.',
#   'size': 12,
#   'y_org': 167,
#   'x_end': 246,
#   'flags': 4},
#  {'text': 'Harry setzte sich auf und nun stockte ihm der Atem. Die',
#   'size': 12,
#   'y_org': 181,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'Glasscheibe ', 'size': 12, 'y_org': 195, 'x_end': 103, 'flags': 4},
#  {'text': 'am ', 'size': 12, 'y_org': 195, 'x_end': 132, 'flags': 4},
#  {'text': 'Terrarium ', 'size': 12, 'y_org': 195, 'x_end': 195, 'flags': 4},
#  {'text': 'der ', 'size': 12, 'y_org': 195, 'x_end': 225, 'flags': 4},
#  {'text': 'Boa ', 'size': 12, 'y_org': 195, 'x_end': 259, 'flags': 4},
#  {'text': 'constrictor ', 'size': 12, 'y_org': 195, 'x_end': 324, 'flags': 4},
#  {'text': 'war', 'size': 12, 'y_org': 195, 'x_end': 354, 'flags': 4},
#  {'text': 'verschwunden. Die große Schlange entrollte sich im Nu und',
#   'size': 12,
#   'y_org': 209,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'schlängelte sich heraus auf den Boden. - Im ganzen Reptilienhaus',
#   'size': 12,
#   'y_org': 223,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'schrien die Menschen und rannten zu den Ausgängen.',
#   'size': 12,
#   'y_org': 238,
#   'x_end': 298,
#   'flags': 4},
#  {'text': 'Als die Schlange an Harry vorbeiglitt, hätte er schwören',
#   'size': 12,
#   'y_org': 252,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'können, dass eine leise, zischelnde Stimme sagte: »Brasilien, ich',
#   'size': 12,
#   'y_org': 266,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'komme . .. tschüsss, Amigo.«',
#   'size': 12,
#   'y_org': 280,
#   'x_end': 183,
#   'flags': 4},
#  {'text': 'Der Obertierpfleger des Reptilienhauses stand unter Schock.',
#   'size': 12,
#   'y_org': 294,
#   'x_end': 350,
#   'flags': 4},
#  {'text': '»Aber das Glas«, murmelte er ständig vor sich hin, »was ist',
#   'size': 12,
#   'y_org': 308,
#   'x_end': 353,
#   'flags': 4},
#  {'text': 'aus dem Glas geworden?«',
#   'size': 12,
#   'y_org': 323,
#   'x_end': 167,
#   'flags': 4},
#  {'text': 'Der Zoodirektor persönlich brühte Tante Petunia eine Tasse',
#   'size': 12,
#   'y_org': 351,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'starken, ', 'size': 12, 'y_org': 365, 'x_end': 82, 'flags': 4},
#  {'text': 'süßen ', 'size': 12, 'y_org': 365, 'x_end': 123, 'flags': 4},
#  {'text': 'Tee ', 'size': 12, 'y_org': 365, 'x_end': 155, 'flags': 4},
#  {'text': 'und ', 'size': 12, 'y_org': 365, 'x_end': 186, 'flags': 4},
#  {'text': 'überschlug ', 'size': 12, 'y_org': 365, 'x_end': 251, 'flags': 4},
#  {'text': 'sich ', 'size': 12, 'y_org': 365, 'x_end': 284, 'flags': 4},
#  {'text': 'mit ', 'size': 12, 'y_org': 365, 'x_end': 313, 'flags': 4},
#  {'text': 'seinen', 'size': 12, 'y_org': 365, 'x_end': 354, 'flags': 4},
#  {'text': 'Entschuldigungen. Piers und Dudley schnatterten nur noch.',
#   'size': 12,
#   'y_org': 379,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Soweit Harry es gesehen hatte, hatte die Schlange nichts getan,',
#   'size': 12,
#   'y_org': 393,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'außer im vorbeigleiten spielerisch gegen ihre Fersen zu',
#   'size': 12,
#   'y_org': 408,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'schlenzen, doch als sie alle wieder in Onkel Vernons Wagen',
#   'size': 12,
#   'y_org': 422,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'saßen, erzählte ihnen Dudley, die Schlange hätte ihm fast das',
#   'size': 12,
#   'y_org': 436,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'Bein abgebissen, während Piers schwor, sie hätte versucht, ihn',
#   'size': 12,
#   'y_org': 450,
#   'x_end': 354,
#   'flags': 4},
#  {'text': 'totzuquetschen. Doch am schlimmsten',
#   'size': 12,
#   'y_org': 464,
#   'x_end': 226,
#   'flags': 4},
#  {'text': 'für Harry war, dass Piers, als er sich ein wenig beruhigt hatte,',
#   'size': 12,
#   'y_org': 54,
#   'x_end': 354,
#   'flags': 4},
#  ...]

# %%
def same(a, b, uncertainty):
    return a <= b + uncertainty and a >= b - uncertainty

# %%
def group_spans_in_lines(spans):
    lines = []
    current_line_y = spans[0]['y_org']
    current_span_list = []
    for span in spans:
        if same(span['y_org'], current_line_y, UNCERTAINTY_LINE_HEIGTH):
            current_span_list.append(span)
        else:
            lines.append(current_span_list)
            current_line_y = span['y_org']
            current_span_list = [span]
    lines.append(current_span_list)
    return lines

# %%
lines = group_spans_in_lines(spans)
lines
# Out:
# [[{'text': 'Dudley umnachtet ',
#    'size': 20,
#    'y_org': 72,
#    'x_end': 297,
#    'flags': 20}],
#  [{'text': 'Der bislang heißeste Tag des Sommers neigte sich dem Ende zu ',
#    'size': 11,
#    'y_org': 105,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und eine schläfrige Stille lag über den großen wuchtigen Häusern des ',
#    'size': 11,
#    'y_org': 118,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Ligusterwegs. Autos, die normalerweise glänzten, standen staubig in ',
#    'size': 11,
#    'y_org': 130,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'den Einfahrten, und Rasenflächen, die einst smaragdgrün waren, lagen ',
#    'size': 11,
#    'y_org': 142,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'verdorrt und gelbstichig da – wegen der Dürre war es verboten ',
#    'size': 11,
#    'y_org': 155,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'worden, sie mit Gartenschläuchen zu wässern. Die Bewohner des ',
#    'size': 11,
#    'y_org': 168,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Ligusterwegs, die sich nun nicht mehr wie üblich mit Autowaschen ',
#    'size': 11,
#    'y_org': 180,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und Rasenmähen die Zeit vertreiben konnten, hatten sich in die ',
#    'size': 11,
#    'y_org': 193,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Schatten ihrer kühlen Häuser zurückgezogen und die Fenster weit ',
#    'size': 11,
#    'y_org': 206,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'aufgestoßen ', 'size': 11, 'y_org': 219, 'x_end': 113, 'flags': 4},
#   {'text': 'in ', 'size': 11, 'y_org': 219, 'x_end': 137, 'flags': 4},
#   {'text': 'der ', 'size': 11, 'y_org': 219, 'x_end': 166, 'flags': 4},
#   {'text': 'Hoffnung, ', 'size': 11, 'y_org': 219, 'x_end': 226, 'flags': 4},
#   {'text': 'eine ', 'size': 11, 'y_org': 219, 'x_end': 259, 'flags': 4},
#   {'text': 'vermeintliche ',
#    'size': 11,
#    'y_org': 219,
#    'x_end': 334,
#    'flags': 4},
#   {'text': 'Brise ', 'size': 11, 'y_org': 219, 'x_end': 372, 'flags': 4}],
#  [{'text': 'hereinzulocken. Der einzige Mensch, der noch draußen war, ein ',
#    'size': 11,
#    'y_org': 231,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Teenager, lag in einem Blumenbeet vor Nummer vier flach auf dem ',
#    'size': 11,
#    'y_org': 244,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Rücken. ', 'size': 11, 'y_org': 256, 'x_end': 97, 'flags': 4}],
#  [{'text': 'Es war ein schlaksiger, schwarzhaariger Junge mit Brille, der ',
#    'size': 11,
#    'y_org': 275,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'ausgezehrt und leicht ungesund wirkte wie jemand, der in kurzer Zeit ',
#    'size': 11,
#    'y_org': 288,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'recht schnell gewachsen war. Seine Jeans war dreckig und zerrissen, ',
#    'size': 11,
#    'y_org': 300,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'sein T-Shirt ausgeleiert und verblichen, und die Sohlen seiner ',
#    'size': 11,
#    'y_org': 313,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Turnschuhe schälten sich vom Oberleder. Harry Potters Äußeres ',
#    'size': 11,
#    'y_org': 326,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'machte ihn nicht lieb Kind bei den Nachbarn, jener Sorte von ',
#    'size': 11,
#    'y_org': 338,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Menschen, die meinten, Schmuddeligkeit gehöre gesetzlich bestraft, ',
#    'size': 11,
#    'y_org': 351,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'doch da er sich an diesem Abend hinter einem großen ',
#    'size': 11,
#    'y_org': 364,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Hortensienbusch versteckt hatte, war er für Passanten gänzlich ',
#    'size': 11,
#    'y_org': 376,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'unsichtbar. Tatsächlich konnten ihn nur Onkel Vernon und Tante ',
#    'size': 11,
#    'y_org': 389,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Petunia sehen, falls sie die Köpfe aus dem Wohnzimmerfenster ',
#    'size': 11,
#    'y_org': 402,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'streckten und senkrecht nach unten ins Blumenbeet schauten. ',
#    'size': 11,
#    'y_org': 414,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': 'Alles in allem, dachte Harry, konnte man ihm zu seiner Idee, sich ',
#    'size': 11,
#    'y_org': 432,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hier zu verstecken, nur gratulieren. Vielleicht war es nicht sonderlich ',
#    'size': 11,
#    'y_org': 445,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'bequem, wie er da auf der heißen, harten Erde lag, doch immerhin ',
#    'size': 11,
#    'y_org': 458,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'stierte ihn niemand finster an und knirschte so laut mit den Zähnen, ',
#    'size': 11,
#    'y_org': 471,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dass er die Nachrichten nicht hören konnte, oder warf ihm gehässige ',
#    'size': 11,
#    'y_org': 484,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Fragen an den Kopf, wie es noch jedes Mal geschehen war, wenn er ',
#    'size': 11,
#    'y_org': 496,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'versucht hatte, sich ins Wohnzimmer zu setzen und mit Tante und ',
#    'size': 11,
#    'y_org': 509,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Onkel fernzusehen. ',
#    'size': 11,
#    'y_org': 521,
#    'x_end': 145,
#    'flags': 4}],
#  [{'text': 'Als wäre Harrys Gedanke durchs offene Fenster geflattert, fing ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Vernon Dursley, sein Onkel, plötzlich an zu reden. ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 283,
#    'flags': 4}],
#  [{'text': '»Bin froh, dass der Bursche nicht mehr versucht, sich hier breit zu ',
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'machen. Übrigens, wo steckt er eigentlich?« ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 256,
#    'flags': 4}],
#  [{'text': '»Ich weiß es nicht«, sagte Tante Petunia beiläufig. »Nicht im Haus ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'jedenfalls.« ',
#    'size': 11,
#    'y_org': 138,
#    'x_end': 111,
#    'flags': 4}],
#  [{'text': 'Onkel Vernon grunzte. ',
#    'size': 11,
#    'y_org': 157,
#    'x_end': 175,
#    'flags': 4}],
#  [{'text': '»Die Nachrichten gucken …«, höhnte er. »Möchte wissen, was er ',
#    'size': 11,
#    'y_org': 176,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wirklich im Schilde führt. Ein normaler Junge pfeift doch drauf, was ',
#    'size': 11,
#    'y_org': 189,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'in den Nachrichten kommt – Dudley hat keine Ahnung, was in der ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Welt passiert. Bin mir nicht mal sicher, ob er weiß, wer der ',
#    'size': 11,
#    'y_org': 214,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': "Premierminister ist! Jedenfalls sieht's nicht so aus, als käme irgendwas ",
#    'size': 11,
#    'y_org': 227,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'über seine Sippschaft in unseren Nachrichten …« ',
#    'size': 11,
#    'y_org': 240,
#    'x_end': 279,
#    'flags': 4}],
#  [{'text': '»Vernon, ', 'size': 11, 'y_org': 258, 'x_end': 115, 'flags': 4},
#   {'text': 'schhh!«, ', 'size': 11, 'y_org': 258, 'x_end': 156, 'flags': 6},
#   {'text': 'sagte Tante Petunia. »Das Fenster steht offen!« ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 367,
#    'flags': 4}],
#  [{'text': '»Oh – ja – Verzeihung, Liebling.« ',
#    'size': 11,
#    'y_org': 276,
#    'x_end': 226,
#    'flags': 4}],
#  [{'text': 'Die Dursleys verstummten. Harry lauschte einem Werbesong für ',
#    'size': 11,
#    'y_org': 295,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Obst-und-Kleie-Frühstücksflocken, während er Mrs. Figg, eine ',
#    'size': 11,
#    'y_org': 308,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'schrullige alte Dame aus dem nahen Glyzinenweg, langsam ',
#    'size': 11,
#    'y_org': 321,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'vorbeitappen sah. Sie blickte finster drein und murmelte vor sich hin. ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Harry war sehr froh, dass er hinter dem Busch versteckt lag, weil Mrs. ',
#    'size': 11,
#    'y_org': 346,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Figg ihn seit kurzem jedes Mal wenn sie ihn auf der Straße traf, zu ',
#    'size': 11,
#    'y_org': 358,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sich nach Hause zum Tee einlud. Sie war um die Ecke gebogen und ',
#    'size': 11,
#    'y_org': 371,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'verschwunden, als Onkel Vernons Stimme erneut aus dem Fenster ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'schwebte. ', 'size': 11, 'y_org': 396, 'x_end': 104, 'flags': 4}],
#  [{'text': '»Duddy ist zum Tee eingeladen?« ',
#    'size': 11,
#    'y_org': 415,
#    'x_end': 225,
#    'flags': 4}],
#  [{'text': '»Bei den Polkissens«, sagte Tante Petunia liebevoll. »Er hat so ',
#    'size': 11,
#    'y_org': 434,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'viele kleine Freunde, beliebt, wie er ist …« ',
#    'size': 11,
#    'y_org': 447,
#    'x_end': 251,
#    'flags': 4}],
#  [{'text': 'Mit Mühe verkniff sich Harry ein Schnauben. Die Dursleys waren ',
#    'size': 11,
#    'y_org': 465,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'wirklich erstaunlich dumm, wenn es um ihren Sohn Dudley ging. All ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'seine fadenscheinigen Lügen, er wäre jeden Abend der Sommerferien ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'bei einem anderen Typen aus seiner Gang zum Tee, hatten sie ',
#    'size': 11,
#    'y_org': 503,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'geschluckt. Harry wusste genau, dass Dudley nirgends zum Tee war; ',
#    'size': 11,
#    'y_org': 516,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'er und seine Gang verbrachten jeden Abend damit, den Spielplatz im ',
#    'size': 11,
#    'y_org': 528,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Park zu demolieren, an Straßenecken zu rauchen und Steine auf ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'vorbeikommende Autos und Kinder zu werfen. Harry hatte sie ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'während seiner abendlichen Streifzüge durch Little Whinging dabei ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'beobachtet; er hatte den größten Teil der Ferien damit verbracht, durch ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'die Straßen zu ziehen und unterwegs Zeitungen aus den Mülleimern ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'zu klauben. ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 110,
#    'flags': 4}],
#  [{'text': 'Als die ersten Töne der Melodie für die Sieben-Uhr-Nachrichten ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'an Harrys Ohr drangen, drehte sich ihm der Magen um. Vielleicht ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'heute Abend – nachdem er einen Monat gewartet hatte –, vielleicht ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'war es heute so weit. ',
#    'size': 11,
#    'y_org': 184,
#    'x_end': 152,
#    'flags': 4}],
#  [{'text': '»Während der Streik der spanischen Gepäckabfertiger in die ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'zweite Woche geht, sitzen so viele Urlauber wie noch nie auf den ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 369,
#    'flags': 6}],
#  [{'text': 'Flughäfen fest …« ',
#    'size': 11,
#    'y_org': 228,
#    'x_end': 142,
#    'flags': 6}],
#  [{'text': '»Denen würde ich eine lebenslange Siesta verpassen, wenn du ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'mich fragst«, knurrte Onkel Vernon, kaum dass der Sprecher den Satz ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'vollendet hatte, und doch: Draußen im Blumenbeet schien sich Harrys ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Magen wieder zu entspannen. Wenn irgendetwas passiert wäre, dann ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hätten sie es sicher als Erstes in den Nachrichten gebracht; Tod und ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Zerstörung waren wichtiger als gestrandete Urlauber. ',
#    'size': 11,
#    'y_org': 310,
#    'x_end': 295,
#    'flags': 4}],
#  [{'text': 'Er atmete lange und ruhig aus und blickte in den strahlend blauen ',
#    'size': 11,
#    'y_org': 328,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Himmel. Diesen Sommer war es Tag für Tag das Gleiche gewesen: ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'die Spannung, die Erwartung, die zeitweilige Erleichterung und dann ',
#    'size': 11,
#    'y_org': 353,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'erneut die wachsende Spannung … und stets drängender die Frage, ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'warum ', 'size': 11, 'y_org': 378, 'x_end': 91, 'flags': 6},
#   {'text': 'noch nichts passiert war. ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 203,
#    'flags': 4}],
#  [{'text': 'Er lauschte weiter, nur für den Fall, dass es einen kleinen Hinweis ',
#    'size': 11,
#    'y_org': 397,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'gab, dessen ganze Bedeutung den Muggeln entging – ein rätselhaftes ',
#    'size': 11,
#    'y_org': 410,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Verschwinden vielleicht, oder ein merkwürdiger Unfall … aber dem ',
#    'size': 11,
#    'y_org': 423,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Streik der Gepäckabfertiger folgte eine Meldung über die Dürre im ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Südosten Englands (»Hoffentlich hört der nebenan zu!«, bellte Onkel ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Vernon. »Der mit seinen Sprinklern, die er um drei Uhr morgens ',
#    'size': 11,
#    'y_org': 460,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'anstellt!«), dann über einen Hubschrauber, der beinahe über einem ',
#    'size': 11,
#    'y_org': 473,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Feld in Surrey abgestürzt war, schließlich über die Scheidung einer ',
#    'size': 11,
#    'y_org': 486,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'prominenten Schauspielerin von ihrem prominenten Mann (»Als ob ',
#    'size': 11,
#    'y_org': 498,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'wir an deren schmutzigen Affären interessiert wären«, naserümpfte ',
#    'size': 11,
#    'y_org': 511,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Tante Petunia, die diesen Fall in jeder Illustrierten, die ihr unter die ',
#    'size': 11,
#    'y_org': 524,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'knochigen Finger kam, gebannt verfolgte). ',
#    'size': 11,
#    'y_org': 536,
#    'x_end': 248,
#    'flags': 4}],
#  [{'text': 'Harry schloss die Augen vor dem jetzt flammenden Abendhimmel, ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'während der Sprecher sagte: ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 197,
#    'flags': 4},
#   {'text': '»— und schließlich hat Wally der ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'Wellensittich sich etwas Neues einfallen lassen, wie er sich diesen ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 369,
#    'flags': 6}],
#  [{'text': 'Sommer abkühlen kann. Wally, der auf den Five Feathers in Barnsley ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'lebt, hat Wasserski gelernt! Mary Dorkins hat sich dort für Sie ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'umgeschaut.« ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 121,
#    'flags': 6}],
#  [{'text': 'Harry öffnete die Augen. Wenn sie schon bei Wasserski fahrenden ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Wellensittichen waren, würde nichts Hörenswertes mehr kommen. Er ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'drehte sich vorsichtig auf den Bauch und stemmte sich auf Knie und ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Ellbogen, um unter dem Fenster wegzukriechen. ',
#    'size': 11,
#    'y_org': 184,
#    'x_end': 274,
#    'flags': 4}],
#  [{'text': 'Er hatte sich gerade mal fünf Zentimeter bewegt, als mehrere ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Dinge in sehr rascher Folge passierten. ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 232,
#    'flags': 4}],
#  [{'text': 'Ein lauter, widerhallender ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 189,
#    'flags': 4},
#   {'text': 'Knall ', 'size': 11, 'y_org': 234, 'x_end': 217, 'flags': 6},
#   {'text': 'zerriss die schläfrige Stille wie ein ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Pistolenschuss; eine Katze sauste unter einem geparkten Wagen ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'hervor und stob davon; ein spitzer Schrei, ein gellender Fluch und das ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Geräusch ', 'size': 11, 'y_org': 271, 'x_end': 101, 'flags': 4},
#   {'text': 'von ', 'size': 11, 'y_org': 271, 'x_end': 131, 'flags': 4},
#   {'text': 'zerbrechendem ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 210,
#    'flags': 4},
#   {'text': 'Porzellan ', 'size': 11, 'y_org': 271, 'x_end': 265, 'flags': 4},
#   {'text': 'drangen ', 'size': 11, 'y_org': 271, 'x_end': 313, 'flags': 4},
#   {'text': 'aus ', 'size': 11, 'y_org': 271, 'x_end': 340, 'flags': 4},
#   {'text': 'dem ', 'size': 11, 'y_org': 271, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Wohnzimmer der Dursleys. Als sei dies das Signal, auf das Harry ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'gewartet hatte, schnellte er hoch und zog einen dünnen hölzernen ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Zauberstab aus seinem Jeansbund wie ein Schwert aus der Scheide – ',
#    'size': 11,
#    'y_org': 310,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'doch bevor er sich ganz aufrichten konnte, krachte er mit der ',
#    'size': 11,
#    'y_org': 322,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Schädeldecke gegen das offene Fenster der Dursleys. Es ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 316,
#    'flags': 4},
#   {'text': 'rumste ', 'size': 11, 'y_org': 334, 'x_end': 352, 'flags': 6},
#   {'text': 'und ', 'size': 11, 'y_org': 334, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Tante Petunia kreischte noch lauter. ',
#    'size': 11,
#    'y_org': 347,
#    'x_end': 218,
#    'flags': 4}],
#  [{'text': 'Harry hatte das Gefühl, als wäre sein Kopf entzweigespalten. ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Schwankend, mit tränenden Augen, versuchte er den Blick auf die ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Straße zu richten, um die Quelle des Lärms auszumachen, doch kaum ',
#    'size': 11,
#    'y_org': 391,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'hatte er sich stolpernd erhoben, langten zwei große, purpurrote Hände ',
#    'size': 11,
#    'y_org': 404,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'durchs offene Fenster und schlossen sich fest um seine Kehle. ',
#    'size': 11,
#    'y_org': 417,
#    'x_end': 333,
#    'flags': 4}],
#  [{'text': '»Tu – das – Ding – weg!«, ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 195,
#    'flags': 6},
#   {'text': 'schnarrte Onkel Vernon in Harrys Ohr. ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '»Sofort! Bevor – es – jemand – sieht!« ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 230,
#    'flags': 6}],
#  [{'text': '»Lass – mich – los!«, keuchte Harry. Einige Sekunden lang rangen ',
#    'size': 11,
#    'y_org': 466,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'sie miteinander. Harry, der mit der rechten Hand den erhobenen ',
#    'size': 11,
#    'y_org': 479,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Zauberstab fest umklammerte, zog mit der linken an den Wurstfingern ',
#    'size': 11,
#    'y_org': 492,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'seines Onkels; dann, in dem Moment, als der Schmerz an Harrys ',
#    'size': 11,
#    'y_org': 504,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Schädeldecke besonders fies pochte, japste Onkel Vernon plötzlich ',
#    'size': 11,
#    'y_org': 517,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und ließ Harry los, als ob er einen elektrischen Schlag bekommen ',
#    'size': 11,
#    'y_org': 530,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hätte. Eine unsichtbare Kraft schien durch seinen Neffen pulsiert zu ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sein, so dass er ihn unmöglich weiter festhalten konnte. ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 304,
#    'flags': 4}],
#  [{'text': 'Keuchend fiel Harry bäuchlings über den Hortensienbusch, richtete ',
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'sich auf und spähte umher. Was den lauten Knall verursacht haben ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'könnte, war nicht im Entferntesten zu erkennen, aber inzwischen ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'lugten Gesichter aus einigen Fenstern in der Nachbarschaft. Harry ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'steckte hastig seinen Zauberstab in die Jeans und versuchte, eine ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Unschuldsmiene aufzusetzen. ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 190,
#    'flags': 4}],
#  [{'text': '»Wunderbarer Abend!«, rief Onkel Vernon und winkte Mrs. ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Nummer sieben von gegenüber zu, die durch ihre Netzvorhänge böse ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'herüberfunkelte. »Haben Sie eben diesen Auspuffknall gehört? Hat ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Petunia und mir einen schönen Schreck eingejagt!« ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 286,
#    'flags': 4}],
#  [{'text': 'Er grinste unentwegt auf schreckliche, besessene Art umher, bis all ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'die neugierigen Nachbarn von ihren Fenstern verschwunden waren, ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'dann winkte er Harry zu sich heran, und aus dem Grinsen wurde eine ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'wutentbrannte Grimasse. ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 171,
#    'flags': 4}],
#  [{'text': 'Harry trat ein paar Schritte näher und achtete darauf, kurz vor dem ',
#    'size': 11,
#    'y_org': 290,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Punkt Halt zu machen, an dem Onkel Vernons ausgestreckte Hände ',
#    'size': 11,
#    'y_org': 303,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'ihn wieder würgen konnten. ',
#    'size': 11,
#    'y_org': 316,
#    'x_end': 184,
#    'flags': 4}],
#  [{'text': '»Was zum Teufel soll das, Bursche?«, fragte Onkel Vernon mit ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'heiserer, vor Wut zitternder Stimme. ',
#    'size': 11,
#    'y_org': 346,
#    'x_end': 221,
#    'flags': 4}],
#  [{'text': '»Was soll was?«, sagte Harry kühl. Er blickte unablässig links und ',
#    'size': 11,
#    'y_org': 365,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'rechts ', 'size': 11, 'y_org': 378, 'x_end': 86, 'flags': 4},
#   {'text': 'die ', 'size': 11, 'y_org': 378, 'x_end': 111, 'flags': 4},
#   {'text': 'Straße ', 'size': 11, 'y_org': 378, 'x_end': 151, 'flags': 4},
#   {'text': 'entlang, ', 'size': 11, 'y_org': 378, 'x_end': 197, 'flags': 4},
#   {'text': 'immer ', 'size': 11, 'y_org': 378, 'x_end': 238, 'flags': 4},
#   {'text': 'noch ', 'size': 11, 'y_org': 378, 'x_end': 271, 'flags': 4},
#   {'text': 'in ', 'size': 11, 'y_org': 378, 'x_end': 292, 'flags': 4},
#   {'text': 'der ', 'size': 11, 'y_org': 378, 'x_end': 317, 'flags': 4},
#   {'text': 'Hoffnung ', 'size': 11, 'y_org': 378, 'x_end': 372, 'flags': 4}],
#  [{'text': 'herauszufinden, von wem der Knall stammte. ',
#    'size': 11,
#    'y_org': 390,
#    'x_end': 260,
#    'flags': 4}],
#  [{'text': '»Einen Lärm machen, als ginge eine Pistole los, und das direkt vor ',
#    'size': 11,
#    'y_org': 409,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'unserem …« ', 'size': 11, 'y_org': 422, 'x_end': 117, 'flags': 4}],
#  [{'text': '»Den Lärm hab ich nicht gemacht«, sagte Harry entschieden. ',
#    'size': 11,
#    'y_org': 441,
#    'x_end': 344,
#    'flags': 4}],
#  [{'text': 'Neben Onkel Vernons breitem, puterrotem Gesicht tauchte jetzt ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Tante Petunias schmales Pferdegesicht auf. Sie war aschgrau. ',
#    'size': 11,
#    'y_org': 472,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': '»Warum hast du unter unserem Fenster herumgelungert?« ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': '»Ja – ja, gute Frage, Petunia! Was hast du unter unserem ',
#    'size': 11,
#    'y_org': 509,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Fenstergetrieben, Bursche?« ',
#    'size': 11,
#    'y_org': 522,
#    'x_end': 186,
#    'flags': 4}],
#  [{'text': '»Die Nachrichten gehört«, sagte Harry mit resignierter Stimme. ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 355,
#    'flags': 4}],
#  [{'text': 'Tante und Onkel tauschten empörte Blicke. ',
#    'size': 11,
#    'y_org': 82,
#    'x_end': 265,
#    'flags': 4}],
#  [{'text': '»Die Nachrichten gehört! ',
#    'size': 11,
#    'y_org': 101,
#    'x_end': 187,
#    'flags': 4},
#   {'text': 'Schon wieder', 'size': 11, 'y_org': 101, 'x_end': 247, 'flags': 6},
#   {'text': '?« ', 'size': 11, 'y_org': 101, 'x_end': 260, 'flags': 4}],
#  [{'text': '»Na ja, es gibt doch jeden Tag neue, oder?«, sagte Harry. ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 328,
#    'flags': 4}],
#  [{'text': '»Spiel mir hier nicht den Neunmalklugen, Bursche! Ich will ',
#    'size': 11,
#    'y_org': 138,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'wissen, was du wirklich im Schilde führst – und hör mir bloß auf mit ',
#    'size': 11,
#    'y_org': 150,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'diesem Quatsch von wegen ',
#    'size': 11,
#    'y_org': 163,
#    'x_end': 182,
#    'flags': 4},
#   {'text': 'die Nachrichten hören',
#    'size': 11,
#    'y_org': 163,
#    'x_end': 287,
#    'flags': 6},
#   {'text': '! Du weißt genau, ',
#    'size': 11,
#    'y_org': 163,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dass ', 'size': 11, 'y_org': 176, 'x_end': 79, 'flags': 4},
#   {'text': 'deine Sippschaft ',
#    'size': 11,
#    'y_org': 176,
#    'x_end': 154,
#    'flags': 6},
#   {'text': '…« ', 'size': 11, 'y_org': 176, 'x_end': 174, 'flags': 4}],
#  [{'text': '»Vorsicht, Vernon!«, hauchte Tante Petunia, und Onkel Vernon ',
#    'size': 11,
#    'y_org': 195,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'senkte die Stimme, bis Harry ihn kaum noch hören konnte – »dass ',
#    'size': 11,
#    'y_org': 208,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'deine Sippschaft ',
#    'size': 11,
#    'y_org': 220,
#    'x_end': 132,
#    'flags': 6},
#   {'text': 'nicht in ', 'size': 11, 'y_org': 220, 'x_end': 167, 'flags': 4},
#   {'text': 'unsere ', 'size': 11, 'y_org': 220, 'x_end': 201, 'flags': 6},
#   {'text': 'Nachrichten kommt!« ',
#    'size': 11,
#    'y_org': 220,
#    'x_end': 300,
#    'flags': 4}],
#  [{'text': '»Das meinst du wohl«, sagte Harry. ',
#    'size': 11,
#    'y_org': 239,
#    'x_end': 233,
#    'flags': 4}],
#  [{'text': 'Die Dursleys glotzten ihn ein paar Sekunden an, dann schimpfte ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Tante Petunia: »Du bist ein gemeiner kleiner Lügner. Was treiben ',
#    'size': 11,
#    'y_org': 270,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'denn all diese …«, auch sie senkte die Stimme, so dass Harry das ',
#    'size': 11,
#    'y_org': 282,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'nächste Wort von ihren Lippen ablesen musste, »… ',
#    'size': 11,
#    'y_org': 295,
#    'x_end': 291,
#    'flags': 4},
#   {'text': 'Eulen ', 'size': 11, 'y_org': 295, 'x_end': 322, 'flags': 6},
#   {'text': 'hier, wenn ', 'size': 11, 'y_org': 295, 'x_end': 371, 'flags': 4}],
#  [{'text': 'sie dir keine Nachrichten bringen?« ',
#    'size': 11,
#    'y_org': 308,
#    'x_end': 217,
#    'flags': 4}],
#  [{'text': '»Aha!«, flüsterte Onkel Vernon triumphierend. »Jetzt lass dir dazu ',
#    'size': 11,
#    'y_org': 327,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'mal eine Ausrede einfallen, Bursche! Als ob wir nicht wüssten, dass ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'du deine ganzen Nachrichten von diesen ekelhaften Vögeln ',
#    'size': 11,
#    'y_org': 352,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'bekommst!« ', 'size': 11, 'y_org': 364, 'x_end': 115, 'flags': 4}],
#  [{'text': 'Harry zögerte einen Moment. Es kostete ihn einige Überwindung, ',
#    'size': 11,
#    'y_org': 383,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'diesmal die Wahrheit zu sagen, obwohl Onkel und Tante unmöglich ',
#    'size': 11,
#    'y_org': 396,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wissen konnten, wie schlimm es für ihn war, sie einzugestehen. ',
#    'size': 11,
#    'y_org': 408,
#    'x_end': 340,
#    'flags': 4}],
#  [{'text': '»Die Eulen … bringen mir keine Nachrichten«, antwortete er ',
#    'size': 11,
#    'y_org': 427,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'tonlos. ', 'size': 11, 'y_org': 440, 'x_end': 89, 'flags': 4}],
#  [{'text': '»Das glaub ich nicht«, sagte Tante Petunia sofort. ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 293,
#    'flags': 4}],
#  [{'text': '»Und ich auch nicht«, bestätigte Onkel Vernon. ',
#    'size': 11,
#    'y_org': 477,
#    'x_end': 284,
#    'flags': 4}],
#  [{'text': '»Wir wissen, dass du irgendein krummes Ding vorhast«, sagte ',
#    'size': 11,
#    'y_org': 496,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Tante Petunia. ',
#    'size': 11,
#    'y_org': 508,
#    'x_end': 124,
#    'flags': 4}],
#  [{'text': '»Wir sind schließlich nicht blöde, verstehst du«, sagte Onkel ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Vernon. ', 'size': 11, 'y_org': 76, 'x_end': 96, 'flags': 4}],
#  [{'text': '»Na, ', 'size': 11, 'y_org': 95, 'x_end': 95, 'flags': 4},
#   {'text': 'das ', 'size': 11, 'y_org': 95, 'x_end': 120, 'flags': 6},
#   {'text': "ist ja mal 'ne Neuigkeit«, erwiderte Harry mit ",
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'anschwellendem Zorn, und bevor die Dursleys ihn zurückrufen ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'konnten, wirbelte er herum, lief über den Rasen, sprang über die ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'niedrige Gartenmauer und ging mit großen Schritten die Straße ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'entlang davon. ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 124,
#    'flags': 4}],
#  [{'text': 'Das gab Ärger, so viel war sicher. Er würde Onkel und Tante ',
#    'size': 11,
#    'y_org': 164,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'später Rede und Antwort stehen und für seine Frechheit bezahlen ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'müssen, doch fürs Erste war ihm das ziemlich schnuppe; er hatte viel ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dringendere Angelegenheiten im Kopf. ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 232,
#    'flags': 4}],
#  [{'text': 'Harry war sich sicher, dass der Knall von jemandem herrührte, der ',
#    'size': 11,
#    'y_org': 221,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'appariert oder disappariert war. Es war genau das Geräusch, das ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Dobby der Hauself machte, wenn er ins Blaue hinein verschwand. ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Konnte Dobby denn hier im Ligusterweg sein? Folgte ihm Dobby ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'vielleicht genau in diesem Moment? Bei diesem Gedanken schnellte ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'er herum und spähte zurück, doch der Ligusterweg schien ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'vollkommen ausgestorben, und Harry war sicher, dass Dobby nicht ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wusste, wie man sich unsichtbar machte. ',
#    'size': 11,
#    'y_org': 310,
#    'x_end': 240,
#    'flags': 4}],
#  [{'text': 'Er ging weiter und achtete dabei kaum auf den Weg, den er ',
#    'size': 11,
#    'y_org': 328,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'einschlug, denn er hatte diese Straßen in letzter Zeit so oft ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'durchstreift, dass ihn seine Füße wie von allein zu seinen ',
#    'size': 11,
#    'y_org': 353,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Lieblingsplätzen trugen. Alle paar Schritte warf er einen Blick über ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'die Schulter. Ein magisches Wesen hatte sich in seiner Nähe ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'aufgehalten, als er zwischen Tante Petunias sterbenden Begonien ',
#    'size': 11,
#    'y_org': 391,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'gelegen hatte, das war sicher. Warum hatte es ihn nicht angesprochen, ',
#    'size': 11,
#    'y_org': 404,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'warum hatte es keine Verbindung aufgenommen, warum versteckte es ',
#    'size': 11,
#    'y_org': 417,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'sich jetzt? ',
#    'size': 11,
#    'y_org': 429,
#    'x_end': 104,
#    'flags': 4}],
#  [{'text': 'Und dann, als seine Enttäuschung ihren Höhepunkt erreicht hatte, ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'schwand plötzlich diese Gewissheit. ',
#    'size': 11,
#    'y_org': 460,
#    'x_end': 219,
#    'flags': 4}],
#  [{'text': 'Vielleicht war es doch kein magisches Geräusch gewesen. ',
#    'size': 11,
#    'y_org': 479,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Vielleicht wartete er nur so verzweifelt auf das kleinste Zeichen aus ',
#    'size': 11,
#    'y_org': 492,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'einer Welt, in die er gehörte, dass er bei ganz gewöhnlichen ',
#    'size': 11,
#    'y_org': 504,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Geräuschen einfach überreagierte. Konnte er sicher sein, dass der ',
#    'size': 11,
#    'y_org': 517,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Lärm nicht daher rührte, dass in einem Nachbarhaus etwas zu Bruch ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'gegangen war? ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 127,
#    'flags': 4}],
#  [{'text': 'Harry hatte ein dumpfes, flaues Gefühl im Magen, und ',
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'unversehens überfiel ihn wieder die Hoffnungslosigkeit, die ihn den ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'ganzen Sommer über geplagt hatte. ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 216,
#    'flags': 4}],
#  [{'text': 'Morgen früh um fünf würde der Wecker ihn aus dem Schlaf reißen, ',
#    'size': 11,
#    'y_org': 138,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'damit er die Eule bezahlen konnte, die ihm den ',
#    'size': 11,
#    'y_org': 151,
#    'x_end': 294,
#    'flags': 4},
#   {'text': 'Tagespropheten ',
#    'size': 11,
#    'y_org': 151,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'brachte – aber hatte es noch einen Zweck, ihn weiter zu beziehen? ',
#    'size': 11,
#    'y_org': 164,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Harry schaute dieser Tage nur kurz auf die Titelseite und warf ihn ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'dann beiseite; wenn diese Trottel von der Zeitung endlich erkannt ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hatten, dass Voldemort zurück war, würde das Schlagzeilen machen, ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'und nur solche Nachrichten scherten Harry. ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 253,
#    'flags': 4}],
#  [{'text': 'Zwar kamen, wenn er Glück hatte, auch Eulen mit Briefen von ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'seinen besten Freunden Ron und Hermine, aber all seine Erwartungen, ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'dass ihre Briefe Neuigkeiten für ihn enthalten würden, waren schon ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'lange zunichte. ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 127,
#    'flags': 4}],
#  [{'text': 'Wir können nicht viel über Du-weißt-schon-was sagen, verstehst ',
#    'size': 11,
#    'y_org': 290,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'du … Man hat uns gesagt, dass wir nichts Wichtiges schreiben dürfen, ',
#    'size': 11,
#    'y_org': 303,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'falls unsere Briefe in die falschen Hände gelangen … Wir sind ',
#    'size': 11,
#    'y_org': 316,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'ziemlich beschäftigt, aber ich kann dir hier nichts Genaues schreiben ',
#    'size': 11,
#    'y_org': 328,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': '… Es geht einiges ab, wir erzählen dir alles, wenn wir dich treffen … ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 365,
#    'flags': 6}],
#  [{'text': 'Aber wann würden sie ihn treffen? Niemand schien sich groß um ',
#    'size': 11,
#    'y_org': 359,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'einen festen Termin zu kümmern. ',
#    'size': 11,
#    'y_org': 372,
#    'x_end': 223,
#    'flags': 4},
#   {'text': 'Ich denke, wir besuchen dich ',
#    'size': 11,
#    'y_org': 372,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'ziemlich bald, ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 124,
#    'flags': 6},
#   {'text': 'hatte Hermine auf seine Geburtstagskarte geschrieben, ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'aber wie bald war bald? Soviel Harry aus den vagen Hinweisen in ',
#    'size': 11,
#    'y_org': 397,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'ihren Briefen schließen konnte, waren Hermine und Ron am selben ',
#    'size': 11,
#    'y_org': 410,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Ort, vermutlich im Haus von Rons Eltern. Er konnte es kaum ertragen, ',
#    'size': 11,
#    'y_org': 423,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'daran zu denken, wie die beiden im Fuchsbau ihren Spaß hatten, ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'während er im Ligusterweg festsaß. Tatsächlich war er so sauer auf ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sie, dass er die beiden Schachteln mit Schokolade aus dem ',
#    'size': 11,
#    'y_org': 460,
#    'x_end': 320,
#    'flags': 4},
#   {'text': 'Honigtopf, ', 'size': 11, 'y_org': 460, 'x_end': 372, 'flags': 6}],
#  [{'text': 'die sie ihm zum Geburtstag geschickt hatten, ungeöffnet weggeworfen ',
#    'size': 11,
#    'y_org': 473,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'hatte. Später hatte er es bereut, nach dem welken Salat, den Tante ',
#    'size': 11,
#    'y_org': 486,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Petunia am selben Abend noch zum Essen aufgetischt hatte. ',
#    'size': 11,
#    'y_org': 498,
#    'x_end': 325,
#    'flags': 4}],
#  [{'text': 'Womit waren Ron und Hermine eigentlich so beschäftigt? Und ',
#    'size': 11,
#    'y_org': 517,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'warum war er, Harry, nicht beschäftigt? Hatte er nicht bewiesen, dass ',
#    'size': 11,
#    'y_org': 530,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'er mit viel mehr fertig werden konnte als sie? Hatten sie alle ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'vergessen, was er getan hatte? War es nicht er gewesen, der diesen ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Friedhof betreten und gesehen hatte, wie Cedric ermordet wurde, und ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'der an diesen Grabstein gefesselt wurde und fast umgebracht worden ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wäre? ', 'size': 11, 'y_org': 114, 'x_end': 87, 'flags': 4}],
#  [{'text': 'Denk nicht drüber nach, ermahnte sich Harry streng und zum ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'hundertsten Mal in diesem Sommer. Schlimm genug, dass er den ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Friedhof in seinen Alpträumen immer wieder besuchte, da brauchte er ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'in seinen wachen Momenten nicht auch noch darüber nachzubrüten. ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 360,
#    'flags': 4}],
#  [{'text': 'Er bog um eine Ecke und war nun auf dem Magnolienring; auf ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'halbem Weg die Straße entlang kam er an der schmalen Gasse vorbei, ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'die an einer Garage entlangführte und in der er zum ersten Mal seinen ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Paten gesehen hatte. Sirius zumindest schien zu verstehen, wie Harry ',
#    'size': 11,
#    'y_org': 228,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sich fühlte. Zugegeben, seine Briefe enthielten ebenso wenig ',
#    'size': 11,
#    'y_org': 240,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'handfeste Neuigkeiten wie die von Ron und Hermine, aber wenigstens ',
#    'size': 11,
#    'y_org': 252,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'schrieb er ihm zur Vorsicht mahnende und tröstende Worte statt ',
#    'size': 11,
#    'y_org': 265,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'quälender Andeutungen: Ich weiß, das muss frustrierend für dich sein ',
#    'size': 11,
#    'y_org': 278,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '… Halt die Ohren steif dann wird schon alles gut gehen … Sei ',
#    'size': 11,
#    'y_org': 291,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'vorsichtig und tu nichts Unbesonnenes … ',
#    'size': 11,
#    'y_org': 304,
#    'x_end': 244,
#    'flags': 4}],
#  [{'text': 'Immerhin, dachte Harry, während er den Magnolienring ',
#    'size': 11,
#    'y_org': 322,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'überquerte, in die Magnolienstraße einbog und auf den nun schon im ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Dunkeln liegenden Park mit dem Spielplatz zuging, immerhin hatte er ',
#    'size': 11,
#    'y_org': 347,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '(im Wesentlichen) befolgt, was Sirius ihm geraten hatte. Zumindest ',
#    'size': 11,
#    'y_org': 360,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hatte er der Versuchung widerstanden, den Koffer an seinen Besen zu ',
#    'size': 11,
#    'y_org': 372,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'binden und sich auf eigene Faust auf die Reise zum Fuchsbau zu ',
#    'size': 11,
#    'y_org': 385,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'machen. Im Grunde hatte er sich sehr gut verhalten, wenn er ',
#    'size': 11,
#    'y_org': 398,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'überlegte, wie enttäuscht und zornig er darüber war, so lange im ',
#    'size': 11,
#    'y_org': 411,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Ligusterweg festzusitzen, wo er nichts weiter unternehmen konnte, als ',
#    'size': 11,
#    'y_org': 423,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'sich in Blumenbeeten zu verstecken, in der Hoffnung, einen Hinweis ',
#    'size': 11,
#    'y_org': 436,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'darauf zu erlauschen, was Lord Voldemort gerade machte. Dennoch ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'wurmte es ihn, dass ihn ausgerechnet ein Mann vor Unbesonnenheiten ',
#    'size': 11,
#    'y_org': 461,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'warnte, der zwölf Jahre im Zauberergefängnis von Askaban gesessen ',
#    'size': 11,
#    'y_org': 474,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hatte, der entkommen war, daraufhin den Mord begehen wollte, für ',
#    'size': 11,
#    'y_org': 486,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'den man ihn ursprünglich verurteilt hatte, und schließlich mit einem ',
#    'size': 11,
#    'y_org': 499,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'gestohlenen Hippogreif geflohen war. ',
#    'size': 11,
#    'y_org': 512,
#    'x_end': 227,
#    'flags': 4}],
#  [{'text': 'Harry schwang sich über das geschlossene Parktor und überquerte ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'den verdorrten Rasen. Der Park war so menschenleer wie die Straßen ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'in der Nachbarschaft. Er erreichte die Schaukeln und ließ sich auf ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'einer davon nieder, der letzten, die Dudley und seine Freunde noch ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'nicht demoliert hatten, schlang einen Arm um die Kette und starrte ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'trübsinnig auf die Erde. Im Blumenbeet der Dursleys würde er sich ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'nicht mehr verstecken können. Morgen musste er sich etwas Neues ',
#    'size': 11,
#    'y_org': 139,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'einfallen lassen, wie er die Nachrichten hören konnte. Bis dahin hatte ',
#    'size': 11,
#    'y_org': 152,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'er nichts, auf das er sich freuen konnte, nur eine weitere unruhige, ',
#    'size': 11,
#    'y_org': 165,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sorgenvoll durchwälzte Nacht, denn selbst wenn er von Alpträumen ',
#    'size': 11,
#    'y_org': 178,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'um Cedric verschont blieb, plagten ihn schreckliche Träume von ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'langen schwarzen Korridoren, die alle an Mauern und verschlossenen ',
#    'size': 11,
#    'y_org': 203,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Türen endeten, was, wie er vermutete, etwas zu tun hatte mit dem ',
#    'size': 11,
#    'y_org': 216,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Gefühl, in der Falle zu sitzen, das ihn am Tage quälte. Seine alte ',
#    'size': 11,
#    'y_org': 228,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Stirnnarbe ziepte oft unangenehm, aber Ron oder Hermine oder Sirius, ',
#    'size': 11,
#    'y_org': 240,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'da machte er sich nichts vor, würden dies nicht mehr sonderlich ',
#    'size': 11,
#    'y_org': 253,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'spannend finden. Früher hatten ihn die Narbenschmerzen gewarnt, ',
#    'size': 11,
#    'y_org': 266,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'wenn Voldemort wieder stärker wurde, doch nun, da Voldemort ',
#    'size': 11,
#    'y_org': 279,
# ...
#  [{'text': 'Pergamentumschlag, den sie im Schnabel trug, zu Harrys Füßen ',
#    'size': 11,
#    'y_org': 421,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'fallen, legte eine elegante Kurve hin, wobei sie mit den Flügelspitzen ',
#    'size': 11,
#    'y_org': 434,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'sacht den Kühlschrank streifte, sauste wieder hinaus und entschwand ',
#    'size': 11,
#    'y_org': 447,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'über dem Garten. ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 137,
#    'flags': 4}],
#  [{'text': '»EULEN!«, bellte Onkel Vernon, und die schwer mitgenommene ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Ader an seiner Schläfe pulsierte zornig, während er das Küchenfenster ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'zuschlug. »SCHON WIEDER EULEN! ICH DULDE KEINE EULEN ',
#    'size': 11,
#    'y_org': 503,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'MEHR IN MEINEM HAUS!« ',
#    'size': 11,
#    'y_org': 516,
#    'x_end': 196,
#    'flags': 4}],
#  [{'text': 'Doch Harry, dem das Herz irgendwo in der Gegend des ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Adamsapfels pochte, riss bereits den Umschlag auf und zog den Brief ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'heraus. ', 'size': 11, 'y_org': 89, 'x_end': 92, 'flags': 4}],
#  [{'text': 'Sehr geehrter Mr. Potter, wir haben Information erhalten, wonach ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Sie den Patronus-Zauber heute Abend um dreiundzwanzig Minuten ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'nach neun in einem Muggelwohngebiet und in Gegenwart eines ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Muggels ausgeführt haben. ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 180,
#    'flags': 4}],
#  [{'text': 'Die Schwere dieser Verletzung des Erlasses zur Vernunftgemäßen ',
#    'size': 11,
#    'y_org': 164,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Beschränkung der Zauberei Minderjähriger hat zu Ihrem Verweis von ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'der Hogwarts-Schule für Hexerei und Zauberei geführt. Beauftragte ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'des Ministeriums werden Sie unverzüglich an Ihrem Wohnort ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'aufsuchen, um Ihren Zauberstab zu zerstören. ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 262,
#    'flags': 4}],
#  [{'text': 'Da Sie bereits eine offizielle Verwarnung aufgrund eines früheren ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Vergehens gemäß Abschnitt 13 des Geheimhaltungsabkommens der ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Internationalen Zauberervereinigung erhalten haben, bedauern wir ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Ihnen mitteilen zu müssen, dass Ihre Anwesenheit bei einer ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'disziplinarischen Anhörung im Zaubereiministerium am zwölften ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'August um neun Uhr verlangt ist. ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 207,
#    'flags': 4}],
#  [{'text': 'In der Hoffnung, dass Sie wohlauf sind, ',
#    'size': 11,
#    'y_org': 316,
#    'x_end': 249,
#    'flags': 4}],
#  [{'text': 'mit freundlichen Grüßen ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 184,
#    'flags': 4}],
#  [{'text': 'Mafalda Hopfkirch ',
#    'size': 11,
#    'y_org': 352,
#    'x_end': 160,
#    'flags': 6}],
#  [{'text': 'Abteilung für unbefugte Zauberei ',
#    'size': 11,
#    'y_org': 371,
#    'x_end': 223,
#    'flags': 4}],
#  [{'text': 'Zaubereiministerium ',
#    'size': 11,
#    'y_org': 390,
#    'x_end': 166,
#    'flags': 4}],
#  [{'text': 'Harry las den Brief zweimal durch. Nur verschwommen nahm er ',
#    'size': 11,
#    'y_org': 408,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wahr, dass Onkel Vernon und Tante Petunia redeten. In seinem Kopf ',
#    'size': 11,
#    'y_org': 421,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'war alles eisig und taub. Eine Tatsache hatte sich in sein Bewusstsein ',
#    'size': 11,
#    'y_org': 434,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'gebohrt wie ein lähmender Pfeil. Sie hatten ihn von Hogwarts ',
#    'size': 11,
#    'y_org': 447,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'verwiesen. Alles war zu Ende. Er würde nie zurückkehren. ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 319,
#    'flags': 4}],
#  [{'text': 'Er blickte zu den Dursleys hoch. Onkel Vernon, purpurrot im ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Gesicht, die Fäuste immer noch gereckt, schrie andauernd; Tante ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Petunia hatte die Arme um Dudley gelegt, der von neuem würgte. ',
#    'size': 11,
#    'y_org': 503,
#    'x_end': 350,
#    'flags': 4}],
#  [{'text': 'Harrys zeitweilig betäubtes Gehirn schien wieder zu erwachen. ',
#    'size': 11,
#    'y_org': 522,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Beauftragte des Ministeriums werden Sie unverzüglich an Ihrem ',
#    'size': 11,
#    'y_org': 534,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'Wohnort aufsuchen, um Ihren Zauberstab zu zerstören. ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 307,
#    'flags': 6},
#   {'text': 'Da gab es nur ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'eines. Er musste fliehen – und zwar sofort. Wohin, wusste Harry ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'nicht, doch so viel war sicher: Ob er in Hogwarts war oder nicht, ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'seinen Zauberstab brauchte er. Fast traumwandlerisch zog er ihn ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'heraus und wandte sich zum Gehen. ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 219,
#    'flags': 4}],
#  [{'text': '»Wo willst du hin?«, rief Onkel Vernon. Als Harry nicht ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'antwortete, stampfte er durch die Küche und versperrte die Tür zum ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Flur. »Ich bin noch nicht fertig mit dir, Bursche!« ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 280,
#    'flags': 4}],
#  [{'text': '»Geh mir aus dem Weg«, sagte Harry leise. ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 267,
#    'flags': 4}],
#  [{'text': '»Du bleibst hier und erklärst, wie mein Sohn …« ',
#    'size': 11,
#    'y_org': 196,
#    'x_end': 291,
#    'flags': 4}],
#  [{'text': '»Wenn du nicht aus dem Weg gehst, verhex ich dich«, sagte Harry ',
#    'size': 11,
#    'y_org': 214,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und hob den Zauberstab. ',
#    'size': 11,
#    'y_org': 227,
#    'x_end': 169,
#    'flags': 4}],
#  [{'text': '»Darauf fall ich nicht rein!«, schnarrte Onkel Vernon. »Ich weiß, ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dass du ihn nicht außerhalb dieser Beklopptenanstalt benutzen darfst, ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'die ihr Schule nennt!« ',
#    'size': 11,
#    'y_org': 270,
#    'x_end': 157,
#    'flags': 4}],
#  [{'text': '»Die Beklopptenanstalt hat mich rausgeschmissen«, sagte Harry. ',
#    'size': 11,
#    'y_org': 289,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': '»Also kann ich tun, was ich will. Du hast drei Sekunden. Eins – zwei ',
#    'size': 11,
#    'y_org': 302,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '…« ', 'size': 11, 'y_org': 315, 'x_end': 77, 'flags': 4}],
#  [{'text': 'Ein schallender KNALL erfüllte die Küche. Tante Petunia ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'kreischte, Onkel Vernon schrie und duckte sich, und zum dritten Mal ',
#    'size': 11,
#    'y_org': 346,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'an diesem Abend suchte Harry nach dem Ursprung eines Lärms, den ',
#    'size': 11,
#    'y_org': 358,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'er nicht verursacht hatte. Er sah ihn sofort: Eine Schleiereule saß ',
#    'size': 11,
#    'y_org': 371,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'draußen auf dem Küchenfenstersims, benommen und zerzaust, da sie ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'eben gegen das geschlossene Fenster gekracht war. ',
#    'size': 11,
#    'y_org': 396,
#    'x_end': 286,
#    'flags': 4}],
#  [{'text': 'Harry stürmte durch die Küche, ohne auf Onkel Vernons ',
#    'size': 11,
#    'y_org': 415,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'ängstlichen »EULEN!«-Schrei zu achten, und riss das Fenster auf. Die ',
#    'size': 11,
#    'y_org': 428,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Eule streckte ihr Bein vor, an das eine kleine Pergamentrolle ',
#    'size': 11,
#    'y_org': 441,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'gebunden war, schüttelte die Federn und flog davon, kaum dass Harry ',
#    'size': 11,
#    'y_org': 453,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'den Brief geborgen hatte. Mit zitternden Händen entrollte er die ',
#    'size': 11,
#    'y_org': 466,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'zweite Botschaft, die sehr hastig und verkleckst in schwarzer Tinte ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'geschrieben war. ',
#    'size': 11,
#    'y_org': 491,
#    'x_end': 135,
#    'flags': 4}],
#  [{'text': 'Harry … ', 'size': 11, 'y_org': 510, 'x_end': 115, 'flags': 4}],
#  [{'text': 'Dumbledore ist eben im Ministerium eingetroffen und versucht, ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'alles wieder ms Lot zu bringen. VERLASS DAS HAUS VON ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'TANTE UND ONKEL NICHT. GEBRAUCH KEINEN ZAUBER ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'MEHR. GIB DEINEN ZAUBERSTAB NICHT AB. Arthur Weasley. ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 367,
#    'flags': 4}],
#  [{'text': 'Dumbledore versuchte alles wieder ins Lot zu bringen … was ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sollte ', 'size': 11, 'y_org': 132, 'x_end': 83, 'flags': 4},
#   {'text': 'das ', 'size': 11, 'y_org': 132, 'x_end': 111, 'flags': 4},
#   {'text': 'heißen? ', 'size': 11, 'y_org': 132, 'x_end': 157, 'flags': 4},
#   {'text': 'Hatte ', 'size': 11, 'y_org': 132, 'x_end': 194, 'flags': 4},
#   {'text': 'Dumbledore ', 'size': 11, 'y_org': 132, 'x_end': 262, 'flags': 4},
#   {'text': 'Macht ', 'size': 11, 'y_org': 132, 'x_end': 302, 'flags': 4},
#   {'text': 'genug, ', 'size': 11, 'y_org': 132, 'x_end': 345, 'flags': 4},
#   {'text': 'das ', 'size': 11, 'y_org': 132, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Zaubereiministerium zum Rückzug zu zwingen? Gab es also eine ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Chance, dass er doch nach Hogwarts zurück durfte? Ein kleiner ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Hoffnungsfunke flammte in Harrys Brust auf, gleich wieder erstickt ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'von Panik – wie sollte er sich weigern, seinen Zauberstab abzugeben, ',
#    'size': 11,
#    'y_org': 184,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'ohne einen Zauber zu gebrauchen? Er würde sich mit den ',
#    'size': 11,
#    'y_org': 196,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Ministeriumsleuten duellieren müssen, und wenn er das tat, konnte er ',
#    'size': 11,
#    'y_org': 209,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'von Glück reden, wenn sie ihn nicht nach Askaban steckten, vom ',
#    'size': 11,
#    'y_org': 222,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Rauswurf ganz zu schweigen. ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 191,
#    'flags': 4}],
#  [{'text': 'Seine Gedanken rasten … er konnte fliehen und dabei Gefahr ',
#    'size': 11,
#    'y_org': 252,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'laufen, vom Ministerium geschnappt zu werden, oder aber bleiben und ',
#    'size': 11,
#    'y_org': 265,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'warten, bis sie ihn hier kriegten. Dann lieber fliehen, aber er wusste, ',
#    'size': 11,
#    'y_org': 278,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'dass Mr. Weasley nur sein Bestes am Herzen lag … und schließlich ',
#    'size': 11,
#    'y_org': 291,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'hatte Dumbledore schon viel Schlimmeres wieder eingerenkt. ',
#    'size': 11,
#    'y_org': 304,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': "»Na gut«, sagte Harry. »Ich hab's mir anders überlegt. Ich bleibe.« ",
#    'size': 11,
#    'y_org': 322,
#    'x_end': 367,
#    'flags': 4}],
#  [{'text': 'Schwungvoll setzte er sich auf einen Stuhl am Küchentisch und sah ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Dudley und Tante Petunia geradeheraus an. Den Dursleys schien es ',
#    'size': 11,
#    'y_org': 353,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'angesichts dieses plötzlichen Sinneswandels die Sprache verschlagen ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'zu haben. Tante Petunia linste verzweifelt zu Onkel Vernon hinüber. ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Die Ader an seiner roten Schläfe pochte heftiger denn je. ',
#    'size': 11,
#    'y_org': 391,
#    'x_end': 310,
#    'flags': 4}],
#  [{'text': '»Wo kommen all die verdammten Eulen her?«, knurrte er. ',
#    'size': 11,
#    'y_org': 410,
#    'x_end': 332,
#    'flags': 4}],
#  [{'text': '»Die erste war aus dem Zaubereiministerium, die kam mit dem ',
#    'size': 11,
#    'y_org': 429,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Rauswurf«, sagte Harry gelassen. Er spitzte die Ohren, um etwaige ',
#    'size': 11,
#    'y_org': 441,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Geräusche ', 'size': 11, 'y_org': 454, 'x_end': 106, 'flags': 4},
#   {'text': 'draußen ', 'size': 11, 'y_org': 454, 'x_end': 156, 'flags': 4},
#   {'text': 'zu ', 'size': 11, 'y_org': 454, 'x_end': 181, 'flags': 4},
#   {'text': 'hören. ', 'size': 11, 'y_org': 454, 'x_end': 223, 'flags': 4},
#   {'text': 'Vielleicht ', 'size': 11, 'y_org': 454, 'x_end': 281, 'flags': 4},
#   {'text': 'waren ', 'size': 11, 'y_org': 454, 'x_end': 322, 'flags': 4},
#   {'text': 'ja ', 'size': 11, 'y_org': 454, 'x_end': 344, 'flags': 4},
#   {'text': 'die ', 'size': 11, 'y_org': 454, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Ministeriumsleute im Anmarsch, und es war einfacher und weniger ',
#    'size': 11,
#    'y_org': 466,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'lärmträchtig, Onkel Vernons Fragen zu beantworten, als ihn erneut in ',
#    'size': 11,
#    'y_org': 479,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'brüllende Rage zu versetzen. »Die zweite war vom Vater meines ',
#    'size': 11,
#    'y_org': 492,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Freundes Ron, der im Ministerium arbeitet.« ',
#    'size': 11,
#    'y_org': 504,
#    'x_end': 256,
#    'flags': 4}],
#  [{'text': '»Zaubereiministerium?«, brüllte Onkel Vernon. »Leute wie ihr in ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'der Regierung? Oh, das erklärt alles, alles, kein Wunder, dass das ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 370,
#    'flags': 6}],
#  [{'text': 'Land vor die Hunde geht.« ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 179,
#    'flags': 6}],
#  [{'text': 'Da Harry nicht antwortete, starrte ihn Onkel Vernon funkelnd vor ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 372,
#    'flags': 4}],
#  ...]

# %%
def get_text_constants(lines):
    text_sizes = {}
    text_ends = {}
    for line in lines:
        span = line[-1]
        text_len, text_size, text_end = len(span['text']), span['size'], span['x_end']
        if not (text_size in text_sizes):
            text_sizes[text_size] = 0
        text_sizes[text_size] += text_len
        if not (text_end in text_ends):
            text_ends[text_end] = 0
        text_ends[text_end] += 1
    #return text_sizes, text_ends
    return max(text_sizes, key=text_sizes.get), max(text_ends, key=text_ends.get)

# %%
text_size, end_pos = get_text_constants(lines)
print(f'{text_size=}, {end_pos=}')
# Out:
# text_size=11, end_pos=372

# %%
lines
# Out:
# [[{'text': 'Dudley umnachtet ',
#    'size': 20,
#    'y_org': 72,
#    'x_end': 297,
#    'flags': 20}],
#  [{'text': 'Der bislang heißeste Tag des Sommers neigte sich dem Ende zu ',
#    'size': 11,
#    'y_org': 105,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und eine schläfrige Stille lag über den großen wuchtigen Häusern des ',
#    'size': 11,
#    'y_org': 118,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Ligusterwegs. Autos, die normalerweise glänzten, standen staubig in ',
#    'size': 11,
#    'y_org': 130,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'den Einfahrten, und Rasenflächen, die einst smaragdgrün waren, lagen ',
#    'size': 11,
#    'y_org': 142,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'verdorrt und gelbstichig da – wegen der Dürre war es verboten ',
#    'size': 11,
#    'y_org': 155,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'worden, sie mit Gartenschläuchen zu wässern. Die Bewohner des ',
#    'size': 11,
#    'y_org': 168,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Ligusterwegs, die sich nun nicht mehr wie üblich mit Autowaschen ',
#    'size': 11,
#    'y_org': 180,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und Rasenmähen die Zeit vertreiben konnten, hatten sich in die ',
#    'size': 11,
#    'y_org': 193,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Schatten ihrer kühlen Häuser zurückgezogen und die Fenster weit ',
#    'size': 11,
#    'y_org': 206,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'aufgestoßen ', 'size': 11, 'y_org': 219, 'x_end': 113, 'flags': 4},
#   {'text': 'in ', 'size': 11, 'y_org': 219, 'x_end': 137, 'flags': 4},
#   {'text': 'der ', 'size': 11, 'y_org': 219, 'x_end': 166, 'flags': 4},
#   {'text': 'Hoffnung, ', 'size': 11, 'y_org': 219, 'x_end': 226, 'flags': 4},
#   {'text': 'eine ', 'size': 11, 'y_org': 219, 'x_end': 259, 'flags': 4},
#   {'text': 'vermeintliche ',
#    'size': 11,
#    'y_org': 219,
#    'x_end': 334,
#    'flags': 4},
#   {'text': 'Brise ', 'size': 11, 'y_org': 219, 'x_end': 372, 'flags': 4}],
#  [{'text': 'hereinzulocken. Der einzige Mensch, der noch draußen war, ein ',
#    'size': 11,
#    'y_org': 231,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Teenager, lag in einem Blumenbeet vor Nummer vier flach auf dem ',
#    'size': 11,
#    'y_org': 244,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Rücken. ', 'size': 11, 'y_org': 256, 'x_end': 97, 'flags': 4}],
#  [{'text': 'Es war ein schlaksiger, schwarzhaariger Junge mit Brille, der ',
#    'size': 11,
#    'y_org': 275,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'ausgezehrt und leicht ungesund wirkte wie jemand, der in kurzer Zeit ',
#    'size': 11,
#    'y_org': 288,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'recht schnell gewachsen war. Seine Jeans war dreckig und zerrissen, ',
#    'size': 11,
#    'y_org': 300,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'sein T-Shirt ausgeleiert und verblichen, und die Sohlen seiner ',
#    'size': 11,
#    'y_org': 313,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Turnschuhe schälten sich vom Oberleder. Harry Potters Äußeres ',
#    'size': 11,
#    'y_org': 326,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'machte ihn nicht lieb Kind bei den Nachbarn, jener Sorte von ',
#    'size': 11,
#    'y_org': 338,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Menschen, die meinten, Schmuddeligkeit gehöre gesetzlich bestraft, ',
#    'size': 11,
#    'y_org': 351,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'doch da er sich an diesem Abend hinter einem großen ',
#    'size': 11,
#    'y_org': 364,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Hortensienbusch versteckt hatte, war er für Passanten gänzlich ',
#    'size': 11,
#    'y_org': 376,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'unsichtbar. Tatsächlich konnten ihn nur Onkel Vernon und Tante ',
#    'size': 11,
#    'y_org': 389,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Petunia sehen, falls sie die Köpfe aus dem Wohnzimmerfenster ',
#    'size': 11,
#    'y_org': 402,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'streckten und senkrecht nach unten ins Blumenbeet schauten. ',
#    'size': 11,
#    'y_org': 414,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': 'Alles in allem, dachte Harry, konnte man ihm zu seiner Idee, sich ',
#    'size': 11,
#    'y_org': 432,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hier zu verstecken, nur gratulieren. Vielleicht war es nicht sonderlich ',
#    'size': 11,
#    'y_org': 445,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'bequem, wie er da auf der heißen, harten Erde lag, doch immerhin ',
#    'size': 11,
#    'y_org': 458,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'stierte ihn niemand finster an und knirschte so laut mit den Zähnen, ',
#    'size': 11,
#    'y_org': 471,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dass er die Nachrichten nicht hören konnte, oder warf ihm gehässige ',
#    'size': 11,
#    'y_org': 484,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Fragen an den Kopf, wie es noch jedes Mal geschehen war, wenn er ',
#    'size': 11,
#    'y_org': 496,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'versucht hatte, sich ins Wohnzimmer zu setzen und mit Tante und ',
#    'size': 11,
#    'y_org': 509,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Onkel fernzusehen. ',
#    'size': 11,
#    'y_org': 521,
#    'x_end': 145,
#    'flags': 4}],
#  [{'text': 'Als wäre Harrys Gedanke durchs offene Fenster geflattert, fing ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Vernon Dursley, sein Onkel, plötzlich an zu reden. ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 283,
#    'flags': 4}],
#  [{'text': '»Bin froh, dass der Bursche nicht mehr versucht, sich hier breit zu ',
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'machen. Übrigens, wo steckt er eigentlich?« ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 256,
#    'flags': 4}],
#  [{'text': '»Ich weiß es nicht«, sagte Tante Petunia beiläufig. »Nicht im Haus ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'jedenfalls.« ',
#    'size': 11,
#    'y_org': 138,
#    'x_end': 111,
#    'flags': 4}],
#  [{'text': 'Onkel Vernon grunzte. ',
#    'size': 11,
#    'y_org': 157,
#    'x_end': 175,
#    'flags': 4}],
#  [{'text': '»Die Nachrichten gucken …«, höhnte er. »Möchte wissen, was er ',
#    'size': 11,
#    'y_org': 176,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wirklich im Schilde führt. Ein normaler Junge pfeift doch drauf, was ',
#    'size': 11,
#    'y_org': 189,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'in den Nachrichten kommt – Dudley hat keine Ahnung, was in der ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Welt passiert. Bin mir nicht mal sicher, ob er weiß, wer der ',
#    'size': 11,
#    'y_org': 214,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': "Premierminister ist! Jedenfalls sieht's nicht so aus, als käme irgendwas ",
#    'size': 11,
#    'y_org': 227,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'über seine Sippschaft in unseren Nachrichten …« ',
#    'size': 11,
#    'y_org': 240,
#    'x_end': 279,
#    'flags': 4}],
#  [{'text': '»Vernon, ', 'size': 11, 'y_org': 258, 'x_end': 115, 'flags': 4},
#   {'text': 'schhh!«, ', 'size': 11, 'y_org': 258, 'x_end': 156, 'flags': 6},
#   {'text': 'sagte Tante Petunia. »Das Fenster steht offen!« ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 367,
#    'flags': 4}],
#  [{'text': '»Oh – ja – Verzeihung, Liebling.« ',
#    'size': 11,
#    'y_org': 276,
#    'x_end': 226,
#    'flags': 4}],
#  [{'text': 'Die Dursleys verstummten. Harry lauschte einem Werbesong für ',
#    'size': 11,
#    'y_org': 295,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Obst-und-Kleie-Frühstücksflocken, während er Mrs. Figg, eine ',
#    'size': 11,
#    'y_org': 308,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'schrullige alte Dame aus dem nahen Glyzinenweg, langsam ',
#    'size': 11,
#    'y_org': 321,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'vorbeitappen sah. Sie blickte finster drein und murmelte vor sich hin. ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Harry war sehr froh, dass er hinter dem Busch versteckt lag, weil Mrs. ',
#    'size': 11,
#    'y_org': 346,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Figg ihn seit kurzem jedes Mal wenn sie ihn auf der Straße traf, zu ',
#    'size': 11,
#    'y_org': 358,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sich nach Hause zum Tee einlud. Sie war um die Ecke gebogen und ',
#    'size': 11,
#    'y_org': 371,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'verschwunden, als Onkel Vernons Stimme erneut aus dem Fenster ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'schwebte. ', 'size': 11, 'y_org': 396, 'x_end': 104, 'flags': 4}],
#  [{'text': '»Duddy ist zum Tee eingeladen?« ',
#    'size': 11,
#    'y_org': 415,
#    'x_end': 225,
#    'flags': 4}],
#  [{'text': '»Bei den Polkissens«, sagte Tante Petunia liebevoll. »Er hat so ',
#    'size': 11,
#    'y_org': 434,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'viele kleine Freunde, beliebt, wie er ist …« ',
#    'size': 11,
#    'y_org': 447,
#    'x_end': 251,
#    'flags': 4}],
#  [{'text': 'Mit Mühe verkniff sich Harry ein Schnauben. Die Dursleys waren ',
#    'size': 11,
#    'y_org': 465,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'wirklich erstaunlich dumm, wenn es um ihren Sohn Dudley ging. All ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'seine fadenscheinigen Lügen, er wäre jeden Abend der Sommerferien ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'bei einem anderen Typen aus seiner Gang zum Tee, hatten sie ',
#    'size': 11,
#    'y_org': 503,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'geschluckt. Harry wusste genau, dass Dudley nirgends zum Tee war; ',
#    'size': 11,
#    'y_org': 516,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'er und seine Gang verbrachten jeden Abend damit, den Spielplatz im ',
#    'size': 11,
#    'y_org': 528,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Park zu demolieren, an Straßenecken zu rauchen und Steine auf ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'vorbeikommende Autos und Kinder zu werfen. Harry hatte sie ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'während seiner abendlichen Streifzüge durch Little Whinging dabei ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'beobachtet; er hatte den größten Teil der Ferien damit verbracht, durch ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'die Straßen zu ziehen und unterwegs Zeitungen aus den Mülleimern ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'zu klauben. ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 110,
#    'flags': 4}],
#  [{'text': 'Als die ersten Töne der Melodie für die Sieben-Uhr-Nachrichten ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'an Harrys Ohr drangen, drehte sich ihm der Magen um. Vielleicht ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'heute Abend – nachdem er einen Monat gewartet hatte –, vielleicht ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'war es heute so weit. ',
#    'size': 11,
#    'y_org': 184,
#    'x_end': 152,
#    'flags': 4}],
#  [{'text': '»Während der Streik der spanischen Gepäckabfertiger in die ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'zweite Woche geht, sitzen so viele Urlauber wie noch nie auf den ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 369,
#    'flags': 6}],
#  [{'text': 'Flughäfen fest …« ',
#    'size': 11,
#    'y_org': 228,
#    'x_end': 142,
#    'flags': 6}],
#  [{'text': '»Denen würde ich eine lebenslange Siesta verpassen, wenn du ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'mich fragst«, knurrte Onkel Vernon, kaum dass der Sprecher den Satz ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'vollendet hatte, und doch: Draußen im Blumenbeet schien sich Harrys ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Magen wieder zu entspannen. Wenn irgendetwas passiert wäre, dann ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hätten sie es sicher als Erstes in den Nachrichten gebracht; Tod und ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Zerstörung waren wichtiger als gestrandete Urlauber. ',
#    'size': 11,
#    'y_org': 310,
#    'x_end': 295,
#    'flags': 4}],
#  [{'text': 'Er atmete lange und ruhig aus und blickte in den strahlend blauen ',
#    'size': 11,
#    'y_org': 328,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Himmel. Diesen Sommer war es Tag für Tag das Gleiche gewesen: ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'die Spannung, die Erwartung, die zeitweilige Erleichterung und dann ',
#    'size': 11,
#    'y_org': 353,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'erneut die wachsende Spannung … und stets drängender die Frage, ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'warum ', 'size': 11, 'y_org': 378, 'x_end': 91, 'flags': 6},
#   {'text': 'noch nichts passiert war. ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 203,
#    'flags': 4}],
#  [{'text': 'Er lauschte weiter, nur für den Fall, dass es einen kleinen Hinweis ',
#    'size': 11,
#    'y_org': 397,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'gab, dessen ganze Bedeutung den Muggeln entging – ein rätselhaftes ',
#    'size': 11,
#    'y_org': 410,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Verschwinden vielleicht, oder ein merkwürdiger Unfall … aber dem ',
#    'size': 11,
#    'y_org': 423,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Streik der Gepäckabfertiger folgte eine Meldung über die Dürre im ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Südosten Englands (»Hoffentlich hört der nebenan zu!«, bellte Onkel ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Vernon. »Der mit seinen Sprinklern, die er um drei Uhr morgens ',
#    'size': 11,
#    'y_org': 460,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'anstellt!«), dann über einen Hubschrauber, der beinahe über einem ',
#    'size': 11,
#    'y_org': 473,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Feld in Surrey abgestürzt war, schließlich über die Scheidung einer ',
#    'size': 11,
#    'y_org': 486,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'prominenten Schauspielerin von ihrem prominenten Mann (»Als ob ',
#    'size': 11,
#    'y_org': 498,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'wir an deren schmutzigen Affären interessiert wären«, naserümpfte ',
#    'size': 11,
#    'y_org': 511,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Tante Petunia, die diesen Fall in jeder Illustrierten, die ihr unter die ',
#    'size': 11,
#    'y_org': 524,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'knochigen Finger kam, gebannt verfolgte). ',
#    'size': 11,
#    'y_org': 536,
#    'x_end': 248,
#    'flags': 4}],
#  [{'text': 'Harry schloss die Augen vor dem jetzt flammenden Abendhimmel, ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'während der Sprecher sagte: ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 197,
#    'flags': 4},
#   {'text': '»— und schließlich hat Wally der ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'Wellensittich sich etwas Neues einfallen lassen, wie er sich diesen ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 369,
#    'flags': 6}],
#  [{'text': 'Sommer abkühlen kann. Wally, der auf den Five Feathers in Barnsley ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'lebt, hat Wasserski gelernt! Mary Dorkins hat sich dort für Sie ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'umgeschaut.« ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 121,
#    'flags': 6}],
#  [{'text': 'Harry öffnete die Augen. Wenn sie schon bei Wasserski fahrenden ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Wellensittichen waren, würde nichts Hörenswertes mehr kommen. Er ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'drehte sich vorsichtig auf den Bauch und stemmte sich auf Knie und ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Ellbogen, um unter dem Fenster wegzukriechen. ',
#    'size': 11,
#    'y_org': 184,
#    'x_end': 274,
#    'flags': 4}],
#  [{'text': 'Er hatte sich gerade mal fünf Zentimeter bewegt, als mehrere ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Dinge in sehr rascher Folge passierten. ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 232,
#    'flags': 4}],
#  [{'text': 'Ein lauter, widerhallender ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 189,
#    'flags': 4},
#   {'text': 'Knall ', 'size': 11, 'y_org': 234, 'x_end': 217, 'flags': 6},
#   {'text': 'zerriss die schläfrige Stille wie ein ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Pistolenschuss; eine Katze sauste unter einem geparkten Wagen ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'hervor und stob davon; ein spitzer Schrei, ein gellender Fluch und das ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Geräusch ', 'size': 11, 'y_org': 271, 'x_end': 101, 'flags': 4},
#   {'text': 'von ', 'size': 11, 'y_org': 271, 'x_end': 131, 'flags': 4},
#   {'text': 'zerbrechendem ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 210,
#    'flags': 4},
#   {'text': 'Porzellan ', 'size': 11, 'y_org': 271, 'x_end': 265, 'flags': 4},
#   {'text': 'drangen ', 'size': 11, 'y_org': 271, 'x_end': 313, 'flags': 4},
#   {'text': 'aus ', 'size': 11, 'y_org': 271, 'x_end': 340, 'flags': 4},
#   {'text': 'dem ', 'size': 11, 'y_org': 271, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Wohnzimmer der Dursleys. Als sei dies das Signal, auf das Harry ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'gewartet hatte, schnellte er hoch und zog einen dünnen hölzernen ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Zauberstab aus seinem Jeansbund wie ein Schwert aus der Scheide – ',
#    'size': 11,
#    'y_org': 310,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'doch bevor er sich ganz aufrichten konnte, krachte er mit der ',
#    'size': 11,
#    'y_org': 322,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Schädeldecke gegen das offene Fenster der Dursleys. Es ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 316,
#    'flags': 4},
#   {'text': 'rumste ', 'size': 11, 'y_org': 334, 'x_end': 352, 'flags': 6},
#   {'text': 'und ', 'size': 11, 'y_org': 334, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Tante Petunia kreischte noch lauter. ',
#    'size': 11,
#    'y_org': 347,
#    'x_end': 218,
#    'flags': 4}],
#  [{'text': 'Harry hatte das Gefühl, als wäre sein Kopf entzweigespalten. ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Schwankend, mit tränenden Augen, versuchte er den Blick auf die ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Straße zu richten, um die Quelle des Lärms auszumachen, doch kaum ',
#    'size': 11,
#    'y_org': 391,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'hatte er sich stolpernd erhoben, langten zwei große, purpurrote Hände ',
#    'size': 11,
#    'y_org': 404,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'durchs offene Fenster und schlossen sich fest um seine Kehle. ',
#    'size': 11,
#    'y_org': 417,
#    'x_end': 333,
#    'flags': 4}],
#  [{'text': '»Tu – das – Ding – weg!«, ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 195,
#    'flags': 6},
#   {'text': 'schnarrte Onkel Vernon in Harrys Ohr. ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '»Sofort! Bevor – es – jemand – sieht!« ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 230,
#    'flags': 6}],
#  [{'text': '»Lass – mich – los!«, keuchte Harry. Einige Sekunden lang rangen ',
#    'size': 11,
#    'y_org': 466,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'sie miteinander. Harry, der mit der rechten Hand den erhobenen ',
#    'size': 11,
#    'y_org': 479,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Zauberstab fest umklammerte, zog mit der linken an den Wurstfingern ',
#    'size': 11,
#    'y_org': 492,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'seines Onkels; dann, in dem Moment, als der Schmerz an Harrys ',
#    'size': 11,
#    'y_org': 504,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Schädeldecke besonders fies pochte, japste Onkel Vernon plötzlich ',
#    'size': 11,
#    'y_org': 517,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und ließ Harry los, als ob er einen elektrischen Schlag bekommen ',
#    'size': 11,
#    'y_org': 530,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hätte. Eine unsichtbare Kraft schien durch seinen Neffen pulsiert zu ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sein, so dass er ihn unmöglich weiter festhalten konnte. ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 304,
#    'flags': 4}],
#  [{'text': 'Keuchend fiel Harry bäuchlings über den Hortensienbusch, richtete ',
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'sich auf und spähte umher. Was den lauten Knall verursacht haben ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'könnte, war nicht im Entferntesten zu erkennen, aber inzwischen ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'lugten Gesichter aus einigen Fenstern in der Nachbarschaft. Harry ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'steckte hastig seinen Zauberstab in die Jeans und versuchte, eine ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Unschuldsmiene aufzusetzen. ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 190,
#    'flags': 4}],
#  [{'text': '»Wunderbarer Abend!«, rief Onkel Vernon und winkte Mrs. ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Nummer sieben von gegenüber zu, die durch ihre Netzvorhänge böse ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'herüberfunkelte. »Haben Sie eben diesen Auspuffknall gehört? Hat ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Petunia und mir einen schönen Schreck eingejagt!« ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 286,
#    'flags': 4}],
#  [{'text': 'Er grinste unentwegt auf schreckliche, besessene Art umher, bis all ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'die neugierigen Nachbarn von ihren Fenstern verschwunden waren, ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'dann winkte er Harry zu sich heran, und aus dem Grinsen wurde eine ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'wutentbrannte Grimasse. ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 171,
#    'flags': 4}],
#  [{'text': 'Harry trat ein paar Schritte näher und achtete darauf, kurz vor dem ',
#    'size': 11,
#    'y_org': 290,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Punkt Halt zu machen, an dem Onkel Vernons ausgestreckte Hände ',
#    'size': 11,
#    'y_org': 303,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'ihn wieder würgen konnten. ',
#    'size': 11,
#    'y_org': 316,
#    'x_end': 184,
#    'flags': 4}],
#  [{'text': '»Was zum Teufel soll das, Bursche?«, fragte Onkel Vernon mit ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'heiserer, vor Wut zitternder Stimme. ',
#    'size': 11,
#    'y_org': 346,
#    'x_end': 221,
#    'flags': 4}],
#  [{'text': '»Was soll was?«, sagte Harry kühl. Er blickte unablässig links und ',
#    'size': 11,
#    'y_org': 365,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'rechts ', 'size': 11, 'y_org': 378, 'x_end': 86, 'flags': 4},
#   {'text': 'die ', 'size': 11, 'y_org': 378, 'x_end': 111, 'flags': 4},
#   {'text': 'Straße ', 'size': 11, 'y_org': 378, 'x_end': 151, 'flags': 4},
#   {'text': 'entlang, ', 'size': 11, 'y_org': 378, 'x_end': 197, 'flags': 4},
#   {'text': 'immer ', 'size': 11, 'y_org': 378, 'x_end': 238, 'flags': 4},
#   {'text': 'noch ', 'size': 11, 'y_org': 378, 'x_end': 271, 'flags': 4},
#   {'text': 'in ', 'size': 11, 'y_org': 378, 'x_end': 292, 'flags': 4},
#   {'text': 'der ', 'size': 11, 'y_org': 378, 'x_end': 317, 'flags': 4},
#   {'text': 'Hoffnung ', 'size': 11, 'y_org': 378, 'x_end': 372, 'flags': 4}],
#  [{'text': 'herauszufinden, von wem der Knall stammte. ',
#    'size': 11,
#    'y_org': 390,
#    'x_end': 260,
#    'flags': 4}],
#  [{'text': '»Einen Lärm machen, als ginge eine Pistole los, und das direkt vor ',
#    'size': 11,
#    'y_org': 409,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'unserem …« ', 'size': 11, 'y_org': 422, 'x_end': 117, 'flags': 4}],
#  [{'text': '»Den Lärm hab ich nicht gemacht«, sagte Harry entschieden. ',
#    'size': 11,
#    'y_org': 441,
#    'x_end': 344,
#    'flags': 4}],
#  [{'text': 'Neben Onkel Vernons breitem, puterrotem Gesicht tauchte jetzt ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Tante Petunias schmales Pferdegesicht auf. Sie war aschgrau. ',
#    'size': 11,
#    'y_org': 472,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': '»Warum hast du unter unserem Fenster herumgelungert?« ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': '»Ja – ja, gute Frage, Petunia! Was hast du unter unserem ',
#    'size': 11,
#    'y_org': 509,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Fenstergetrieben, Bursche?« ',
#    'size': 11,
#    'y_org': 522,
#    'x_end': 186,
#    'flags': 4}],
#  [{'text': '»Die Nachrichten gehört«, sagte Harry mit resignierter Stimme. ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 355,
#    'flags': 4}],
#  [{'text': 'Tante und Onkel tauschten empörte Blicke. ',
#    'size': 11,
#    'y_org': 82,
#    'x_end': 265,
#    'flags': 4}],
#  [{'text': '»Die Nachrichten gehört! ',
#    'size': 11,
#    'y_org': 101,
#    'x_end': 187,
#    'flags': 4},
#   {'text': 'Schon wieder', 'size': 11, 'y_org': 101, 'x_end': 247, 'flags': 6},
#   {'text': '?« ', 'size': 11, 'y_org': 101, 'x_end': 260, 'flags': 4}],
#  [{'text': '»Na ja, es gibt doch jeden Tag neue, oder?«, sagte Harry. ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 328,
#    'flags': 4}],
#  [{'text': '»Spiel mir hier nicht den Neunmalklugen, Bursche! Ich will ',
#    'size': 11,
#    'y_org': 138,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'wissen, was du wirklich im Schilde führst – und hör mir bloß auf mit ',
#    'size': 11,
#    'y_org': 150,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'diesem Quatsch von wegen ',
#    'size': 11,
#    'y_org': 163,
#    'x_end': 182,
#    'flags': 4},
#   {'text': 'die Nachrichten hören',
#    'size': 11,
#    'y_org': 163,
#    'x_end': 287,
#    'flags': 6},
#   {'text': '! Du weißt genau, ',
#    'size': 11,
#    'y_org': 163,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dass ', 'size': 11, 'y_org': 176, 'x_end': 79, 'flags': 4},
#   {'text': 'deine Sippschaft ',
#    'size': 11,
#    'y_org': 176,
#    'x_end': 154,
#    'flags': 6},
#   {'text': '…« ', 'size': 11, 'y_org': 176, 'x_end': 174, 'flags': 4}],
#  [{'text': '»Vorsicht, Vernon!«, hauchte Tante Petunia, und Onkel Vernon ',
#    'size': 11,
#    'y_org': 195,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'senkte die Stimme, bis Harry ihn kaum noch hören konnte – »dass ',
#    'size': 11,
#    'y_org': 208,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'deine Sippschaft ',
#    'size': 11,
#    'y_org': 220,
#    'x_end': 132,
#    'flags': 6},
#   {'text': 'nicht in ', 'size': 11, 'y_org': 220, 'x_end': 167, 'flags': 4},
#   {'text': 'unsere ', 'size': 11, 'y_org': 220, 'x_end': 201, 'flags': 6},
#   {'text': 'Nachrichten kommt!« ',
#    'size': 11,
#    'y_org': 220,
#    'x_end': 300,
#    'flags': 4}],
#  [{'text': '»Das meinst du wohl«, sagte Harry. ',
#    'size': 11,
#    'y_org': 239,
#    'x_end': 233,
#    'flags': 4}],
#  [{'text': 'Die Dursleys glotzten ihn ein paar Sekunden an, dann schimpfte ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Tante Petunia: »Du bist ein gemeiner kleiner Lügner. Was treiben ',
#    'size': 11,
#    'y_org': 270,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'denn all diese …«, auch sie senkte die Stimme, so dass Harry das ',
#    'size': 11,
#    'y_org': 282,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'nächste Wort von ihren Lippen ablesen musste, »… ',
#    'size': 11,
#    'y_org': 295,
#    'x_end': 291,
#    'flags': 4},
#   {'text': 'Eulen ', 'size': 11, 'y_org': 295, 'x_end': 322, 'flags': 6},
#   {'text': 'hier, wenn ', 'size': 11, 'y_org': 295, 'x_end': 371, 'flags': 4}],
#  [{'text': 'sie dir keine Nachrichten bringen?« ',
#    'size': 11,
#    'y_org': 308,
#    'x_end': 217,
#    'flags': 4}],
#  [{'text': '»Aha!«, flüsterte Onkel Vernon triumphierend. »Jetzt lass dir dazu ',
#    'size': 11,
#    'y_org': 327,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'mal eine Ausrede einfallen, Bursche! Als ob wir nicht wüssten, dass ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'du deine ganzen Nachrichten von diesen ekelhaften Vögeln ',
#    'size': 11,
#    'y_org': 352,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'bekommst!« ', 'size': 11, 'y_org': 364, 'x_end': 115, 'flags': 4}],
#  [{'text': 'Harry zögerte einen Moment. Es kostete ihn einige Überwindung, ',
#    'size': 11,
#    'y_org': 383,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'diesmal die Wahrheit zu sagen, obwohl Onkel und Tante unmöglich ',
#    'size': 11,
#    'y_org': 396,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wissen konnten, wie schlimm es für ihn war, sie einzugestehen. ',
#    'size': 11,
#    'y_org': 408,
#    'x_end': 340,
#    'flags': 4}],
#  [{'text': '»Die Eulen … bringen mir keine Nachrichten«, antwortete er ',
#    'size': 11,
#    'y_org': 427,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'tonlos. ', 'size': 11, 'y_org': 440, 'x_end': 89, 'flags': 4}],
#  [{'text': '»Das glaub ich nicht«, sagte Tante Petunia sofort. ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 293,
#    'flags': 4}],
#  [{'text': '»Und ich auch nicht«, bestätigte Onkel Vernon. ',
#    'size': 11,
#    'y_org': 477,
#    'x_end': 284,
#    'flags': 4}],
#  [{'text': '»Wir wissen, dass du irgendein krummes Ding vorhast«, sagte ',
#    'size': 11,
#    'y_org': 496,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Tante Petunia. ',
#    'size': 11,
#    'y_org': 508,
#    'x_end': 124,
#    'flags': 4}],
#  [{'text': '»Wir sind schließlich nicht blöde, verstehst du«, sagte Onkel ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Vernon. ', 'size': 11, 'y_org': 76, 'x_end': 96, 'flags': 4}],
#  [{'text': '»Na, ', 'size': 11, 'y_org': 95, 'x_end': 95, 'flags': 4},
#   {'text': 'das ', 'size': 11, 'y_org': 95, 'x_end': 120, 'flags': 6},
#   {'text': "ist ja mal 'ne Neuigkeit«, erwiderte Harry mit ",
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'anschwellendem Zorn, und bevor die Dursleys ihn zurückrufen ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'konnten, wirbelte er herum, lief über den Rasen, sprang über die ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'niedrige Gartenmauer und ging mit großen Schritten die Straße ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'entlang davon. ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 124,
#    'flags': 4}],
#  [{'text': 'Das gab Ärger, so viel war sicher. Er würde Onkel und Tante ',
#    'size': 11,
#    'y_org': 164,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'später Rede und Antwort stehen und für seine Frechheit bezahlen ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'müssen, doch fürs Erste war ihm das ziemlich schnuppe; er hatte viel ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dringendere Angelegenheiten im Kopf. ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 232,
#    'flags': 4}],
#  [{'text': 'Harry war sich sicher, dass der Knall von jemandem herrührte, der ',
#    'size': 11,
#    'y_org': 221,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'appariert oder disappariert war. Es war genau das Geräusch, das ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Dobby der Hauself machte, wenn er ins Blaue hinein verschwand. ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Konnte Dobby denn hier im Ligusterweg sein? Folgte ihm Dobby ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'vielleicht genau in diesem Moment? Bei diesem Gedanken schnellte ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'er herum und spähte zurück, doch der Ligusterweg schien ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'vollkommen ausgestorben, und Harry war sicher, dass Dobby nicht ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wusste, wie man sich unsichtbar machte. ',
#    'size': 11,
#    'y_org': 310,
#    'x_end': 240,
#    'flags': 4}],
#  [{'text': 'Er ging weiter und achtete dabei kaum auf den Weg, den er ',
#    'size': 11,
#    'y_org': 328,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'einschlug, denn er hatte diese Straßen in letzter Zeit so oft ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'durchstreift, dass ihn seine Füße wie von allein zu seinen ',
#    'size': 11,
#    'y_org': 353,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Lieblingsplätzen trugen. Alle paar Schritte warf er einen Blick über ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'die Schulter. Ein magisches Wesen hatte sich in seiner Nähe ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'aufgehalten, als er zwischen Tante Petunias sterbenden Begonien ',
#    'size': 11,
#    'y_org': 391,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'gelegen hatte, das war sicher. Warum hatte es ihn nicht angesprochen, ',
#    'size': 11,
#    'y_org': 404,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'warum hatte es keine Verbindung aufgenommen, warum versteckte es ',
#    'size': 11,
#    'y_org': 417,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'sich jetzt? ',
#    'size': 11,
#    'y_org': 429,
#    'x_end': 104,
#    'flags': 4}],
#  [{'text': 'Und dann, als seine Enttäuschung ihren Höhepunkt erreicht hatte, ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'schwand plötzlich diese Gewissheit. ',
#    'size': 11,
#    'y_org': 460,
#    'x_end': 219,
#    'flags': 4}],
#  [{'text': 'Vielleicht war es doch kein magisches Geräusch gewesen. ',
#    'size': 11,
#    'y_org': 479,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Vielleicht wartete er nur so verzweifelt auf das kleinste Zeichen aus ',
#    'size': 11,
#    'y_org': 492,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'einer Welt, in die er gehörte, dass er bei ganz gewöhnlichen ',
#    'size': 11,
#    'y_org': 504,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Geräuschen einfach überreagierte. Konnte er sicher sein, dass der ',
#    'size': 11,
#    'y_org': 517,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Lärm nicht daher rührte, dass in einem Nachbarhaus etwas zu Bruch ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'gegangen war? ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 127,
#    'flags': 4}],
#  [{'text': 'Harry hatte ein dumpfes, flaues Gefühl im Magen, und ',
#    'size': 11,
#    'y_org': 95,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'unversehens überfiel ihn wieder die Hoffnungslosigkeit, die ihn den ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'ganzen Sommer über geplagt hatte. ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 216,
#    'flags': 4}],
#  [{'text': 'Morgen früh um fünf würde der Wecker ihn aus dem Schlaf reißen, ',
#    'size': 11,
#    'y_org': 138,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'damit er die Eule bezahlen konnte, die ihm den ',
#    'size': 11,
#    'y_org': 151,
#    'x_end': 294,
#    'flags': 4},
#   {'text': 'Tagespropheten ',
#    'size': 11,
#    'y_org': 151,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'brachte – aber hatte es noch einen Zweck, ihn weiter zu beziehen? ',
#    'size': 11,
#    'y_org': 164,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Harry schaute dieser Tage nur kurz auf die Titelseite und warf ihn ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'dann beiseite; wenn diese Trottel von der Zeitung endlich erkannt ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hatten, dass Voldemort zurück war, würde das Schlagzeilen machen, ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'und nur solche Nachrichten scherten Harry. ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 253,
#    'flags': 4}],
#  [{'text': 'Zwar kamen, wenn er Glück hatte, auch Eulen mit Briefen von ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'seinen besten Freunden Ron und Hermine, aber all seine Erwartungen, ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'dass ihre Briefe Neuigkeiten für ihn enthalten würden, waren schon ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'lange zunichte. ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 127,
#    'flags': 4}],
#  [{'text': 'Wir können nicht viel über Du-weißt-schon-was sagen, verstehst ',
#    'size': 11,
#    'y_org': 290,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'du … Man hat uns gesagt, dass wir nichts Wichtiges schreiben dürfen, ',
#    'size': 11,
#    'y_org': 303,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'falls unsere Briefe in die falschen Hände gelangen … Wir sind ',
#    'size': 11,
#    'y_org': 316,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'ziemlich beschäftigt, aber ich kann dir hier nichts Genaues schreiben ',
#    'size': 11,
#    'y_org': 328,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': '… Es geht einiges ab, wir erzählen dir alles, wenn wir dich treffen … ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 365,
#    'flags': 6}],
#  [{'text': 'Aber wann würden sie ihn treffen? Niemand schien sich groß um ',
#    'size': 11,
#    'y_org': 359,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'einen festen Termin zu kümmern. ',
#    'size': 11,
#    'y_org': 372,
#    'x_end': 223,
#    'flags': 4},
#   {'text': 'Ich denke, wir besuchen dich ',
#    'size': 11,
#    'y_org': 372,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'ziemlich bald, ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 124,
#    'flags': 6},
#   {'text': 'hatte Hermine auf seine Geburtstagskarte geschrieben, ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'aber wie bald war bald? Soviel Harry aus den vagen Hinweisen in ',
#    'size': 11,
#    'y_org': 397,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'ihren Briefen schließen konnte, waren Hermine und Ron am selben ',
#    'size': 11,
#    'y_org': 410,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Ort, vermutlich im Haus von Rons Eltern. Er konnte es kaum ertragen, ',
#    'size': 11,
#    'y_org': 423,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'daran zu denken, wie die beiden im Fuchsbau ihren Spaß hatten, ',
#    'size': 11,
#    'y_org': 435,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'während er im Ligusterweg festsaß. Tatsächlich war er so sauer auf ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sie, dass er die beiden Schachteln mit Schokolade aus dem ',
#    'size': 11,
#    'y_org': 460,
#    'x_end': 320,
#    'flags': 4},
#   {'text': 'Honigtopf, ', 'size': 11, 'y_org': 460, 'x_end': 372, 'flags': 6}],
#  [{'text': 'die sie ihm zum Geburtstag geschickt hatten, ungeöffnet weggeworfen ',
#    'size': 11,
#    'y_org': 473,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'hatte. Später hatte er es bereut, nach dem welken Salat, den Tante ',
#    'size': 11,
#    'y_org': 486,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Petunia am selben Abend noch zum Essen aufgetischt hatte. ',
#    'size': 11,
#    'y_org': 498,
#    'x_end': 325,
#    'flags': 4}],
#  [{'text': 'Womit waren Ron und Hermine eigentlich so beschäftigt? Und ',
#    'size': 11,
#    'y_org': 517,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'warum war er, Harry, nicht beschäftigt? Hatte er nicht bewiesen, dass ',
#    'size': 11,
#    'y_org': 530,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'er mit viel mehr fertig werden konnte als sie? Hatten sie alle ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'vergessen, was er getan hatte? War es nicht er gewesen, der diesen ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Friedhof betreten und gesehen hatte, wie Cedric ermordet wurde, und ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'der an diesen Grabstein gefesselt wurde und fast umgebracht worden ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wäre? ', 'size': 11, 'y_org': 114, 'x_end': 87, 'flags': 4}],
#  [{'text': 'Denk nicht drüber nach, ermahnte sich Harry streng und zum ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'hundertsten Mal in diesem Sommer. Schlimm genug, dass er den ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Friedhof in seinen Alpträumen immer wieder besuchte, da brauchte er ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'in seinen wachen Momenten nicht auch noch darüber nachzubrüten. ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 360,
#    'flags': 4}],
#  [{'text': 'Er bog um eine Ecke und war nun auf dem Magnolienring; auf ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'halbem Weg die Straße entlang kam er an der schmalen Gasse vorbei, ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'die an einer Garage entlangführte und in der er zum ersten Mal seinen ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Paten gesehen hatte. Sirius zumindest schien zu verstehen, wie Harry ',
#    'size': 11,
#    'y_org': 228,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sich fühlte. Zugegeben, seine Briefe enthielten ebenso wenig ',
#    'size': 11,
#    'y_org': 240,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'handfeste Neuigkeiten wie die von Ron und Hermine, aber wenigstens ',
#    'size': 11,
#    'y_org': 252,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'schrieb er ihm zur Vorsicht mahnende und tröstende Worte statt ',
#    'size': 11,
#    'y_org': 265,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'quälender Andeutungen: Ich weiß, das muss frustrierend für dich sein ',
#    'size': 11,
#    'y_org': 278,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '… Halt die Ohren steif dann wird schon alles gut gehen … Sei ',
#    'size': 11,
#    'y_org': 291,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'vorsichtig und tu nichts Unbesonnenes … ',
#    'size': 11,
#    'y_org': 304,
#    'x_end': 244,
#    'flags': 4}],
#  [{'text': 'Immerhin, dachte Harry, während er den Magnolienring ',
#    'size': 11,
#    'y_org': 322,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'überquerte, in die Magnolienstraße einbog und auf den nun schon im ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Dunkeln liegenden Park mit dem Spielplatz zuging, immerhin hatte er ',
#    'size': 11,
#    'y_org': 347,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '(im Wesentlichen) befolgt, was Sirius ihm geraten hatte. Zumindest ',
#    'size': 11,
#    'y_org': 360,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hatte er der Versuchung widerstanden, den Koffer an seinen Besen zu ',
#    'size': 11,
#    'y_org': 372,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'binden und sich auf eigene Faust auf die Reise zum Fuchsbau zu ',
#    'size': 11,
#    'y_org': 385,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'machen. Im Grunde hatte er sich sehr gut verhalten, wenn er ',
#    'size': 11,
#    'y_org': 398,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'überlegte, wie enttäuscht und zornig er darüber war, so lange im ',
#    'size': 11,
#    'y_org': 411,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Ligusterweg festzusitzen, wo er nichts weiter unternehmen konnte, als ',
#    'size': 11,
#    'y_org': 423,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'sich in Blumenbeeten zu verstecken, in der Hoffnung, einen Hinweis ',
#    'size': 11,
#    'y_org': 436,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'darauf zu erlauschen, was Lord Voldemort gerade machte. Dennoch ',
#    'size': 11,
#    'y_org': 448,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'wurmte es ihn, dass ihn ausgerechnet ein Mann vor Unbesonnenheiten ',
#    'size': 11,
#    'y_org': 461,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'warnte, der zwölf Jahre im Zauberergefängnis von Askaban gesessen ',
#    'size': 11,
#    'y_org': 474,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'hatte, der entkommen war, daraufhin den Mord begehen wollte, für ',
#    'size': 11,
#    'y_org': 486,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'den man ihn ursprünglich verurteilt hatte, und schließlich mit einem ',
#    'size': 11,
#    'y_org': 499,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'gestohlenen Hippogreif geflohen war. ',
#    'size': 11,
#    'y_org': 512,
#    'x_end': 227,
#    'flags': 4}],
#  [{'text': 'Harry schwang sich über das geschlossene Parktor und überquerte ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'den verdorrten Rasen. Der Park war so menschenleer wie die Straßen ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'in der Nachbarschaft. Er erreichte die Schaukeln und ließ sich auf ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'einer davon nieder, der letzten, die Dudley und seine Freunde noch ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'nicht demoliert hatten, schlang einen Arm um die Kette und starrte ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'trübsinnig auf die Erde. Im Blumenbeet der Dursleys würde er sich ',
#    'size': 11,
#    'y_org': 126,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'nicht mehr verstecken können. Morgen musste er sich etwas Neues ',
#    'size': 11,
#    'y_org': 139,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'einfallen lassen, wie er die Nachrichten hören konnte. Bis dahin hatte ',
#    'size': 11,
#    'y_org': 152,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'er nichts, auf das er sich freuen konnte, nur eine weitere unruhige, ',
#    'size': 11,
#    'y_org': 165,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sorgenvoll durchwälzte Nacht, denn selbst wenn er von Alpträumen ',
#    'size': 11,
#    'y_org': 178,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'um Cedric verschont blieb, plagten ihn schreckliche Träume von ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'langen schwarzen Korridoren, die alle an Mauern und verschlossenen ',
#    'size': 11,
#    'y_org': 203,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Türen endeten, was, wie er vermutete, etwas zu tun hatte mit dem ',
#    'size': 11,
#    'y_org': 216,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Gefühl, in der Falle zu sitzen, das ihn am Tage quälte. Seine alte ',
#    'size': 11,
#    'y_org': 228,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Stirnnarbe ziepte oft unangenehm, aber Ron oder Hermine oder Sirius, ',
#    'size': 11,
#    'y_org': 240,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'da machte er sich nichts vor, würden dies nicht mehr sonderlich ',
#    'size': 11,
#    'y_org': 253,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'spannend finden. Früher hatten ihn die Narbenschmerzen gewarnt, ',
#    'size': 11,
#    'y_org': 266,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'wenn Voldemort wieder stärker wurde, doch nun, da Voldemort ',
#    'size': 11,
#    'y_org': 279,
# ...
#  [{'text': 'Pergamentumschlag, den sie im Schnabel trug, zu Harrys Füßen ',
#    'size': 11,
#    'y_org': 421,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'fallen, legte eine elegante Kurve hin, wobei sie mit den Flügelspitzen ',
#    'size': 11,
#    'y_org': 434,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'sacht den Kühlschrank streifte, sauste wieder hinaus und entschwand ',
#    'size': 11,
#    'y_org': 447,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'über dem Garten. ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 137,
#    'flags': 4}],
#  [{'text': '»EULEN!«, bellte Onkel Vernon, und die schwer mitgenommene ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Ader an seiner Schläfe pulsierte zornig, während er das Küchenfenster ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'zuschlug. »SCHON WIEDER EULEN! ICH DULDE KEINE EULEN ',
#    'size': 11,
#    'y_org': 503,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'MEHR IN MEINEM HAUS!« ',
#    'size': 11,
#    'y_org': 516,
#    'x_end': 196,
#    'flags': 4}],
#  [{'text': 'Doch Harry, dem das Herz irgendwo in der Gegend des ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Adamsapfels pochte, riss bereits den Umschlag auf und zog den Brief ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'heraus. ', 'size': 11, 'y_org': 89, 'x_end': 92, 'flags': 4}],
#  [{'text': 'Sehr geehrter Mr. Potter, wir haben Information erhalten, wonach ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Sie den Patronus-Zauber heute Abend um dreiundzwanzig Minuten ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'nach neun in einem Muggelwohngebiet und in Gegenwart eines ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Muggels ausgeführt haben. ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 180,
#    'flags': 4}],
#  [{'text': 'Die Schwere dieser Verletzung des Erlasses zur Vernunftgemäßen ',
#    'size': 11,
#    'y_org': 164,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Beschränkung der Zauberei Minderjähriger hat zu Ihrem Verweis von ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'der Hogwarts-Schule für Hexerei und Zauberei geführt. Beauftragte ',
#    'size': 11,
#    'y_org': 190,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'des Ministeriums werden Sie unverzüglich an Ihrem Wohnort ',
#    'size': 11,
#    'y_org': 202,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'aufsuchen, um Ihren Zauberstab zu zerstören. ',
#    'size': 11,
#    'y_org': 215,
#    'x_end': 262,
#    'flags': 4}],
#  [{'text': 'Da Sie bereits eine offizielle Verwarnung aufgrund eines früheren ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Vergehens gemäß Abschnitt 13 des Geheimhaltungsabkommens der ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Internationalen Zauberervereinigung erhalten haben, bedauern wir ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Ihnen mitteilen zu müssen, dass Ihre Anwesenheit bei einer ',
#    'size': 11,
#    'y_org': 271,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'disziplinarischen Anhörung im Zaubereiministerium am zwölften ',
#    'size': 11,
#    'y_org': 284,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'August um neun Uhr verlangt ist. ',
#    'size': 11,
#    'y_org': 297,
#    'x_end': 207,
#    'flags': 4}],
#  [{'text': 'In der Hoffnung, dass Sie wohlauf sind, ',
#    'size': 11,
#    'y_org': 316,
#    'x_end': 249,
#    'flags': 4}],
#  [{'text': 'mit freundlichen Grüßen ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 184,
#    'flags': 4}],
#  [{'text': 'Mafalda Hopfkirch ',
#    'size': 11,
#    'y_org': 352,
#    'x_end': 160,
#    'flags': 6}],
#  [{'text': 'Abteilung für unbefugte Zauberei ',
#    'size': 11,
#    'y_org': 371,
#    'x_end': 223,
#    'flags': 4}],
#  [{'text': 'Zaubereiministerium ',
#    'size': 11,
#    'y_org': 390,
#    'x_end': 166,
#    'flags': 4}],
#  [{'text': 'Harry las den Brief zweimal durch. Nur verschwommen nahm er ',
#    'size': 11,
#    'y_org': 408,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'wahr, dass Onkel Vernon und Tante Petunia redeten. In seinem Kopf ',
#    'size': 11,
#    'y_org': 421,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'war alles eisig und taub. Eine Tatsache hatte sich in sein Bewusstsein ',
#    'size': 11,
#    'y_org': 434,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'gebohrt wie ein lähmender Pfeil. Sie hatten ihn von Hogwarts ',
#    'size': 11,
#    'y_org': 447,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'verwiesen. Alles war zu Ende. Er würde nie zurückkehren. ',
#    'size': 11,
#    'y_org': 459,
#    'x_end': 319,
#    'flags': 4}],
#  [{'text': 'Er blickte zu den Dursleys hoch. Onkel Vernon, purpurrot im ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Gesicht, die Fäuste immer noch gereckt, schrie andauernd; Tante ',
#    'size': 11,
#    'y_org': 490,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Petunia hatte die Arme um Dudley gelegt, der von neuem würgte. ',
#    'size': 11,
#    'y_org': 503,
#    'x_end': 350,
#    'flags': 4}],
#  [{'text': 'Harrys zeitweilig betäubtes Gehirn schien wieder zu erwachen. ',
#    'size': 11,
#    'y_org': 522,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Beauftragte des Ministeriums werden Sie unverzüglich an Ihrem ',
#    'size': 11,
#    'y_org': 534,
#    'x_end': 372,
#    'flags': 6}],
#  [{'text': 'Wohnort aufsuchen, um Ihren Zauberstab zu zerstören. ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 307,
#    'flags': 6},
#   {'text': 'Da gab es nur ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'eines. Er musste fliehen – und zwar sofort. Wohin, wusste Harry ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'nicht, doch so viel war sicher: Ob er in Hogwarts war oder nicht, ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'seinen Zauberstab brauchte er. Fast traumwandlerisch zog er ihn ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'heraus und wandte sich zum Gehen. ',
#    'size': 11,
#    'y_org': 114,
#    'x_end': 219,
#    'flags': 4}],
#  [{'text': '»Wo willst du hin?«, rief Onkel Vernon. Als Harry nicht ',
#    'size': 11,
#    'y_org': 132,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'antwortete, stampfte er durch die Küche und versperrte die Tür zum ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Flur. »Ich bin noch nicht fertig mit dir, Bursche!« ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 280,
#    'flags': 4}],
#  [{'text': '»Geh mir aus dem Weg«, sagte Harry leise. ',
#    'size': 11,
#    'y_org': 177,
#    'x_end': 267,
#    'flags': 4}],
#  [{'text': '»Du bleibst hier und erklärst, wie mein Sohn …« ',
#    'size': 11,
#    'y_org': 196,
#    'x_end': 291,
#    'flags': 4}],
#  [{'text': '»Wenn du nicht aus dem Weg gehst, verhex ich dich«, sagte Harry ',
#    'size': 11,
#    'y_org': 214,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'und hob den Zauberstab. ',
#    'size': 11,
#    'y_org': 227,
#    'x_end': 169,
#    'flags': 4}],
#  [{'text': '»Darauf fall ich nicht rein!«, schnarrte Onkel Vernon. »Ich weiß, ',
#    'size': 11,
#    'y_org': 246,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'dass du ihn nicht außerhalb dieser Beklopptenanstalt benutzen darfst, ',
#    'size': 11,
#    'y_org': 258,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'die ihr Schule nennt!« ',
#    'size': 11,
#    'y_org': 270,
#    'x_end': 157,
#    'flags': 4}],
#  [{'text': '»Die Beklopptenanstalt hat mich rausgeschmissen«, sagte Harry. ',
#    'size': 11,
#    'y_org': 289,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': '»Also kann ich tun, was ich will. Du hast drei Sekunden. Eins – zwei ',
#    'size': 11,
#    'y_org': 302,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': '…« ', 'size': 11, 'y_org': 315, 'x_end': 77, 'flags': 4}],
#  [{'text': 'Ein schallender KNALL erfüllte die Küche. Tante Petunia ',
#    'size': 11,
#    'y_org': 334,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'kreischte, Onkel Vernon schrie und duckte sich, und zum dritten Mal ',
#    'size': 11,
#    'y_org': 346,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'an diesem Abend suchte Harry nach dem Ursprung eines Lärms, den ',
#    'size': 11,
#    'y_org': 358,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'er nicht verursacht hatte. Er sah ihn sofort: Eine Schleiereule saß ',
#    'size': 11,
#    'y_org': 371,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'draußen auf dem Küchenfenstersims, benommen und zerzaust, da sie ',
#    'size': 11,
#    'y_org': 384,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'eben gegen das geschlossene Fenster gekracht war. ',
#    'size': 11,
#    'y_org': 396,
#    'x_end': 286,
#    'flags': 4}],
#  [{'text': 'Harry stürmte durch die Küche, ohne auf Onkel Vernons ',
#    'size': 11,
#    'y_org': 415,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'ängstlichen »EULEN!«-Schrei zu achten, und riss das Fenster auf. Die ',
#    'size': 11,
#    'y_org': 428,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Eule streckte ihr Bein vor, an das eine kleine Pergamentrolle ',
#    'size': 11,
#    'y_org': 441,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'gebunden war, schüttelte die Federn und flog davon, kaum dass Harry ',
#    'size': 11,
#    'y_org': 453,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'den Brief geborgen hatte. Mit zitternden Händen entrollte er die ',
#    'size': 11,
#    'y_org': 466,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'zweite Botschaft, die sehr hastig und verkleckst in schwarzer Tinte ',
#    'size': 11,
#    'y_org': 478,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'geschrieben war. ',
#    'size': 11,
#    'y_org': 491,
#    'x_end': 135,
#    'flags': 4}],
#  [{'text': 'Harry … ', 'size': 11, 'y_org': 510, 'x_end': 115, 'flags': 4}],
#  [{'text': 'Dumbledore ist eben im Ministerium eingetroffen und versucht, ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'alles wieder ms Lot zu bringen. VERLASS DAS HAUS VON ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'TANTE UND ONKEL NICHT. GEBRAUCH KEINEN ZAUBER ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'MEHR. GIB DEINEN ZAUBERSTAB NICHT AB. Arthur Weasley. ',
#    'size': 11,
#    'y_org': 102,
#    'x_end': 367,
#    'flags': 4}],
#  [{'text': 'Dumbledore versuchte alles wieder ins Lot zu bringen … was ',
#    'size': 11,
#    'y_org': 120,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'sollte ', 'size': 11, 'y_org': 132, 'x_end': 83, 'flags': 4},
#   {'text': 'das ', 'size': 11, 'y_org': 132, 'x_end': 111, 'flags': 4},
#   {'text': 'heißen? ', 'size': 11, 'y_org': 132, 'x_end': 157, 'flags': 4},
#   {'text': 'Hatte ', 'size': 11, 'y_org': 132, 'x_end': 194, 'flags': 4},
#   {'text': 'Dumbledore ', 'size': 11, 'y_org': 132, 'x_end': 262, 'flags': 4},
#   {'text': 'Macht ', 'size': 11, 'y_org': 132, 'x_end': 302, 'flags': 4},
#   {'text': 'genug, ', 'size': 11, 'y_org': 132, 'x_end': 345, 'flags': 4},
#   {'text': 'das ', 'size': 11, 'y_org': 132, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Zaubereiministerium zum Rückzug zu zwingen? Gab es also eine ',
#    'size': 11,
#    'y_org': 145,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Chance, dass er doch nach Hogwarts zurück durfte? Ein kleiner ',
#    'size': 11,
#    'y_org': 158,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Hoffnungsfunke flammte in Harrys Brust auf, gleich wieder erstickt ',
#    'size': 11,
#    'y_org': 171,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'von Panik – wie sollte er sich weigern, seinen Zauberstab abzugeben, ',
#    'size': 11,
#    'y_org': 184,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'ohne einen Zauber zu gebrauchen? Er würde sich mit den ',
#    'size': 11,
#    'y_org': 196,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'Ministeriumsleuten duellieren müssen, und wenn er das tat, konnte er ',
#    'size': 11,
#    'y_org': 209,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'von Glück reden, wenn sie ihn nicht nach Askaban steckten, vom ',
#    'size': 11,
#    'y_org': 222,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Rauswurf ganz zu schweigen. ',
#    'size': 11,
#    'y_org': 234,
#    'x_end': 191,
#    'flags': 4}],
#  [{'text': 'Seine Gedanken rasten … er konnte fliehen und dabei Gefahr ',
#    'size': 11,
#    'y_org': 252,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'laufen, vom Ministerium geschnappt zu werden, oder aber bleiben und ',
#    'size': 11,
#    'y_org': 265,
#    'x_end': 372,
#    'flags': 4}],
#  [{'text': 'warten, bis sie ihn hier kriegten. Dann lieber fliehen, aber er wusste, ',
#    'size': 11,
#    'y_org': 278,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'dass Mr. Weasley nur sein Bestes am Herzen lag … und schließlich ',
#    'size': 11,
#    'y_org': 291,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'hatte Dumbledore schon viel Schlimmeres wieder eingerenkt. ',
#    'size': 11,
#    'y_org': 304,
#    'x_end': 331,
#    'flags': 4}],
#  [{'text': "»Na gut«, sagte Harry. »Ich hab's mir anders überlegt. Ich bleibe.« ",
#    'size': 11,
#    'y_org': 322,
#    'x_end': 367,
#    'flags': 4}],
#  [{'text': 'Schwungvoll setzte er sich auf einen Stuhl am Küchentisch und sah ',
#    'size': 11,
#    'y_org': 340,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Dudley und Tante Petunia geradeheraus an. Den Dursleys schien es ',
#    'size': 11,
#    'y_org': 353,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'angesichts dieses plötzlichen Sinneswandels die Sprache verschlagen ',
#    'size': 11,
#    'y_org': 366,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'zu haben. Tante Petunia linste verzweifelt zu Onkel Vernon hinüber. ',
#    'size': 11,
#    'y_org': 378,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Die Ader an seiner roten Schläfe pochte heftiger denn je. ',
#    'size': 11,
#    'y_org': 391,
#    'x_end': 310,
#    'flags': 4}],
#  [{'text': '»Wo kommen all die verdammten Eulen her?«, knurrte er. ',
#    'size': 11,
#    'y_org': 410,
#    'x_end': 332,
#    'flags': 4}],
#  [{'text': '»Die erste war aus dem Zaubereiministerium, die kam mit dem ',
#    'size': 11,
#    'y_org': 429,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'Rauswurf«, sagte Harry gelassen. Er spitzte die Ohren, um etwaige ',
#    'size': 11,
#    'y_org': 441,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'Geräusche ', 'size': 11, 'y_org': 454, 'x_end': 106, 'flags': 4},
#   {'text': 'draußen ', 'size': 11, 'y_org': 454, 'x_end': 156, 'flags': 4},
#   {'text': 'zu ', 'size': 11, 'y_org': 454, 'x_end': 181, 'flags': 4},
#   {'text': 'hören. ', 'size': 11, 'y_org': 454, 'x_end': 223, 'flags': 4},
#   {'text': 'Vielleicht ', 'size': 11, 'y_org': 454, 'x_end': 281, 'flags': 4},
#   {'text': 'waren ', 'size': 11, 'y_org': 454, 'x_end': 322, 'flags': 4},
#   {'text': 'ja ', 'size': 11, 'y_org': 454, 'x_end': 344, 'flags': 4},
#   {'text': 'die ', 'size': 11, 'y_org': 454, 'x_end': 372, 'flags': 4}],
#  [{'text': 'Ministeriumsleute im Anmarsch, und es war einfacher und weniger ',
#    'size': 11,
#    'y_org': 466,
#    'x_end': 370,
#    'flags': 4}],
#  [{'text': 'lärmträchtig, Onkel Vernons Fragen zu beantworten, als ihn erneut in ',
#    'size': 11,
#    'y_org': 479,
#    'x_end': 371,
#    'flags': 4}],
#  [{'text': 'brüllende Rage zu versetzen. »Die zweite war vom Vater meines ',
#    'size': 11,
#    'y_org': 492,
#    'x_end': 369,
#    'flags': 4}],
#  [{'text': 'Freundes Ron, der im Ministerium arbeitet.« ',
#    'size': 11,
#    'y_org': 504,
#    'x_end': 256,
#    'flags': 4}],
#  [{'text': '»Zaubereiministerium?«, brüllte Onkel Vernon. »Leute wie ihr in ',
#    'size': 11,
#    'y_org': 64,
#    'x_end': 371,
#    'flags': 6}],
#  [{'text': 'der Regierung? Oh, das erklärt alles, alles, kein Wunder, dass das ',
#    'size': 11,
#    'y_org': 76,
#    'x_end': 370,
#    'flags': 6}],
#  [{'text': 'Land vor die Hunde geht.« ',
#    'size': 11,
#    'y_org': 89,
#    'x_end': 179,
#    'flags': 6}],
#  [{'text': 'Da Harry nicht antwortete, starrte ihn Onkel Vernon funkelnd vor ',
#    'size': 11,
#    'y_org': 108,
#    'x_end': 372,
#    'flags': 4}],
#  ...]

# %%
def lines_to_paragraphs(lines, text_size, end_pos):
    paragraphs = []
    current_paragraph_spans = []
    current_paragraph_size = lines[0][0]['size']
    for line in lines:

        # If a new size comes, create a new paragraph
        if not same(line[0]['size'], current_paragraph_size, UNCERTAINTY_SIZE):
            paragraphs.append({
                'size': current_paragraph_size,
                'spans': current_paragraph_spans
            })
            current_paragraph_spans = []
            current_paragraph_size = line[0]['size']
        
        # Add the spans to the current paragraph
        for span in line:
            current_paragraph_spans.append({
                'text': span['text'],
                'size': span['size'],
                'flags': span['flags']
            })

        # Remove '-' from line break if a word got cut
        if current_paragraph_spans[-1]['text'][-1] == '-':
            current_paragraph_spans[-1]['text'] = current_paragraph_spans[-1]['text'][:-1]
        elif current_paragraph_spans[-1]['text'][-1] != ' ':
            current_paragraph_spans[-1]['text'] = current_paragraph_spans[-1]['text'] + ' '

        # End the paragraph if the lines doesn't go until the end
        if line[-1]['x_end'] <= end_pos - UNCERTAINTY_END and line[0]['size'] <= text_size + UNCERTAINTY_SIZE:
            paragraphs.append({
                'size': current_paragraph_size,
                'spans': current_paragraph_spans
            })
            current_paragraph_spans = []
            current_paragraph_size = line[0]['size']
    
    # Add the last paragraph
    paragraphs.append({
        'size': current_paragraph_size,
        'spans': current_paragraph_spans
    })

    return paragraphs

# %%
ps = lines_to_paragraphs(lines, text_size, end_pos)
ps
# Out:
# [{'size': 20,
#   'spans': [{'text': 'Dudley umnachtet ', 'size': 20, 'flags': 20}]},
#  {'size': 11,
#   'spans': [{'text': 'Der bislang heißeste Tag des Sommers neigte sich dem Ende zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und eine schläfrige Stille lag über den großen wuchtigen Häusern des ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Ligusterwegs. Autos, die normalerweise glänzten, standen staubig in ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'den Einfahrten, und Rasenflächen, die einst smaragdgrün waren, lagen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'verdorrt und gelbstichig da – wegen der Dürre war es verboten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'worden, sie mit Gartenschläuchen zu wässern. Die Bewohner des ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Ligusterwegs, die sich nun nicht mehr wie üblich mit Autowaschen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und Rasenmähen die Zeit vertreiben konnten, hatten sich in die ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schatten ihrer kühlen Häuser zurückgezogen und die Fenster weit ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'aufgestoßen ', 'size': 11, 'flags': 4},
#    {'text': 'in ', 'size': 11, 'flags': 4},
#    {'text': 'der ', 'size': 11, 'flags': 4},
#    {'text': 'Hoffnung, ', 'size': 11, 'flags': 4},
#    {'text': 'eine ', 'size': 11, 'flags': 4},
#    {'text': 'vermeintliche ', 'size': 11, 'flags': 4},
#    {'text': 'Brise ', 'size': 11, 'flags': 4},
#    {'text': 'hereinzulocken. Der einzige Mensch, der noch draußen war, ein ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Teenager, lag in einem Blumenbeet vor Nummer vier flach auf dem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Rücken. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Es war ein schlaksiger, schwarzhaariger Junge mit Brille, der ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ausgezehrt und leicht ungesund wirkte wie jemand, der in kurzer Zeit ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'recht schnell gewachsen war. Seine Jeans war dreckig und zerrissen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sein T-Shirt ausgeleiert und verblichen, und die Sohlen seiner ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Turnschuhe schälten sich vom Oberleder. Harry Potters Äußeres ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'machte ihn nicht lieb Kind bei den Nachbarn, jener Sorte von ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Menschen, die meinten, Schmuddeligkeit gehöre gesetzlich bestraft, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'doch da er sich an diesem Abend hinter einem großen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Hortensienbusch versteckt hatte, war er für Passanten gänzlich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'unsichtbar. Tatsächlich konnten ihn nur Onkel Vernon und Tante ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Petunia sehen, falls sie die Köpfe aus dem Wohnzimmerfenster ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'streckten und senkrecht nach unten ins Blumenbeet schauten. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Alles in allem, dachte Harry, konnte man ihm zu seiner Idee, sich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hier zu verstecken, nur gratulieren. Vielleicht war es nicht sonderlich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'bequem, wie er da auf der heißen, harten Erde lag, doch immerhin ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'stierte ihn niemand finster an und knirschte so laut mit den Zähnen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dass er die Nachrichten nicht hören konnte, oder warf ihm gehässige ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Fragen an den Kopf, wie es noch jedes Mal geschehen war, wenn er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'versucht hatte, sich ins Wohnzimmer zu setzen und mit Tante und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Onkel fernzusehen. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Als wäre Harrys Gedanke durchs offene Fenster geflattert, fing ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Vernon Dursley, sein Onkel, plötzlich an zu reden. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Bin froh, dass der Bursche nicht mehr versucht, sich hier breit zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'machen. Übrigens, wo steckt er eigentlich?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Ich weiß es nicht«, sagte Tante Petunia beiläufig. »Nicht im Haus ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'jedenfalls.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Onkel Vernon grunzte. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Die Nachrichten gucken …«, höhnte er. »Möchte wissen, was er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wirklich im Schilde führt. Ein normaler Junge pfeift doch drauf, was ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'in den Nachrichten kommt – Dudley hat keine Ahnung, was in der ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Welt passiert. Bin mir nicht mal sicher, ob er weiß, wer der ',
#     'size': 11,
#     'flags': 4},
#    {'text': "Premierminister ist! Jedenfalls sieht's nicht so aus, als käme irgendwas ",
#     'size': 11,
#     'flags': 4},
#    {'text': 'über seine Sippschaft in unseren Nachrichten …« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Vernon, ', 'size': 11, 'flags': 4},
#    {'text': 'schhh!«, ', 'size': 11, 'flags': 6},
#    {'text': 'sagte Tante Petunia. »Das Fenster steht offen!« ',
#     'size': 11,
#     'flags': 4},
#    {'text': '»Oh – ja – Verzeihung, Liebling.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Die Dursleys verstummten. Harry lauschte einem Werbesong für ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Obst-und-Kleie-Frühstücksflocken, während er Mrs. Figg, eine ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schrullige alte Dame aus dem nahen Glyzinenweg, langsam ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vorbeitappen sah. Sie blickte finster drein und murmelte vor sich hin. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Harry war sehr froh, dass er hinter dem Busch versteckt lag, weil Mrs. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Figg ihn seit kurzem jedes Mal wenn sie ihn auf der Straße traf, zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sich nach Hause zum Tee einlud. Sie war um die Ecke gebogen und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'verschwunden, als Onkel Vernons Stimme erneut aus dem Fenster ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schwebte. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Duddy ist zum Tee eingeladen?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Bei den Polkissens«, sagte Tante Petunia liebevoll. »Er hat so ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'viele kleine Freunde, beliebt, wie er ist …« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Mit Mühe verkniff sich Harry ein Schnauben. Die Dursleys waren ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wirklich erstaunlich dumm, wenn es um ihren Sohn Dudley ging. All ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'seine fadenscheinigen Lügen, er wäre jeden Abend der Sommerferien ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'bei einem anderen Typen aus seiner Gang zum Tee, hatten sie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'geschluckt. Harry wusste genau, dass Dudley nirgends zum Tee war; ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er und seine Gang verbrachten jeden Abend damit, den Spielplatz im ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Park zu demolieren, an Straßenecken zu rauchen und Steine auf ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vorbeikommende Autos und Kinder zu werfen. Harry hatte sie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'während seiner abendlichen Streifzüge durch Little Whinging dabei ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'beobachtet; er hatte den größten Teil der Ferien damit verbracht, durch ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'die Straßen zu ziehen und unterwegs Zeitungen aus den Mülleimern ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'zu klauben. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Als die ersten Töne der Melodie für die Sieben-Uhr-Nachrichten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'an Harrys Ohr drangen, drehte sich ihm der Magen um. Vielleicht ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'heute Abend – nachdem er einen Monat gewartet hatte –, vielleicht ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'war es heute so weit. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Während der Streik der spanischen Gepäckabfertiger in die ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'zweite Woche geht, sitzen so viele Urlauber wie noch nie auf den ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'Flughäfen fest …« ', 'size': 11, 'flags': 6}]},
#  {'size': 11,
#   'spans': [{'text': '»Denen würde ich eine lebenslange Siesta verpassen, wenn du ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'mich fragst«, knurrte Onkel Vernon, kaum dass der Sprecher den Satz ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vollendet hatte, und doch: Draußen im Blumenbeet schien sich Harrys ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Magen wieder zu entspannen. Wenn irgendetwas passiert wäre, dann ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hätten sie es sicher als Erstes in den Nachrichten gebracht; Tod und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Zerstörung waren wichtiger als gestrandete Urlauber. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er atmete lange und ruhig aus und blickte in den strahlend blauen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Himmel. Diesen Sommer war es Tag für Tag das Gleiche gewesen: ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'die Spannung, die Erwartung, die zeitweilige Erleichterung und dann ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'erneut die wachsende Spannung … und stets drängender die Frage, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'warum ', 'size': 11, 'flags': 6},
#    {'text': 'noch nichts passiert war. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er lauschte weiter, nur für den Fall, dass es einen kleinen Hinweis ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gab, dessen ganze Bedeutung den Muggeln entging – ein rätselhaftes ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Verschwinden vielleicht, oder ein merkwürdiger Unfall … aber dem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Streik der Gepäckabfertiger folgte eine Meldung über die Dürre im ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Südosten Englands (»Hoffentlich hört der nebenan zu!«, bellte Onkel ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Vernon. »Der mit seinen Sprinklern, die er um drei Uhr morgens ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'anstellt!«), dann über einen Hubschrauber, der beinahe über einem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Feld in Surrey abgestürzt war, schließlich über die Scheidung einer ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'prominenten Schauspielerin von ihrem prominenten Mann (»Als ob ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wir an deren schmutzigen Affären interessiert wären«, naserümpfte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Tante Petunia, die diesen Fall in jeder Illustrierten, die ihr unter die ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'knochigen Finger kam, gebannt verfolgte). ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry schloss die Augen vor dem jetzt flammenden Abendhimmel, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'während der Sprecher sagte: ', 'size': 11, 'flags': 4},
#    {'text': '»— und schließlich hat Wally der ', 'size': 11, 'flags': 6},
#    {'text': 'Wellensittich sich etwas Neues einfallen lassen, wie er sich diesen ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'Sommer abkühlen kann. Wally, der auf den Five Feathers in Barnsley ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'lebt, hat Wasserski gelernt! Mary Dorkins hat sich dort für Sie ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'umgeschaut.« ', 'size': 11, 'flags': 6}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry öffnete die Augen. Wenn sie schon bei Wasserski fahrenden ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Wellensittichen waren, würde nichts Hörenswertes mehr kommen. Er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'drehte sich vorsichtig auf den Bauch und stemmte sich auf Knie und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Ellbogen, um unter dem Fenster wegzukriechen. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er hatte sich gerade mal fünf Zentimeter bewegt, als mehrere ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Dinge in sehr rascher Folge passierten. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Ein lauter, widerhallender ', 'size': 11, 'flags': 4},
#    {'text': 'Knall ', 'size': 11, 'flags': 6},
#    {'text': 'zerriss die schläfrige Stille wie ein ', 'size': 11, 'flags': 4},
#    {'text': 'Pistolenschuss; eine Katze sauste unter einem geparkten Wagen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hervor und stob davon; ein spitzer Schrei, ein gellender Fluch und das ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Geräusch ', 'size': 11, 'flags': 4},
#    {'text': 'von ', 'size': 11, 'flags': 4},
#    {'text': 'zerbrechendem ', 'size': 11, 'flags': 4},
#    {'text': 'Porzellan ', 'size': 11, 'flags': 4},
#    {'text': 'drangen ', 'size': 11, 'flags': 4},
#    {'text': 'aus ', 'size': 11, 'flags': 4},
#    {'text': 'dem ', 'size': 11, 'flags': 4},
#    {'text': 'Wohnzimmer der Dursleys. Als sei dies das Signal, auf das Harry ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gewartet hatte, schnellte er hoch und zog einen dünnen hölzernen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Zauberstab aus seinem Jeansbund wie ein Schwert aus der Scheide – ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'doch bevor er sich ganz aufrichten konnte, krachte er mit der ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schädeldecke gegen das offene Fenster der Dursleys. Es ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'rumste ', 'size': 11, 'flags': 6},
#    {'text': 'und ', 'size': 11, 'flags': 4},
#    {'text': 'Tante Petunia kreischte noch lauter. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry hatte das Gefühl, als wäre sein Kopf entzweigespalten. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schwankend, mit tränenden Augen, versuchte er den Blick auf die ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Straße zu richten, um die Quelle des Lärms auszumachen, doch kaum ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hatte er sich stolpernd erhoben, langten zwei große, purpurrote Hände ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'durchs offene Fenster und schlossen sich fest um seine Kehle. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Tu – das – Ding – weg!«, ', 'size': 11, 'flags': 6},
#    {'text': 'schnarrte Onkel Vernon in Harrys Ohr. ', 'size': 11, 'flags': 4},
#    {'text': '»Sofort! Bevor – es – jemand – sieht!« ',
#     'size': 11,
#     'flags': 6}]},
#  {'size': 11,
#   'spans': [{'text': '»Lass – mich – los!«, keuchte Harry. Einige Sekunden lang rangen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sie miteinander. Harry, der mit der rechten Hand den erhobenen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Zauberstab fest umklammerte, zog mit der linken an den Wurstfingern ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'seines Onkels; dann, in dem Moment, als der Schmerz an Harrys ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schädeldecke besonders fies pochte, japste Onkel Vernon plötzlich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und ließ Harry los, als ob er einen elektrischen Schlag bekommen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hätte. Eine unsichtbare Kraft schien durch seinen Neffen pulsiert zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sein, so dass er ihn unmöglich weiter festhalten konnte. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Keuchend fiel Harry bäuchlings über den Hortensienbusch, richtete ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sich auf und spähte umher. Was den lauten Knall verursacht haben ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'könnte, war nicht im Entferntesten zu erkennen, aber inzwischen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'lugten Gesichter aus einigen Fenstern in der Nachbarschaft. Harry ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'steckte hastig seinen Zauberstab in die Jeans und versuchte, eine ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Unschuldsmiene aufzusetzen. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wunderbarer Abend!«, rief Onkel Vernon und winkte Mrs. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Nummer sieben von gegenüber zu, die durch ihre Netzvorhänge böse ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'herüberfunkelte. »Haben Sie eben diesen Auspuffknall gehört? Hat ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Petunia und mir einen schönen Schreck eingejagt!« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er grinste unentwegt auf schreckliche, besessene Art umher, bis all ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'die neugierigen Nachbarn von ihren Fenstern verschwunden waren, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dann winkte er Harry zu sich heran, und aus dem Grinsen wurde eine ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wutentbrannte Grimasse. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry trat ein paar Schritte näher und achtete darauf, kurz vor dem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Punkt Halt zu machen, an dem Onkel Vernons ausgestreckte Hände ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ihn wieder würgen konnten. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Was zum Teufel soll das, Bursche?«, fragte Onkel Vernon mit ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'heiserer, vor Wut zitternder Stimme. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Was soll was?«, sagte Harry kühl. Er blickte unablässig links und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'rechts ', 'size': 11, 'flags': 4},
#    {'text': 'die ', 'size': 11, 'flags': 4},
#    {'text': 'Straße ', 'size': 11, 'flags': 4},
#    {'text': 'entlang, ', 'size': 11, 'flags': 4},
#    {'text': 'immer ', 'size': 11, 'flags': 4},
#    {'text': 'noch ', 'size': 11, 'flags': 4},
#    {'text': 'in ', 'size': 11, 'flags': 4},
#    {'text': 'der ', 'size': 11, 'flags': 4},
#    {'text': 'Hoffnung ', 'size': 11, 'flags': 4},
#    {'text': 'herauszufinden, von wem der Knall stammte. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Einen Lärm machen, als ginge eine Pistole los, und das direkt vor ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'unserem …« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Den Lärm hab ich nicht gemacht«, sagte Harry entschieden. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Neben Onkel Vernons breitem, puterrotem Gesicht tauchte jetzt ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Tante Petunias schmales Pferdegesicht auf. Sie war aschgrau. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Warum hast du unter unserem Fenster herumgelungert?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Ja – ja, gute Frage, Petunia! Was hast du unter unserem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Fenstergetrieben, Bursche?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Die Nachrichten gehört«, sagte Harry mit resignierter Stimme. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Tante und Onkel tauschten empörte Blicke. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Die Nachrichten gehört! ', 'size': 11, 'flags': 4},
#    {'text': 'Schon wieder', 'size': 11, 'flags': 6},
#    {'text': '?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Na ja, es gibt doch jeden Tag neue, oder?«, sagte Harry. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Spiel mir hier nicht den Neunmalklugen, Bursche! Ich will ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wissen, was du wirklich im Schilde führst – und hör mir bloß auf mit ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'diesem Quatsch von wegen ', 'size': 11, 'flags': 4},
#    {'text': 'die Nachrichten hören', 'size': 11, 'flags': 6},
#    {'text': '! Du weißt genau, ', 'size': 11, 'flags': 4},
#    {'text': 'dass ', 'size': 11, 'flags': 4},
#    {'text': 'deine Sippschaft ', 'size': 11, 'flags': 6},
#    {'text': '…« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Vorsicht, Vernon!«, hauchte Tante Petunia, und Onkel Vernon ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'senkte die Stimme, bis Harry ihn kaum noch hören konnte – »dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'deine Sippschaft ', 'size': 11, 'flags': 6},
#    {'text': 'nicht in ', 'size': 11, 'flags': 4},
#    {'text': 'unsere ', 'size': 11, 'flags': 6},
#    {'text': 'Nachrichten kommt!« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Das meinst du wohl«, sagte Harry. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Die Dursleys glotzten ihn ein paar Sekunden an, dann schimpfte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Tante Petunia: »Du bist ein gemeiner kleiner Lügner. Was treiben ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'denn all diese …«, auch sie senkte die Stimme, so dass Harry das ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nächste Wort von ihren Lippen ablesen musste, »… ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Eulen ', 'size': 11, 'flags': 6},
#    {'text': 'hier, wenn ', 'size': 11, 'flags': 4},
#    {'text': 'sie dir keine Nachrichten bringen?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Aha!«, flüsterte Onkel Vernon triumphierend. »Jetzt lass dir dazu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'mal eine Ausrede einfallen, Bursche! Als ob wir nicht wüssten, dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'du deine ganzen Nachrichten von diesen ekelhaften Vögeln ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'bekommst!« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry zögerte einen Moment. Es kostete ihn einige Überwindung, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'diesmal die Wahrheit zu sagen, obwohl Onkel und Tante unmöglich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wissen konnten, wie schlimm es für ihn war, sie einzugestehen. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Die Eulen … bringen mir keine Nachrichten«, antwortete er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'tonlos. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Das glaub ich nicht«, sagte Tante Petunia sofort. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Und ich auch nicht«, bestätigte Onkel Vernon. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wir wissen, dass du irgendein krummes Ding vorhast«, sagte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Tante Petunia. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wir sind schließlich nicht blöde, verstehst du«, sagte Onkel ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Vernon. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Na, ', 'size': 11, 'flags': 4},
#    {'text': 'das ', 'size': 11, 'flags': 6},
#    {'text': "ist ja mal 'ne Neuigkeit«, erwiderte Harry mit ",
#     'size': 11,
#     'flags': 4},
#    {'text': 'anschwellendem Zorn, und bevor die Dursleys ihn zurückrufen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'konnten, wirbelte er herum, lief über den Rasen, sprang über die ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'niedrige Gartenmauer und ging mit großen Schritten die Straße ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'entlang davon. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Das gab Ärger, so viel war sicher. Er würde Onkel und Tante ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'später Rede und Antwort stehen und für seine Frechheit bezahlen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'müssen, doch fürs Erste war ihm das ziemlich schnuppe; er hatte viel ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dringendere Angelegenheiten im Kopf. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry war sich sicher, dass der Knall von jemandem herrührte, der ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'appariert oder disappariert war. Es war genau das Geräusch, das ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Dobby der Hauself machte, wenn er ins Blaue hinein verschwand. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Konnte Dobby denn hier im Ligusterweg sein? Folgte ihm Dobby ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vielleicht genau in diesem Moment? Bei diesem Gedanken schnellte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er herum und spähte zurück, doch der Ligusterweg schien ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vollkommen ausgestorben, und Harry war sicher, dass Dobby nicht ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wusste, wie man sich unsichtbar machte. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er ging weiter und achtete dabei kaum auf den Weg, den er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einschlug, denn er hatte diese Straßen in letzter Zeit so oft ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'durchstreift, dass ihn seine Füße wie von allein zu seinen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Lieblingsplätzen trugen. Alle paar Schritte warf er einen Blick über ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'die Schulter. Ein magisches Wesen hatte sich in seiner Nähe ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'aufgehalten, als er zwischen Tante Petunias sterbenden Begonien ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gelegen hatte, das war sicher. Warum hatte es ihn nicht angesprochen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'warum hatte es keine Verbindung aufgenommen, warum versteckte es ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sich jetzt? ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Und dann, als seine Enttäuschung ihren Höhepunkt erreicht hatte, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schwand plötzlich diese Gewissheit. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Vielleicht war es doch kein magisches Geräusch gewesen. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Vielleicht wartete er nur so verzweifelt auf das kleinste Zeichen aus ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einer Welt, in die er gehörte, dass er bei ganz gewöhnlichen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Geräuschen einfach überreagierte. Konnte er sicher sein, dass der ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Lärm nicht daher rührte, dass in einem Nachbarhaus etwas zu Bruch ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gegangen war? ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry hatte ein dumpfes, flaues Gefühl im Magen, und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'unversehens überfiel ihn wieder die Hoffnungslosigkeit, die ihn den ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ganzen Sommer über geplagt hatte. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Morgen früh um fünf würde der Wecker ihn aus dem Schlaf reißen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'damit er die Eule bezahlen konnte, die ihm den ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Tagespropheten ', 'size': 11, 'flags': 6},
#    {'text': 'brachte – aber hatte es noch einen Zweck, ihn weiter zu beziehen? ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Harry schaute dieser Tage nur kurz auf die Titelseite und warf ihn ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dann beiseite; wenn diese Trottel von der Zeitung endlich erkannt ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hatten, dass Voldemort zurück war, würde das Schlagzeilen machen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und nur solche Nachrichten scherten Harry. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Zwar kamen, wenn er Glück hatte, auch Eulen mit Briefen von ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'seinen besten Freunden Ron und Hermine, aber all seine Erwartungen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dass ihre Briefe Neuigkeiten für ihn enthalten würden, waren schon ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'lange zunichte. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Wir können nicht viel über Du-weißt-schon-was sagen, verstehst ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'du … Man hat uns gesagt, dass wir nichts Wichtiges schreiben dürfen, ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'falls unsere Briefe in die falschen Hände gelangen … Wir sind ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'ziemlich beschäftigt, aber ich kann dir hier nichts Genaues schreiben ',
#     'size': 11,
#     'flags': 6},
#    {'text': '… Es geht einiges ab, wir erzählen dir alles, wenn wir dich treffen … ',
#     'size': 11,
#     'flags': 6},
#    {'text': 'Aber wann würden sie ihn treffen? Niemand schien sich groß um ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einen festen Termin zu kümmern. ', 'size': 11, 'flags': 4},
#    {'text': 'Ich denke, wir besuchen dich ', 'size': 11, 'flags': 6},
#    {'text': 'ziemlich bald, ', 'size': 11, 'flags': 6},
#    {'text': 'hatte Hermine auf seine Geburtstagskarte geschrieben, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'aber wie bald war bald? Soviel Harry aus den vagen Hinweisen in ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ihren Briefen schließen konnte, waren Hermine und Ron am selben ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Ort, vermutlich im Haus von Rons Eltern. Er konnte es kaum ertragen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'daran zu denken, wie die beiden im Fuchsbau ihren Spaß hatten, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'während er im Ligusterweg festsaß. Tatsächlich war er so sauer auf ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sie, dass er die beiden Schachteln mit Schokolade aus dem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Honigtopf, ', 'size': 11, 'flags': 6},
#    {'text': 'die sie ihm zum Geburtstag geschickt hatten, ungeöffnet weggeworfen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hatte. Später hatte er es bereut, nach dem welken Salat, den Tante ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Petunia am selben Abend noch zum Essen aufgetischt hatte. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Womit waren Ron und Hermine eigentlich so beschäftigt? Und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'warum war er, Harry, nicht beschäftigt? Hatte er nicht bewiesen, dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er mit viel mehr fertig werden konnte als sie? Hatten sie alle ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vergessen, was er getan hatte? War es nicht er gewesen, der diesen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Friedhof betreten und gesehen hatte, wie Cedric ermordet wurde, und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'der an diesen Grabstein gefesselt wurde und fast umgebracht worden ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wäre? ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Denk nicht drüber nach, ermahnte sich Harry streng und zum ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hundertsten Mal in diesem Sommer. Schlimm genug, dass er den ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Friedhof in seinen Alpträumen immer wieder besuchte, da brauchte er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'in seinen wachen Momenten nicht auch noch darüber nachzubrüten. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er bog um eine Ecke und war nun auf dem Magnolienring; auf ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'halbem Weg die Straße entlang kam er an der schmalen Gasse vorbei, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'die an einer Garage entlangführte und in der er zum ersten Mal seinen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Paten gesehen hatte. Sirius zumindest schien zu verstehen, wie Harry ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sich fühlte. Zugegeben, seine Briefe enthielten ebenso wenig ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'handfeste Neuigkeiten wie die von Ron und Hermine, aber wenigstens ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schrieb er ihm zur Vorsicht mahnende und tröstende Worte statt ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'quälender Andeutungen: Ich weiß, das muss frustrierend für dich sein ',
#     'size': 11,
#     'flags': 4},
#    {'text': '… Halt die Ohren steif dann wird schon alles gut gehen … Sei ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vorsichtig und tu nichts Unbesonnenes … ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Immerhin, dachte Harry, während er den Magnolienring ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'überquerte, in die Magnolienstraße einbog und auf den nun schon im ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Dunkeln liegenden Park mit dem Spielplatz zuging, immerhin hatte er ',
#     'size': 11,
#     'flags': 4},
#    {'text': '(im Wesentlichen) befolgt, was Sirius ihm geraten hatte. Zumindest ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hatte er der Versuchung widerstanden, den Koffer an seinen Besen zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'binden und sich auf eigene Faust auf die Reise zum Fuchsbau zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'machen. Im Grunde hatte er sich sehr gut verhalten, wenn er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'überlegte, wie enttäuscht und zornig er darüber war, so lange im ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Ligusterweg festzusitzen, wo er nichts weiter unternehmen konnte, als ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sich in Blumenbeeten zu verstecken, in der Hoffnung, einen Hinweis ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'darauf zu erlauschen, was Lord Voldemort gerade machte. Dennoch ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wurmte es ihn, dass ihn ausgerechnet ein Mann vor Unbesonnenheiten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'warnte, der zwölf Jahre im Zauberergefängnis von Askaban gesessen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hatte, der entkommen war, daraufhin den Mord begehen wollte, für ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'den man ihn ursprünglich verurteilt hatte, und schließlich mit einem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gestohlenen Hippogreif geflohen war. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry schwang sich über das geschlossene Parktor und überquerte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'den verdorrten Rasen. Der Park war so menschenleer wie die Straßen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'in der Nachbarschaft. Er erreichte die Schaukeln und ließ sich auf ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einer davon nieder, der letzten, die Dudley und seine Freunde noch ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nicht demoliert hatten, schlang einen Arm um die Kette und starrte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'trübsinnig auf die Erde. Im Blumenbeet der Dursleys würde er sich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nicht mehr verstecken können. Morgen musste er sich etwas Neues ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einfallen lassen, wie er die Nachrichten hören konnte. Bis dahin hatte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er nichts, auf das er sich freuen konnte, nur eine weitere unruhige, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sorgenvoll durchwälzte Nacht, denn selbst wenn er von Alpträumen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'um Cedric verschont blieb, plagten ihn schreckliche Träume von ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'langen schwarzen Korridoren, die alle an Mauern und verschlossenen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Türen endeten, was, wie er vermutete, etwas zu tun hatte mit dem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Gefühl, in der Falle zu sitzen, das ihn am Tage quälte. Seine alte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Stirnnarbe ziepte oft unangenehm, aber Ron oder Hermine oder Sirius, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'da machte er sich nichts vor, würden dies nicht mehr sonderlich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'spannend finden. Früher hatten ihn die Narbenschmerzen gewarnt, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wenn Voldemort wieder stärker wurde, doch nun, da Voldemort ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'zurückgekehrt war, würden seine Freunde ihm wohl nur zu verstehen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'geben, dass es sie nicht überraschte, wenn die Narbe ständig gereizt ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'war … kein Grund zur Sorge … Schnee von gestern … ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Das Gefühl, wie ungerecht das alles war, staute sich in ihm auf, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und er hätte am liebsten vor Wut geschrien. Wenn er nicht gewesen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wäre, hätte überhaupt niemand erfahren, dass Voldemort zurück war! ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Und zur Belohnung saß er vier geschlagene Wochen lang in Little ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Whinging, völlig abgeschnitten von der magischen Welt, dazu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'verurteilt, zwischen welken Begonien zu kauern, nur um Neuigkeiten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'über Wasserski fahrende Wellensittiche zu hören. Wie konnte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Dumbledore ihn nur einfach so vergessen? Wieso hatten Ron und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Hermine sich getroffen, ohne ihn einzuladen? Wie lange noch musste ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er sich von Sirius sagen lassen, er solle die Ohren steif halten und ein ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'braver Junge sein; oder der Versuchung widerstehen, an den blöden ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Tagespropheten ', 'size': 11, 'flags': 6},
#    {'text': 'zu schreiben und denen klar zu machen, dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Voldemort zurückgekehrt war? Solch wilde Gedanken wirbelten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'durch Harrys Kopf, und seine Eingeweide verknoteten sich vor Zorn, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'während eine schwüle, samtene Nacht sich über ihn senkte, in der die ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Luft schwer war vom Geruch warmen, trockenen Grases und einzig ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'das leise Rauschen des Verkehrs auf der Straße hinter den Parkgittern ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'zu hören war. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er wusste nicht, wie lange er auf der Schaukel gesessen hatte, als ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'das Geräusch von Stimmen seine Grübeleien unterbrach und er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'aufblickte. Die Laternen der angrenzenden Straßen spendeten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dunstiges Licht, stark genug, um die Umrisse einer Gruppe von ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Leuten hervortreten zu lassen, die auf dem Weg durch den Park ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'waren. Einer von ihnen sang ein lautes und wüstes Lied. Die anderen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'lachten. Ein leises Ticken kam von mehreren teuren Rennrädern, die ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sie mit sich schoben. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry wusste, wer diese Leute waren. Die Gestalt vorne war ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'unverkennbar sein Cousin Dudley Dursley auf dem Weg nach Hause, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'begleitet von seiner treuen Gang. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Dudley hatte so gewaltige Maße wie eh und je, doch ein Jahr ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'strenger Diät und die Entdeckung eines neuen Talents hatten seine ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Statur deutlich verändert. Wie Onkel Vernon allen, die es hören ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wollten, entzückt erzählte, war Dudley vor kurzem bei den ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schulmeisterschaften ', 'size': 11, 'flags': 4},
#    {'text': 'im ', 'size': 11, 'flags': 4},
#    {'text': 'Südwesten ', 'size': 11, 'flags': 4},
#    {'text': 'der ', 'size': 11, 'flags': 4},
#    {'text': 'Boxchampion ', 'size': 11, 'flags': 4},
#    {'text': 'im ', 'size': 11, 'flags': 4},
#    {'text': 'Juniorenschwergewicht geworden. »Der edle Sport«, wie Onkel ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Vernon ihn nannte, hatte aus Dudley eine noch furchterregendere ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Gestalt gemacht, als er es zu Harrys Grundschulzeit gewesen war, wo ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er als Dudleys erster Punchingball hatte herhalten müssen. Harry hatte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nicht die geringste Angst mehr vor seinem Cousin, doch wollte er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'trotzdem nicht glauben, dass ein Dudley, der lernte, noch härter und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gezielter zuzuschlagen, ein Grund zum Feiern sein sollte. In der ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ganzen Nachbarschaft hatten die Kinder fürchterliche Angst vor ihm – ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sogar mehr noch als vor »diesem Potter-Jungen«, der, wie man sie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gewarnt hatte, ein abgebrühter Hooligan war und ins St.-Brutus',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Sicherheitszentrum für unheilbar kriminelle Jungen ging. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry beobachtete, wie die dunklen Gestalten den Rasen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'überquerten, und fragte sich, wen sie heute Abend verprügelt hatten. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schaut euch um, ', 'size': 11, 'flags': 6},
#    {'text': 'fuhr es Harry unwillkürlich durch den Kopf, während ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er ihnen mit den Augen folgte. ', 'size': 11, 'flags': 4},
#    {'text': 'Kommt schon … schaut euch um … ich ', 'size': 11, 'flags': 6},
#    {'text': "sitze hier ganz allein … kommt und zeigt's mir … ",
#     'size': 11,
#     'flags': 6}]},
#  {'size': 11,
#   'spans': [{'text': 'Wenn Dudleys Freunde ihn hier sitzen sähen, würden sie sicher ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'geradewegs auf ihn losgehen, und was würde Dudley dann tun? Vor ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'seiner Gang wollte er gewiss nicht das Gesicht verlieren, aber er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'würde schreckliche Angst haben, Harry zu provozieren … wie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'herrlich es wäre, Dudley so hin- und hergerissen zu sehen, ihn zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'reizen, zu beobachten, wie er die Kraft nicht aufbrachte, ihm etwas ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'entgegenzusetzen … und falls einer der anderen versuchte, Harry zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schlagen, war er vorbereitet – er hatte seinen Zauberstab. Sollten sie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'doch kommen … liebend gern würde er ein wenig von seinem Frust ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'an den Jungen auslassen, die sein Leben einst zur Hölle gemacht ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hatten. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Aber sie drehten sich nicht um, sie sahen ihn nicht, hatten fast ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schon das Gitter erreicht. Harry bezwang den Impuls, ihnen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nachzurufen … eine Schlägerei anzuzetteln, war nicht klug … er ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'durfte seine magischen Kräfte nicht einsetzen … er würde wieder ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einmal den Rauswurf riskieren. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Die Stimmen von Dudleys Gang erstarben; die Jungen waren außer ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Sicht, auf dem Weg die Magnolienstraße entlang. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': "Da siehst du's mal, Sirius, dachte Harry dumpf. Nichts ",
#     'size': 11,
#     'flags': 4},
#    {'text': 'Unbesonnenes. Hab die Ohren steif gehalten. Genau das Gegenteil ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'von dem, was du getan hättest. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Er hüpfte von der Schaukel und streckte sich. Tante Petunia und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Onkel Vernon schienen der Meinung, wann auch immer Dudley ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'auftauchte, sei die richtige Zeit, um nach Hause zu kommen, und alles ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'danach sei viel zu spät. Onkel Vernon hatte gedroht, Harry im ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Schuppen einzusperren, wenn er je wieder nach Dudley heimkam, und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'so unterdrückte Harry ein Gähnen und machte sich mit immer noch ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'finsterer Miene auf den Weg zum Parktor. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Die Magnolienstraße war wie der Ligusterweg gesäumt von ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'großen, wuchtigen Häusern mit tadellos manikürten Rasenstücken, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'alle von dicken, vierschrötigen Eigenheimbesitzern gemäht, die sehr ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'saubere Autos ähnlich dem von Onkel Vernon fuhren. Harry war ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Little Whinging am Abend lieber, wenn die gardinenbewehrten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Fenster juwelenhelle Farbflecke in die Dunkelheit tupften und er nicht ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Gefahr ', 'size': 11, 'flags': 4},
#    {'text': 'lief, ', 'size': 11, 'flags': 4},
# ...
#     'size': 11,
#     'flags': 4},
#    {'text': 'gegen ihre Mutter wüten und toben hören, und als sie die Halle ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'erreicht hatte, verstärkten Mrs. Blacks markerschütternde Schreie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'noch das Getöse. Lupin eilte zum Porträt hoch, um für Ruhe zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sorgen. Erst als er zurück war, die Küchentür hinter sich geschlossen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und seinen Platz am Tisch wieder eingenommen hatte, begann Sirius ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'zu sprechen. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Gut, Harry … was willst du wissen?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Harry holte tief Luft und stellte die Frage, die ihn seit einem Monat ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nicht mehr losließ. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wo ist Voldemort?«, sagte er, ohne darauf zu achten, dass bei ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dem Namen wieder alle schauderten und zusammenzuckten. »Was hat ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er unternommen? Ich hab versucht die Muggelnachrichten zu sehen, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und es gab noch nichts, was nach ihm aussah, keine merkwürdigen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Todesfälle und dergleichen.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Weil es bislang noch keine merkwürdigen Todesfälle gegeben ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'hat«, sagte Sirius, »jedenfalls soweit wir wissen … und wir wissen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'eine ganze Menge.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Auf jeden Fall mehr, als er glaubt«, sagte Lupin. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wie kommt es, dass er aufgehört hat, Menschen zu töten?«, fragte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Harry. Er wusste, dass Voldemort allein im vergangenen Jahr mehr als ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einmal gemordet hatte. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Weil er keine Aufmerksamkeit auf sich lenken will«, sagte Sirius. ',
#     'size': 11,
#     'flags': 4},
#    {'text': '»Das wäre gefährlich für ihn. Seine Rückkehr ist ihm nicht ganz so ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'gelungen, wie er sich das vorgestellt hat, verstehst du. Er hat sie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'vermasselt.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Besser gesagt, du hast sie ihm vermasselt«, sagte Lupin und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'lächelte zufrieden. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wie?«, fragte Harry perplex. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Du solltest eigentlich nicht überleben!«, sagte Sirius. »Niemand ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'außer seinen Todessern sollte wissen, dass er zurück ist. Aber du hast ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'überlebt und kannst es bezeugen.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Und der Letzte, der wegen seiner Rückkehr alarmiert werden ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sollte, war Dumbledore«, sagte Lupin. »Und du hast dafür gesorgt, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dass es Dumbledore sofort erfahren hat.« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Und was hat das gebracht?«, fragte Harry. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Machst du Witze?«, entgegnete Bill ungläubig. »Dumbledore war ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'der Einzige, vor dem Du-weißt-schon-wer jemals Angst hatte!« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Dank dir konnte Dumbledore schon eine knappe Stunde nach ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Voldemorts Rückkehr den Orden des Phönix wieder einberufen«, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sagte Sirius. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Und – was hat der Orden unternommen?«, sagte Harry und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'blickte in die Runde. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wir tun alles, was wir können, um dafür zu sorgen, dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Voldemort seine Pläne nicht verwirklichen kann«, erwiderte Sirius. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Woher wisst ihr, was er plant?«, fragte Harry rasch. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Dumbledore hat eine ungefähre Vorstellung«, sagte Lupin, »und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Dumbledores ungefähre Vorstellungen erweisen sich normalerweise ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'als zutreffend.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Und was vermutet Dumbledore, dass er plant?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Nun, zunächst will er seine Armee wieder aufbauen«, sagte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Sirius. »In alten Zeiten standen gewaltige Scharen unter seinem ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Befehl: Hexen und Zauberer, die er erpresst oder verhext hatte, ihm zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'folgen, seine getreuen Todesser, viele verschiedene dunkle Kreaturen. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Du hast gehört, dass er vorhat, die Riesen für sich zu gewinnen; nun, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'das wird nur eine der Gruppen sein, die er für sich einnehmen will. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Mit Sicherheit wird er nicht versuchen, es nur mit einem Dutzend ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Todessern gegen das Zaubereiministerium aufzunehmen.« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Also versucht ihr, ihn aufzuhalten, bevor er noch mehr Anhänger ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'bekommt?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wir tun unser Bestes«, erwiderte Lupin. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11, 'spans': [{'text': '»Wie?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Nun, das Wichtigste ist, dass wir versuchen, möglichst viele ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'davon zu überzeugen, dass Du-weißt-schon-wer zurückgekehrt ist, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'damit sie sich wappnen«, sagte Bill. »Das ist allerdings gar nicht so ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einfach.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11, 'spans': [{'text': '»Warum?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wegen der Haltung des Ministeriums«, sagte Tonks. »Du hast ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Cornelius ', 'size': 11, 'flags': 4},
#    {'text': 'Fudge ', 'size': 11, 'flags': 4},
#    {'text': 'gesehen, ', 'size': 11, 'flags': 4},
#    {'text': 'nachdem ', 'size': 11, 'flags': 4},
#    {'text': 'Du-weißt-schon-wer ', 'size': 11, 'flags': 4},
#    {'text': 'zurückgekommen war, Harry. Nun, er hat seine Position überhaupt ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'nicht verändert. Er weigert sich steif und fest zu glauben, dass es so ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ist.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Aber weshalb?«, fragte Harry aufgebracht. »Weshalb ist er so ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'dumm? Wenn Dumbledore …« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Tja, da hast du den Finger auf die Wunde gelegt«, sagte Mr. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Weasley mit einem gequälten Lächeln. »Dumbledore.« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Fudge hat Angst vor ihm, verstehst du«, sagte Tonks traurig. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Angst vor Dumbledore?«, fragte Harry ungläubig. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Angst vor dem, was er vorhat«, erwiderte Mr. Weasley. »Fudge ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'glaubt, Dumbledore heckt eine Verschwörung aus, um ihn zu stürzen. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Er glaubt, Dumbledore will Zaubereiminister werden.« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Aber Dumbledore will doch nicht …« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Natürlich will er nicht«, sagte Mr. Weasley. »Er wollte nie das ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Amt des Ministers, obwohl eine Menge Leute ihn dazu gedrängt ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'haben, als Millicent Bagnold in den Ruhestand ging. Stattdessen kam ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Fudge an die Macht, aber er hat nie vergessen, welch breite ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Unterstützung Dumbledore genoss, obwohl er sich nie um den Posten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'beworben hatte.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Tief in seinem Innern weiß Fudge, dass Dumbledore weit klüger ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ist als er, ein viel mächtigerer Zauberer, und in seiner frühen Amtszeit ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'als Minister hat er Dumbledore ständig um Hilfe und Rat gebeten«, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sagte Lupin. »Aber wie es scheint, hat er sich mit der Macht ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'angefreundet und ist viel selbstsicherer geworden. Er genießt es, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Zaubereiminister zu sein, und hat es geschafft, sich einzureden, dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er der Klügste ist und dass Dumbledore nur Scherereien um ihrer ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'selbst willen heraufbeschwört.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wie kann er so etwas glauben?«, sagte Harry zornig. »Wie kann ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er glauben, dass Dumbledore alles nur erfindet – dass ich alles ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'erfinde?« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wenn das Ministerium sich eingestehen würde, dass Voldemort ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'zurück ist, hieße das, sie hätten es mit den größten Schwierigkeiten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'seit fast vierzehn Jahren zu tun«, sagte Sirius bitter. »Fudge bringt es ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'einfach nicht fertig, sich dem zu stellen. Es ist ja so viel bequemer, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wenn er sich einredet, Dumbledore lüge, um seine Stellung zu ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'untergraben.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Da liegt das Problem«, sagte Lupin. »Wenn das Ministerium ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'darauf beharrt, dass es von Voldemort nichts zu befürchten gibt, ist es ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'schwierig, die Leute davon zu überzeugen, dass er zurück ist, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'besonders da sie es zunächst im Grunde gar nicht glauben wollen. ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Zudem übt das Ministerium starken Druck auf den Tagespropheten ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'aus, nichts von dem zu berichten, was sie Dumbledores ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Gerüchteküche ', 'size': 11, 'flags': 4},
#    {'text': 'nennen, ', 'size': 11, 'flags': 4},
#    {'text': 'also ', 'size': 11, 'flags': 4},
#    {'text': 'hat ', 'size': 11, 'flags': 4},
#    {'text': 'der ', 'size': 11, 'flags': 4},
#    {'text': 'größte ', 'size': 11, 'flags': 4},
#    {'text': 'Teil ', 'size': 11, 'flags': 4},
#    {'text': 'der ', 'size': 11, 'flags': 4},
#    {'text': 'Zauberergemeinschaft überhaupt keine Ahnung, dass irgendetwas ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'geschehen ist, und das macht sie zu leichter Beute für die Todesser, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wenn die den Imperius-Fluch einsetzen.« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Aber ihr erzählt es doch den Leuten, oder nicht?«, sagte Harry ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und blickte reihum zu Mr. Weasley, Sirius, Bill, Mundungus, Lupin ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'und Tonks. »Ihr lasst die Leute doch wissen, dass er zurück ist?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': 'Sie lächelten gezwungen. ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Nun ja, alle glauben, ich sei ein verrückter Massenmörder, und ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'das Ministerium hat einen Preis von zehntausend Galleonen auf ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'meinen Kopf ausgesetzt. Ich kann wohl kaum durch die Straßen ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ziehen und Flugblätter verteilen, oder?«, sagte Sirius unruhig. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Und ich bin bei den meisten in der Gemeinschaft kein sonderlich ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'beliebter Dinnergast«, sagte Lupin. »Das gehört zum Berufsrisiko ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'eines Werwolfs.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Tonks und Arthur würden ihre Stellen im Ministerium verlieren, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'wenn sie anfingen, den Mund aufzumachen«, sagte Sirius, »und es ist ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sehr wichtig für uns, Spione im Ministerium zu haben, weil du davon ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'ausgehen kannst, dass Voldemort auch welche hat.« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Immerhin haben wir es geschafft, ein paar Leute zu überzeugen«, ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sagte Mr. Weasley. »Tonks hier, zum Beispiel – das letzte Mal war sie ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'noch zu jung für den Orden des Phönix, und Auroren auf unserer Seite ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'zu haben ist ein gewaltiger Vorteil – auch Kingsley Shacklebolt ist ein ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'echter Trumpf; er ist verantwortlich für die Jagd nach Sirius, also hat ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'er das Ministerium mit der Information gefüttert, dass Sirius in Tibet ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'sei.« ', 'size': 11, 'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Aber wenn keiner von euch die Nachricht verbreitet, dass ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Voldemort zurück ist …«, fing Harry an. ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Wer sagt, dass keiner von uns die Nachricht verbreitet?«, sagte ',
#     'size': 11,
#     'flags': 4},
#    {'text': 'Sirius. »Warum, glaubst du, hat Dumbledore so viel Ärger?« ',
#     'size': 11,
#     'flags': 4}]},
#  {'size': 11,
#   'spans': [{'text': '»Was soll das heißen?«, fragte Harry. ',
#     'size': 11,
#     'flags': 4}]},
#  ...]

# %%
def combine_spans(paragraphs, text_size):

    def inner_combine(paragraph):
        paragraph_text = ''
        for span in paragraph['spans']:
            text = span['text']
            flags = flags_decomposer(span['flags'])
            if 'italic' in flags:
                text = '<i>' + text + '</i>'
            if 'bold' in flags:
                text = '<b>' + text + '</b>'
            if 'monospaced' in flags:
                text = '<tt>' + text + '</tt>'
            if 'superscript' in flags:
                text = '<sup>' + text + '</sup>'
            if span['size'] < text_size:
                text = '<small>' + text + '</small>'
            paragraph_text += text
        return {
            'size': paragraph['size'],
            'text': paragraph_text
        }
    
    return list(map(inner_combine, paragraphs))

# %%
ps = combine_spans(ps, text_size)
ps
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/julian/Projects/PDF2EPUB/playground.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000018vscode-remote?line=0'>1</a> ps = combine_spans(ps, text_size)
#       <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000018vscode-remote?line=1'>2</a> ps
#
# /home/julian/Projects/PDF2EPUB/playground.ipynb Cell 16' in combine_spans(paragraphs, text_size)
#      <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=13'>14</a>         paragraph_text += text
#      <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=14'>15</a>     return {
#      <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=15'>16</a>         'size': paragraph['size'],
#      <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=16'>17</a>         'text': paragraph_text
#      <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=17'>18</a>     }
# ---> <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=19'>20</a> return list(map(inner_combine, paragraphs))
#
# /home/julian/Projects/PDF2EPUB/playground.ipynb Cell 16' in combine_spans.<locals>.inner_combine(paragraph)
#       <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=2'>3</a> def inner_combine(paragraph):
#       <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=3'>4</a>     paragraph_text = ''
# ----> <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=4'>5</a>     for span in paragraph['spans']:
#       <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=5'>6</a>         text = span['text']
#       <a href='vscode-notebook-cell://badbatscode.ddns.net/home/julian/Projects/PDF2EPUB/playground.ipynb#ch0000017vscode-remote?line=6'>7</a>         flags = flags_decomposer(span['flags'])
#
# KeyError: 'spans'

# %%
def paragraphs_to_chapters(paragraphs, text_size):
    chapters = []
    current_chapter_title = ''
    current_chapter_content = ''

    for paragraph in paragraphs:
        
        # If the text size is great, create a new chapter
        if paragraph['size'] >= text_size + UNCERTAINTY_SIZE:
            chapters.append({
                'title': current_chapter_title,
                'content': current_chapter_content
            })
            current_chapter_title = paragraph['text']
            current_chapter_content = ''

        # Else add the paragraph
        else:
            current_chapter_content += '<p>' + paragraph['text'] + '</p>'
        
    # Add final chapter
    chapters.append({
        'title': current_chapter_title,
        'content': current_chapter_content
    })
    
    return chapters[1:]

# %%
chapters = paragraphs_to_chapters(ps, text_size)
for (i, chapter) in enumerate(chapters):
    title = chapter['title']
    print(f'{i+1:02} :: {title}')
# Out:
# 01 :: <b>Dudley umnachtet </b>
# 02 :: <b>Eulen über Eulen </b>
# 03 :: <b>Die Vorhut </b>
# 04 :: <b>Grimmauldplatz Nummer zwölf </b>
# 05 :: <b>Der Orden des Phönix </b>
# 06 :: <b>Das fürnehme und gar alte Haus </b><b>der Blacks </b>
# 07 :: <b>Das Zaubereiministerium </b>
# 08 :: <b>Die Anhörung </b>
# 09 :: <b>Mrs. Weasleys Wehklage </b>
# 10 :: <b>Luna Lovegood </b>
# 11 :: <b>Das neue Lied des Sprechenden </b><b>Huts </b>
# 12 :: <b>Professor Umbridge </b>
# 13 :: <b>Strafarbeit bei Dolores </b>
# 14 :: <b>Percy und Tatze </b>
# 15 :: <b>Die Großinquisitorin von Hogwarts </b>
# 16 :: <b>Im Eberkopf </b>
# 17 :: <b>Ausbildungserlass Nummer </b><b>vierundzwanzig </b>
# 18 :: <b>Dumbledores Armee </b>
# 19 :: <b>Der Löwe und die Schlange </b>
# 20 :: <b>Hagrids Geschichte </b>
# 21 :: <b>Das Auge der Schlange </b>
# 22 :: <b>St.-Mungo-Hospital für Magische </b><b>Krankheiten und Verletzungen </b>
# 23 :: <b>Weihnachten auf der geschlossenen </b><b>Station </b>
# 24 :: <b>Okklumentik </b>
# 25 :: <b>Der Käfer in der Klemme </b>
# 26 :: <b>Gesehen – unvorhergesehen </b>
# 27 :: <b>Der Zentaur und die Petze </b>
# 28 :: <b>Snapes schlimmste Erinnerung </b>
# 29 :: <b>Berufsberatung </b>
# 30 :: <b>Grawp </b>
# 31 :: <b>ZAGs </b>
# 32 :: <b>Aus dem Feuer </b>
# 33 :: <b>Kampf und Flucht </b>
# 34 :: <b>Die Mysteriumsabteilung </b>
# 35 :: <b>Jenseits des Schleiers </b>
# 36 :: <b>Der Einzige, den er je fürchtete </b>
# 37 :: <b>Die verlorene Prophezeiung </b>
# 38 :: <b>Der zweite Krieg beginnt </b>

# %%
def parse_book(file_path, starting_page=0):
    book = fitz.open(file_path)
    
    spans = get_spans(book, starting_page=starting_page)
    lines = group_spans_in_lines(spans)

    text_size, end_pos = get_text_constants(lines)
    print(f'Found ({text_size=}, {end_pos=})')

    paragraphs = lines_to_paragraphs(lines, text_size, end_pos)
    paragraphs = combine_spans(paragraphs, text_size)
    chapters = paragraphs_to_chapters(paragraphs, text_size)
    
    return chapters

# %%
chs = parse_book('hp1.pdf', starting_page=6)
# Out:
# Found (text_size=12, end_pos=354)

# %%
# TODO:
#  - Ersetze HTML Chars
